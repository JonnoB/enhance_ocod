# %%
import requests
import json
import os

# Your API key
API_KEY = "900d6123-fa32-4830-b753-9d4cf4cafb48"

# Base URL
BASE_URL = "https://use-land-property-data.service.gov.uk/api/v1/"


# Headers
headers = {
    "Authorization": API_KEY,  # API key should be provided directly as the Authorization header
    "Accept": "application/json"  # As advised in the documentation
}

# Get list of available datasets
def get_available_datasets():
    response = requests.get(f"{BASE_URL}datasets", headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: {response.status_code}")
        print(response.text)
        return None

# Get metadata for a specific dataset
def get_dataset_metadata(dataset_name):
    response = requests.get(f"{BASE_URL}datasets/{dataset_name}", headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: {response.status_code}")
        print(response.text)
        return None

# Get download link for a specific file in a dataset
def get_download_link(dataset_name, file_name):
    response = requests.get(f"{BASE_URL}datasets/{dataset_name}/{file_name}", headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: {response.status_code}")
        print(response.text)
        return None

# Get history of a dataset
def get_dataset_history(dataset_name):
    response = requests.get(f"{BASE_URL}datasets/history/{dataset_name}", headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: {response.status_code}")
        print(response.text)
        return None

# Get download link for a historical file
def get_historical_download_link(dataset_name, file_name):
    response = requests.get(f"{BASE_URL}datasets/history/{dataset_name}/{file_name}", headers=headers)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: {response.status_code}")
        print(response.text)
        return None

# Download a file using the temporary download URL
def download_file(download_url, output_path):
    response = requests.get(download_url, stream=True)
    if response.status_code == 200:
        with open(output_path, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        return True
    else:
        print(f"Download error: {response.status_code}")
        return False
    
    # You can then choose a dataset ID to get more info or download
    # For example:
    # dataset_id = "your_chosen_dataset_id"
    # metadata = get_dataset_metadata(dataset_id)
    # if metadata:
    #     print(json.dumps(metadata, indent=2))
    #
    # success = download_dataset(dataset_id, f"/path/to/save/{dataset_id}.csv")
    # if success:
    #     print(f"Dataset {dataset_id} downloaded successfully")

# %%
get_available_datasets()
# Out:
# {'result': [{'name': 'ccod',
#    'title': 'UK companies that own property in England and Wales'},
#   {'name': 'ocod',
#    'title': 'Overseas companies that own property in England and Wales'},
#   {'name': 'nps', 'title': 'National Polygon Service'},
#   {'name': 'nps_sample', 'title': 'National Polygon Service Sample'},
#   {'name': 'res_cov', 'title': 'Restrictive Covenants'},
#   {'name': 'leases', 'title': 'Registered Leases'}],
#  'success': True}

# %%
get_dataset_metadata("ocod")
# Out:
# {'result': {'dataset_id': 54,
#   'description': 'Download data about non-UK companies that own land or property in England and Wales. This dataset was originally called Overseas companies ownership data (OCOD).',
#   'external': False,
#   'fee': 'Free',
#   'file_count': None,
#   'file_size': '37.09 MB',
#   'format': 'CSV',
#   'last_updated': '2 May 2025',
#   'licence_id': 'ocod',
#   'metadata_created': 'Tue, 28 Nov 2023 11:33:33 GMT',
#   'name': 'ocod',
#   'private': False,
#   'public_resources': [{'file_count': 1,
#     'file_name': 'example.csv',
#     'file_size': '5.68 KB',
#     'format': 'CSV',
#     'name': 'Example Data',
#     'row_count': 15}],
#   'resources': [{'file_count': 1,
#     'file_name': 'OCOD_COU_2025_05.zip',
#     'file_size': '946.68 KB',
#     'format': 'CSV',
#     'name': 'Change Only File',
#     'row_count': 2178},
#    {'file_count': 1,
#     'file_name': 'OCOD_FULL_2025_05.zip',
#     'file_size': '37.09 MB',
#     'format': 'CSV',
#     'name': 'Full File',
#     'row_count': 92171}],
#   'state': 'active',
#   'tech_spec_url': 'https://www.gov.uk/government/publications/overseas-companies-ownership-data-technical-specification',
#   'title': 'Overseas companies that own property in England and Wales',
#   'type': 'licenced',
#   'update_frequency': 'Monthly',
#   'url': None,
#   'version': 'v1'},
#  'success': True}

# %%
get_dataset_history('ocod')
# Out:
# {'dataset': 'ocod',
#  'dataset_history': [{'file_size': '3.33 MB',
#    'filename': 'OCOD_COU_2025_04.zip',
#    'last_updated': 'April 2025',
#    'unsorted_date': '02-04-2025'},
#   {'file_size': '37.1 MB',
#    'filename': 'OCOD_FULL_2025_04.zip',
#    'last_updated': 'April 2025',
#    'unsorted_date': '02-04-2025'},
#   {'file_size': '1.57 MB',
#    'filename': 'OCOD_COU_2025_03.zip',
#    'last_updated': 'March 2025',
#    'unsorted_date': '04-03-2025'},
#   {'file_size': '37.13 MB',
#    'filename': 'OCOD_FULL_2025_03.zip',
#    'last_updated': 'March 2025',
#    'unsorted_date': '04-03-2025'},
#   {'file_size': '818.19 KB',
#    'filename': 'OCOD_COU_2025_02.zip',
#    'last_updated': 'February 2025',
#    'unsorted_date': '04-02-2025'},
#   {'file_size': '37.18 MB',
#    'filename': 'OCOD_FULL_2025_02.zip',
#    'last_updated': 'February 2025',
#    'unsorted_date': '04-02-2025'},
#   {'file_size': '722.36 KB',
#    'filename': 'OCOD_COU_2025_01.zip',
#    'last_updated': 'January 2025',
#    'unsorted_date': '03-01-2025'},
#   {'file_size': '37.22 MB',
#    'filename': 'OCOD_FULL_2025_01.zip',
#    'last_updated': 'January 2025',
#    'unsorted_date': '03-01-2025'},
#   {'file_size': '933.06 KB',
#    'filename': 'OCOD_COU_2024_12.zip',
#    'last_updated': 'December 2024',
#    'unsorted_date': '03-12-2024'},
#   {'file_size': '37.24 MB',
#    'filename': 'OCOD_FULL_2024_12.zip',
#    'last_updated': 'December 2024',
#    'unsorted_date': '03-12-2024'},
#   {'file_size': '1.02 MB',
#    'filename': 'OCOD_COU_2024_11.zip',
#    'last_updated': 'November 2024',
#    'unsorted_date': '02-11-2024'},
#   {'file_size': '37.28 MB',
#    'filename': 'OCOD_FULL_2024_11.zip',
#    'last_updated': 'November 2024',
#    'unsorted_date': '02-11-2024'},
#   {'file_size': '693.41 KB',
#    'filename': 'OCOD_COU_2024_10.zip',
#    'last_updated': 'October 2024',
#    'unsorted_date': '02-10-2024'},
#   {'file_size': '37.31 MB',
#    'filename': 'OCOD_FULL_2024_10.zip',
#    'last_updated': 'October 2024',
#    'unsorted_date': '02-10-2024'},
#   {'file_size': '794.22 KB',
#    'filename': 'OCOD_COU_2024_09.zip',
#    'last_updated': 'September 2024',
#    'unsorted_date': '03-09-2024'},
#   {'file_size': '37.3 MB',
#    'filename': 'OCOD_FULL_2024_09.zip',
#    'last_updated': 'September 2024',
#    'unsorted_date': '03-09-2024'},
#   {'file_size': '774.63 KB',
#    'filename': 'OCOD_COU_2024_08.zip',
#    'last_updated': 'August 2024',
#    'unsorted_date': '02-08-2024'},
#   {'file_size': '37.32 MB',
#    'filename': 'OCOD_FULL_2024_08.zip',
#    'last_updated': 'August 2024',
#    'unsorted_date': '02-08-2024'},
#   {'file_size': '894.87 KB',
#    'filename': 'OCOD_COU_2024_07.zip',
#    'last_updated': 'July 2024',
#    'unsorted_date': '02-07-2024'},
#   {'file_size': '37.35 MB',
#    'filename': 'OCOD_FULL_2024_07.zip',
#    'last_updated': 'July 2024',
#    'unsorted_date': '02-07-2024'},
#   {'file_size': '551.53 KB',
#    'filename': 'OCOD_COU_2024_06.zip',
#    'last_updated': 'June 2024',
#    'unsorted_date': '04-06-2024'},
#   {'file_size': '37.34 MB',
#    'filename': 'OCOD_FULL_2024_06.zip',
#    'last_updated': 'June 2024',
#    'unsorted_date': '04-06-2024'},
#   {'file_size': '1.14 MB',
#    'filename': 'OCOD_COU_2024_05.zip',
#    'last_updated': 'May 2024',
#    'unsorted_date': '07-05-2024'},
#   {'file_size': '37.35 MB',
#    'filename': 'OCOD_FULL_2024_05.zip',
#    'last_updated': 'May 2024',
#    'unsorted_date': '07-05-2024'},
#   {'file_size': '228.31 KB',
#    'filename': 'OCOD_COU_2024_04.zip',
#    'last_updated': 'April 2024',
#    'unsorted_date': '02-04-2024'},
#   {'file_size': '7.76 MB',
#    'filename': 'OCOD_FULL_2024_04.zip',
#    'last_updated': 'April 2024',
#    'unsorted_date': '02-04-2024'},
#   {'file_size': '179.93 KB',
#    'filename': 'OCOD_COU_2024_03.zip',
#    'last_updated': 'March 2024',
#    'unsorted_date': '02-03-2024'},
#   {'file_size': '7.81 MB',
#    'filename': 'OCOD_FULL_2024_03.zip',
#    'last_updated': 'March 2024',
#    'unsorted_date': '02-03-2024'},
#   {'file_size': '214.98 KB',
#    'filename': 'OCOD_COU_2024_02.zip',
#    'last_updated': 'February 2024',
#    'unsorted_date': '02-02-2024'},
#   {'file_size': '7.73 MB',
#    'filename': 'OCOD_FULL_2024_02.zip',
#    'last_updated': 'February 2024',
#    'unsorted_date': '02-02-2024'},
#   {'file_size': '160.21 KB',
#    'filename': 'OCOD_COU_2024_01.zip',
#    'last_updated': 'January 2024',
#    'unsorted_date': '02-01-2024'},
#   {'file_size': '7.85 MB',
#    'filename': 'OCOD_FULL_2024_01.zip',
#    'last_updated': 'January 2024',
#    'unsorted_date': '02-01-2024'},
#   {'file_size': '217.62 KB',
#    'filename': 'OCOD_COU_2023_12.zip',
#    'last_updated': 'December 2023',
#    'unsorted_date': '02-12-2023'},
#   {'file_size': '7.75 MB',
#    'filename': 'OCOD_FULL_2023_12.zip',
#    'last_updated': 'December 2023',
#    'unsorted_date': '02-12-2023'},
#   {'file_size': '192.66 KB',
#    'filename': 'OCOD_COU_2023_11.zip',
#    'last_updated': 'November 2023',
#    'unsorted_date': '02-11-2023'},
#   {'file_size': '7.85 MB',
#    'filename': 'OCOD_FULL_2023_11.zip',
#    'last_updated': 'November 2023',
#    'unsorted_date': '02-11-2023'},
#   {'file_size': '198.68 KB',
#    'filename': 'OCOD_COU_2023_10.zip',
#    'last_updated': 'October 2023',
#    'unsorted_date': '02-10-2023'},
#   {'file_size': '7.73 MB',
#    'filename': 'OCOD_FULL_2023_10.zip',
#    'last_updated': 'October 2023',
#    'unsorted_date': '02-10-2023'},
#   {'file_size': '203.38 KB',
#    'filename': 'OCOD_COU_2023_09.zip',
#    'last_updated': 'September 2023',
#    'unsorted_date': '02-09-2023'},
#   {'file_size': '7.83 MB',
#    'filename': 'OCOD_FULL_2023_09.zip',
#    'last_updated': 'September 2023',
#    'unsorted_date': '02-09-2023'},
#   {'file_size': '269.09 KB',
#    'filename': 'OCOD_COU_2023_08.zip',
#    'last_updated': 'August 2023',
#    'unsorted_date': '02-08-2023'},
#   {'file_size': '7.75 MB',
#    'filename': 'OCOD_FULL_2023_08.zip',
#    'last_updated': 'August 2023',
#    'unsorted_date': '02-08-2023'},
#   {'file_size': '306.79 KB',
#    'filename': 'OCOD_COU_2023_07.zip',
#    'last_updated': 'July 2023',
#    'unsorted_date': '02-07-2023'},
#   {'file_size': '7.78 MB',
#    'filename': 'OCOD_FULL_2023_07.zip',
#    'last_updated': 'July 2023',
#    'unsorted_date': '02-07-2023'},
#   {'file_size': '246.19 KB',
#    'filename': 'OCOD_COU_2023_06.zip',
#    'last_updated': 'June 2023',
#    'unsorted_date': '02-06-2023'},
#   {'file_size': '7.74 MB',
#    'filename': 'OCOD_FULL_2023_06.zip',
#    'last_updated': 'June 2023',
#    'unsorted_date': '02-06-2023'},
#   {'file_size': '447.22 KB',
#    'filename': 'OCOD_COU_2023_05.zip',
#    'last_updated': 'May 2023',
#    'unsorted_date': '02-05-2023'},
#   {'file_size': '7.74 MB',
#    'filename': 'OCOD_FULL_2023_05.zip',
#    'last_updated': 'May 2023',
#    'unsorted_date': '02-05-2023'},
#   {'file_size': '289.84 KB',
#    'filename': 'OCOD_COU_2023_04.zip',
#    'last_updated': 'April 2023',
#    'unsorted_date': '02-04-2023'},
#   {'file_size': '7.73 MB',
#    'filename': 'OCOD_FULL_2023_04.zip',
#    'last_updated': 'April 2023',
#    'unsorted_date': '02-04-2023'},
#   {'file_size': '228.93 KB',
#    'filename': 'OCOD_COU_2023_03.zip',
#    'last_updated': 'March 2023',
#    'unsorted_date': '02-03-2023'},
#   {'file_size': '7.75 MB',
#    'filename': 'OCOD_FULL_2023_03.zip',
#    'last_updated': 'March 2023',
#    'unsorted_date': '02-03-2023'},
#   {'file_size': '199.2 KB',
#    'filename': 'OCOD_COU_2023_02.zip',
#    'last_updated': 'February 2023',
#    'unsorted_date': '02-02-2023'},
#   {'file_size': '7.68 MB',
#    'filename': 'OCOD_FULL_2023_02.zip',
#    'last_updated': 'February 2023',
#    'unsorted_date': '02-02-2023'},
#   {'file_size': '579.0 KB',
#    'filename': 'OCOD_COU_2023_01.zip',
#    'last_updated': 'January 2023',
#    'unsorted_date': '02-01-2023'},
#   {'file_size': '7.73 MB',
#    'filename': 'OCOD_FULL_2023_01.zip',
#    'last_updated': 'January 2023',
#    'unsorted_date': '02-01-2023'},
#   {'file_size': '594.04 KB',
#    'filename': 'OCOD_COU_2022_12.zip',
#    'last_updated': 'December 2022',
#    'unsorted_date': '02-12-2022'},
#   {'file_size': '7.71 MB',
#    'filename': 'OCOD_FULL_2022_12.zip',
#    'last_updated': 'December 2022',
#    'unsorted_date': '02-12-2022'},
#   {'file_size': '138.62 KB',
#    'filename': 'OCOD_COU_2022_11.zip',
#    'last_updated': 'November 2022',
#    'unsorted_date': '02-11-2022'},
#   {'file_size': '7.73 MB',
#    'filename': 'OCOD_FULL_2022_11.zip',
#    'last_updated': 'November 2022',
#    'unsorted_date': '02-11-2022'},
#   {'file_size': '255.25 KB',
#    'filename': 'OCOD_COU_2022_10.zip',
#    'last_updated': 'October 2022',
#    'unsorted_date': '02-10-2022'},
#   {'file_size': '7.8 MB',
#    'filename': 'OCOD_FULL_2022_10.zip',
#    'last_updated': 'October 2022',
#    'unsorted_date': '02-10-2022'},
#   {'file_size': '340.0 KB',
#    'filename': 'OCOD_COU_2022_09.zip',
#    'last_updated': 'September 2022',
#    'unsorted_date': '02-09-2022'},
#   {'file_size': '7.8 MB',
#    'filename': 'OCOD_FULL_2022_09.zip',
#    'last_updated': 'September 2022',
#    'unsorted_date': '02-09-2022'},
#   {'file_size': '183.94 KB',
#    'filename': 'OCOD_COU_2022_08.zip',
#    'last_updated': 'August 2022',
#    'unsorted_date': '02-08-2022'},
#   {'file_size': '7.84 MB',
#    'filename': 'OCOD_FULL_2022_08.zip',
#    'last_updated': 'August 2022',
#    'unsorted_date': '02-08-2022'},
#   {'file_size': '130.01 KB',
#    'filename': 'OCOD_COU_2022_07.zip',
#    'last_updated': 'July 2022',
#    'unsorted_date': '02-07-2022'},
#   {'file_size': '7.82 MB',
#    'filename': 'OCOD_FULL_2022_07.zip',
#    'last_updated': 'July 2022',
#    'unsorted_date': '02-07-2022'},
#   {'file_size': '178.33 KB',
#    'filename': 'OCOD_COU_2022_06.zip',
#    'last_updated': 'June 2022',
#    'unsorted_date': '02-06-2022'},
#   {'file_size': '7.85 MB',
#    'filename': 'OCOD_FULL_2022_06.zip',
#    'last_updated': 'June 2022',
#    'unsorted_date': '02-06-2022'},
#   {'file_size': '158.53 KB',
#    'filename': 'OCOD_COU_2022_05.zip',
#    'last_updated': 'May 2022',
#    'unsorted_date': '02-05-2022'},
#   {'file_size': '7.82 MB',
#    'filename': 'OCOD_FULL_2022_05.zip',
#    'last_updated': 'May 2022',
#    'unsorted_date': '02-05-2022'},
#   {'file_size': '177.22 KB',
#    'filename': 'OCOD_COU_2022_04.zip',
#    'last_updated': 'April 2022',
#    'unsorted_date': '02-04-2022'},
#   {'file_size': '7.82 MB',
#    'filename': 'OCOD_FULL_2022_04.zip',
#    'last_updated': 'April 2022',
#    'unsorted_date': '02-04-2022'},
#   {'file_size': '227.37 KB',
#    'filename': 'OCOD_COU_2022_03.zip',
#    'last_updated': 'March 2022',
#    'unsorted_date': '02-03-2022'},
#   {'file_size': '7.83 MB',
#    'filename': 'OCOD_FULL_2022_03.zip',
#    'last_updated': 'March 2022',
#    'unsorted_date': '02-03-2022'},
#   {'file_size': '180.84 KB',
#    'filename': 'OCOD_COU_2022_02.zip',
#    'last_updated': 'February 2022',
#    'unsorted_date': '02-02-2022'},
#   {'file_size': '7.88 MB',
#    'filename': 'OCOD_FULL_2022_02.zip',
#    'last_updated': 'February 2022',
#    'unsorted_date': '02-02-2022'},
#   {'file_size': '164.34 KB',
#    'filename': 'OCOD_COU_2022_01.zip',
#    'last_updated': 'January 2022',
#    'unsorted_date': '02-01-2022'},
#   {'file_size': '7.86 MB',
#    'filename': 'OCOD_FULL_2022_01.zip',
#    'last_updated': 'January 2022',
#    'unsorted_date': '02-01-2022'},
#   {'file_size': '165.27 KB',
#    'filename': 'OCOD_COU_2021_12.zip',
#    'last_updated': 'December 2021',
#    'unsorted_date': '02-12-2021'},
#   {'file_size': '7.85 MB',
#    'filename': 'OCOD_FULL_2021_12.zip',
#    'last_updated': 'December 2021',
#    'unsorted_date': '02-12-2021'},
#   {'file_size': '170.29 KB',
#    'filename': 'OCOD_COU_2021_11.zip',
#    'last_updated': 'November 2021',
#    'unsorted_date': '02-11-2021'},
#   {'file_size': '7.83 MB',
#    'filename': 'OCOD_FULL_2021_11.zip',
#    'last_updated': 'November 2021',
#    'unsorted_date': '02-11-2021'},
#   {'file_size': '145.69 KB',
#    'filename': 'OCOD_COU_2021_10.zip',
#    'last_updated': 'October 2021',
#    'unsorted_date': '02-10-2021'},
#   {'file_size': '7.89 MB',
#    'filename': 'OCOD_FULL_2021_10.zip',
#    'last_updated': 'October 2021',
#    'unsorted_date': '02-10-2021'},
#   {'file_size': '148.65 KB',
#    'filename': 'OCOD_COU_2021_09.zip',
#    'last_updated': 'September 2021',
#    'unsorted_date': '02-09-2021'},
#   {'file_size': '7.91 MB',
#    'filename': 'OCOD_FULL_2021_09.zip',
#    'last_updated': 'September 2021',
#    'unsorted_date': '02-09-2021'},
#   {'file_size': '230.27 KB',
#    'filename': 'OCOD_COU_2021_08.zip',
#    'last_updated': 'August 2021',
#    'unsorted_date': '02-08-2021'},
#   {'file_size': '7.94 MB',
#    'filename': 'OCOD_FULL_2021_08.zip',
#    'last_updated': 'August 2021',
#    'unsorted_date': '02-08-2021'},
#   {'file_size': '189.78 KB',
#    'filename': 'OCOD_COU_2021_07.zip',
#    'last_updated': 'July 2021',
#    'unsorted_date': '02-07-2021'},
#   {'file_size': '7.91 MB',
#    'filename': 'OCOD_FULL_2021_07.zip',
#    'last_updated': 'July 2021',
#    'unsorted_date': '02-07-2021'},
#   {'file_size': '345.06 KB',
#    'filename': 'OCOD_COU_2021_06.zip',
#    'last_updated': 'June 2021',
#    'unsorted_date': '02-06-2021'},
#   {'file_size': '7.97 MB',
#    'filename': 'OCOD_FULL_2021_06.zip',
#    'last_updated': 'June 2021',
#    'unsorted_date': '02-06-2021'},
#   {'file_size': '171.66 KB',
#    'filename': 'OCOD_COU_2021_05.zip',
#    'last_updated': 'May 2021',
#    'unsorted_date': '02-05-2021'},
#   {'file_size': '7.9 MB',
#    'filename': 'OCOD_FULL_2021_05.zip',
#    'last_updated': 'May 2021',
#    'unsorted_date': '02-05-2021'},
#   {'file_size': '203.29 KB',
#    'filename': 'OCOD_COU_2021_04.zip',
#    'last_updated': 'April 2021',
#    'unsorted_date': '02-04-2021'},
#   {'file_size': '8.03 MB',
#    'filename': 'OCOD_FULL_2021_04.zip',
#    'last_updated': 'April 2021',
#    'unsorted_date': '02-04-2021'},
#   {'file_size': '157.26 KB',
#    'filename': 'OCOD_COU_2021_03.zip',
#    'last_updated': 'March 2021',
#    'unsorted_date': '02-03-2021'},
#   {'file_size': '7.93 MB',
#    'filename': 'OCOD_FULL_2021_03.zip',
#    'last_updated': 'March 2021',
#    'unsorted_date': '02-03-2021'},
#   {'file_size': '207.73 KB',
#    'filename': 'OCOD_COU_2021_02.zip',
#    'last_updated': 'February 2021',
#    'unsorted_date': '02-02-2021'},
#   {'file_size': '8.04 MB',
#    'filename': 'OCOD_FULL_2021_02.zip',
#    'last_updated': 'February 2021',
#    'unsorted_date': '02-02-2021'},
#   {'file_size': '265.44 KB',
#    'filename': 'OCOD_COU_2021_01.zip',
#    'last_updated': 'January 2021',
#    'unsorted_date': '02-01-2021'},
#   {'file_size': '7.95 MB',
#    'filename': 'OCOD_FULL_2021_01.zip',
#    'last_updated': 'January 2021',
#    'unsorted_date': '02-01-2021'},
#   {'file_size': '172.41 KB',
#    'filename': 'OCOD_COU_2020_12.zip',
#    'last_updated': 'December 2020',
#    'unsorted_date': '02-12-2020'},
#   {'file_size': '8.07 MB',
#    'filename': 'OCOD_FULL_2020_12.zip',
#    'last_updated': 'December 2020',
#    'unsorted_date': '02-12-2020'},
#   {'file_size': '144.0 KB',
#    'filename': 'OCOD_COU_2020_11.zip',
#    'last_updated': 'November 2020',
#    'unsorted_date': '02-11-2020'},
#   {'file_size': '7.96 MB',
#    'filename': 'OCOD_FULL_2020_11.zip',
#    'last_updated': 'November 2020',
#    'unsorted_date': '02-11-2020'},
#   {'file_size': '137.35 KB',
#    'filename': 'OCOD_COU_2020_10.zip',
#    'last_updated': 'October 2020',
#    'unsorted_date': '02-10-2020'},
#   {'file_size': '8.08 MB',
#    'filename': 'OCOD_FULL_2020_10.zip',
#    'last_updated': 'October 2020',
#    'unsorted_date': '02-10-2020'},
#   {'file_size': '122.8 KB',
#    'filename': 'OCOD_COU_2020_09.zip',
#    'last_updated': 'September 2020',
#    'unsorted_date': '02-09-2020'},
#   {'file_size': '7.98 MB',
#    'filename': 'OCOD_FULL_2020_09.zip',
#    'last_updated': 'September 2020',
#    'unsorted_date': '02-09-2020'},
#   {'file_size': '162.58 KB',
#    'filename': 'OCOD_COU_2020_08.zip',
#    'last_updated': 'August 2020',
#    'unsorted_date': '02-08-2020'},
#   {'file_size': '8.04 MB',
#    'filename': 'OCOD_FULL_2020_08.zip',
#    'last_updated': 'August 2020',
#    'unsorted_date': '02-08-2020'},
#   {'file_size': '188.73 KB',
#    'filename': 'OCOD_COU_2020_07.zip',
#    'last_updated': 'July 2020',
#    'unsorted_date': '02-07-2020'},
#   {'file_size': '7.96 MB',
#    'filename': 'OCOD_FULL_2020_07.zip',
#    'last_updated': 'July 2020',
#    'unsorted_date': '02-07-2020'},
#   {'file_size': '83.61 KB',
#    'filename': 'OCOD_COU_2020_06.zip',
#    'last_updated': 'June 2020',
#    'unsorted_date': '02-06-2020'},
#   {'file_size': '8.11 MB',
#    'filename': 'OCOD_FULL_2020_06.zip',
#    'last_updated': 'June 2020',
#    'unsorted_date': '02-06-2020'},
#   {'file_size': '58.5 KB',
#    'filename': 'OCOD_COU_2020_05.zip',
#    'last_updated': 'May 2020',
#    'unsorted_date': '02-05-2020'},
#   {'file_size': '8.02 MB',
#    'filename': 'OCOD_FULL_2020_05.zip',
#    'last_updated': 'May 2020',
#    'unsorted_date': '02-05-2020'},
#   {'file_size': '147.51 KB',
#    'filename': 'OCOD_COU_2020_04.zip',
#    'last_updated': 'April 2020',
#    'unsorted_date': '02-04-2020'},
#   {'file_size': '8.11 MB',
#    'filename': 'OCOD_FULL_2020_04.zip',
#    'last_updated': 'April 2020',
#    'unsorted_date': '02-04-2020'},
#   {'file_size': '177.97 KB',
#    'filename': 'OCOD_COU_2020_03.zip',
#    'last_updated': 'March 2020',
#    'unsorted_date': '02-03-2020'},
#   {'file_size': '8.05 MB',
#    'filename': 'OCOD_FULL_2020_03.zip',
#    'last_updated': 'March 2020',
#    'unsorted_date': '02-03-2020'},
#   {'file_size': '200.45 KB',
#    'filename': 'OCOD_COU_2020_02.zip',
#    'last_updated': 'February 2020',
#    'unsorted_date': '02-02-2020'},
#   {'file_size': '8.09 MB',
#    'filename': 'OCOD_FULL_2020_02.zip',
#    'last_updated': 'February 2020',
#    'unsorted_date': '02-02-2020'},
#   {'file_size': '161.9 KB',
#    'filename': 'OCOD_COU_2020_01.zip',
#    'last_updated': 'January 2020',
#    'unsorted_date': '02-01-2020'},
#   {'file_size': '8.08 MB',
#    'filename': 'OCOD_FULL_2020_01.zip',
#    'last_updated': 'January 2020',
#    'unsorted_date': '02-01-2020'},
#   {'file_size': '180.71 KB',
#    'filename': 'OCOD_COU_2019_12.zip',
#    'last_updated': 'December 2019',
#    'unsorted_date': '02-12-2019'},
#   {'file_size': '8.11 MB',
#    'filename': 'OCOD_FULL_2019_12.zip',
#    'last_updated': 'December 2019',
#    'unsorted_date': '02-12-2019'},
#   {'file_size': '217.89 KB',
#    'filename': 'OCOD_COU_2019_11.zip',
#    'last_updated': 'November 2019',
#    'unsorted_date': '02-11-2019'},
#   {'file_size': '8.1 MB',
#    'filename': 'OCOD_FULL_2019_11.zip',
#    'last_updated': 'November 2019',
#    'unsorted_date': '02-11-2019'},
#   {'file_size': '235.36 KB',
#    'filename': 'OCOD_COU_2019_10.zip',
#    'last_updated': 'October 2019',
#    'unsorted_date': '02-10-2019'},
#   {'file_size': '8.15 MB',
#    'filename': 'OCOD_FULL_2019_10.zip',
#    'last_updated': 'October 2019',
#    'unsorted_date': '02-10-2019'},
#   {'file_size': '222.54 KB',
#    'filename': 'OCOD_COU_2019_09.zip',
#    'last_updated': 'September 2019',
#    'unsorted_date': '02-09-2019'},
#   {'file_size': '8.09 MB',
#    'filename': 'OCOD_FULL_2019_09.zip',
#    'last_updated': 'September 2019',
#    'unsorted_date': '02-09-2019'},
#   {'file_size': '227.95 KB',
#    'filename': 'OCOD_COU_2019_08.zip',
#    'last_updated': 'August 2019',
#    'unsorted_date': '02-08-2019'},
#   {'file_size': '8.12 MB',
#    'filename': 'OCOD_FULL_2019_08.zip',
#    'last_updated': 'August 2019',
#    'unsorted_date': '02-08-2019'},
#   {'file_size': '389.17 KB',
#    'filename': 'OCOD_COU_2019_07.zip',
#    'last_updated': 'July 2019',
#    'unsorted_date': '02-07-2019'},
#   {'file_size': '8.04 MB',
#    'filename': 'OCOD_FULL_2019_07.zip',
#    'last_updated': 'July 2019',
#    'unsorted_date': '02-07-2019'},
#   {'file_size': '397.64 KB',
#    'filename': 'OCOD_COU_2019_06.zip',
#    'last_updated': 'June 2019',
#    'unsorted_date': '02-06-2019'},
#   {'file_size': '8.16 MB',
#    'filename': 'OCOD_FULL_2019_06.zip',
#    'last_updated': 'June 2019',
#    'unsorted_date': '02-06-2019'},
#   {'file_size': '483.48 KB',
#    'filename': 'OCOD_COU_2019_05.zip',
#    'last_updated': 'May 2019',
#    'unsorted_date': '02-05-2019'},
#   {'file_size': '8.05 MB',
#    'filename': 'OCOD_FULL_2019_05.zip',
#    'last_updated': 'May 2019',
#    'unsorted_date': '02-05-2019'},
#   {'file_size': '213.91 KB',
#    'filename': 'OCOD_COU_2019_04.zip',
#    'last_updated': 'April 2019',
#    'unsorted_date': '02-04-2019'},
#   {'file_size': '8.19 MB',
#    'filename': 'OCOD_FULL_2019_04.zip',
#    'last_updated': 'April 2019',
#    'unsorted_date': '02-04-2019'},
#   {'file_size': '236.66 KB',
#    'filename': 'OCOD_COU_2019_03.zip',
#    'last_updated': 'March 2019',
#    'unsorted_date': '02-03-2019'},
#   {'file_size': '8.08 MB',
#    'filename': 'OCOD_FULL_2019_03.zip',
#    'last_updated': 'March 2019',
#    'unsorted_date': '02-03-2019'},
#   {'file_size': '241.17 KB',
#    'filename': 'OCOD_COU_2019_02.zip',
#    'last_updated': 'February 2019',
#    'unsorted_date': '02-02-2019'},
#   {'file_size': '8.2 MB',
#    'filename': 'OCOD_FULL_2019_02.zip',
#    'last_updated': 'February 2019',
#    'unsorted_date': '02-02-2019'},
#   {'file_size': '171.45 KB',
#    'filename': 'OCOD_COU_2019_01.zip',
#    'last_updated': 'January 2019',
#    'unsorted_date': '02-01-2019'},
#   {'file_size': '8.09 MB',
#    'filename': 'OCOD_FULL_2019_01.zip',
#    'last_updated': 'January 2019',
#    'unsorted_date': '02-01-2019'},
#   {'file_size': '274.13 KB',
#    'filename': 'OCOD_COU_2018_12.zip',
#    'last_updated': 'December 2018',
#    'unsorted_date': '02-12-2018'},
#   {'file_size': '8.21 MB',
#    'filename': 'OCOD_FULL_2018_12.zip',
#    'last_updated': 'December 2018',
#    'unsorted_date': '02-12-2018'},
#   {'file_size': '261.4 KB',
#    'filename': 'OCOD_COU_2018_11.zip',
#    'last_updated': 'November 2018',
#    'unsorted_date': '02-11-2018'},
#   {'file_size': '8.1 MB',
#    'filename': 'OCOD_FULL_2018_11.zip',
#    'last_updated': 'November 2018',
#    'unsorted_date': '02-11-2018'},
#   {'file_size': '259.79 KB',
#    'filename': 'OCOD_COU_2018_10.zip',
#    'last_updated': 'October 2018',
#    'unsorted_date': '02-10-2018'},
#   {'file_size': '8.18 MB',
#    'filename': 'OCOD_FULL_2018_10.zip',
#    'last_updated': 'October 2018',
#    'unsorted_date': '02-10-2018'},
#   {'file_size': '221.47 KB',
#    'filename': 'OCOD_COU_2018_09.zip',
#    'last_updated': 'September 2018',
#    'unsorted_date': '02-09-2018'},
#   {'file_size': '8.07 MB',
#    'filename': 'OCOD_FULL_2018_09.zip',
#    'last_updated': 'September 2018',
#    'unsorted_date': '02-09-2018'},
#   {'file_size': '273.51 KB',
#    'filename': 'OCOD_COU_2018_08.zip',
#    'last_updated': 'August 2018',
#    'unsorted_date': '02-08-2018'},
#   {'file_size': '8.16 MB',
#    'filename': 'OCOD_FULL_2018_08.zip',
#    'last_updated': 'August 2018',
#    'unsorted_date': '02-08-2018'},
#   {'file_size': '239.22 KB',
#    'filename': 'OCOD_COU_2018_07.zip',
#    'last_updated': 'July 2018',
#    'unsorted_date': '02-07-2018'},
#   {'file_size': '8.1 MB',
#    'filename': 'OCOD_FULL_2018_07.zip',
#    'last_updated': 'July 2018',
#    'unsorted_date': '02-07-2018'},
#   {'file_size': '258.96 KB',
#    'filename': 'OCOD_COU_2018_06.zip',
#    'last_updated': 'June 2018',
#    'unsorted_date': '02-06-2018'},
#   {'file_size': '8.18 MB',
#    'filename': 'OCOD_FULL_2018_06.zip',
#    'last_updated': 'June 2018',
#    'unsorted_date': '02-06-2018'},
#   {'file_size': '273.24 KB',
#    'filename': 'OCOD_COU_2018_05.zip',
#    'last_updated': 'May 2018',
#    'unsorted_date': '02-05-2018'},
#   {'file_size': '8.13 MB',
#    'filename': 'OCOD_FULL_2018_05.zip',
#    'last_updated': 'May 2018',
#    'unsorted_date': '02-05-2018'},
#   {'file_size': '346.47 KB',
#    'filename': 'OCOD_COU_2018_04.zip',
#    'last_updated': 'April 2018',
#    'unsorted_date': '02-04-2018'},
#   {'file_size': '8.19 MB',
#    'filename': 'OCOD_FULL_2018_04.zip',
#    'last_updated': 'April 2018',
#    'unsorted_date': '02-04-2018'},
#   {'file_size': '314.38 KB',
#    'filename': 'OCOD_COU_2018_03.zip',
#    'last_updated': 'March 2018',
#    'unsorted_date': '02-03-2018'},
#   {'file_size': '8.17 MB',
#    'filename': 'OCOD_FULL_2018_03.zip',
#    'last_updated': 'March 2018',
#    'unsorted_date': '02-03-2018'},
#   {'file_size': '241.45 KB',
#    'filename': 'OCOD_COU_2018_02.zip',
#    'last_updated': 'February 2018',
#    'unsorted_date': '02-02-2018'},
#   {'file_size': '8.22 MB',
#    'filename': 'OCOD_FULL_2018_02.zip',
#    'last_updated': 'February 2018',
#    'unsorted_date': '02-02-2018'},
#   {'file_size': '260.61 KB',
#    'filename': 'OCOD_COU_2018_01.zip',
#    'last_updated': 'January 2018',
#    'unsorted_date': '02-01-2018'},
#   {'file_size': '8.14 MB',
#    'filename': 'OCOD_FULL_2018_01.zip',
#    'last_updated': 'January 2018',
#    'unsorted_date': '02-01-2018'},
#   {'file_size': '385.69 KB',
#    'filename': 'OCOD_COU_2017_12.zip',
#    'last_updated': 'December 2017',
#    'unsorted_date': '02-12-2017'},
#   {'file_size': '8.18 MB',
#    'filename': 'OCOD_FULL_2017_12.zip',
#    'last_updated': 'December 2017',
#    'unsorted_date': '02-12-2017'},
#   {'file_size': '8.41 MB',
#    'filename': 'OCOD_COU_2017_11.zip',
#    'last_updated': 'November 2017',
#    'unsorted_date': '02-11-2017'},
#   {'file_size': '8.19 MB',
#    'filename': 'OCOD_FULL_2017_11.zip',
#    'last_updated': 'November 2017',
#    'unsorted_date': '02-11-2017'},
#   {'file_size': '7.83 MB',
#    'filename': 'OCOD_FULL_2017_09.zip',
#    'last_updated': 'September 2017',
#    'unsorted_date': '02-09-2017'},
#   {'file_size': '7.92 MB',
#    'filename': 'OCOD_FULL_2017_06.zip',
#    'last_updated': 'June 2017',
#    'unsorted_date': '02-06-2017'},
#   {'file_size': '7.66 MB',
#    'filename': 'OCOD_FULL_2017_03.zip',
#    'last_updated': 'March 2017',
#    'unsorted_date': '02-03-2017'},
#   {'file_size': '7.7 MB',
#    'filename': 'OCOD_FULL_2016_12.zip',
#    'last_updated': 'December 2016',
#    'unsorted_date': '02-12-2016'},
#   {'file_size': '7.63 MB',
#    'filename': 'OCOD_FULL_2016_09.zip',
#    'last_updated': 'September 2016',
#    'unsorted_date': '02-09-2016'},
#   {'file_size': '7.7 MB',
#    'filename': 'OCOD_FULL_2016_06.zip',
#    'last_updated': 'June 2016',
#    'unsorted_date': '02-06-2016'},
#   {'file_size': '7.83 MB',
#    'filename': 'OCOD_FULL_2016_03.zip',
#    'last_updated': 'March 2016',
#    'unsorted_date': '02-03-2016'},
#   {'file_size': '6.14 MB',
#    'filename': 'OCOD_FULL_2015_10.zip',
#    'last_updated': 'October 2015',
#    'unsorted_date': '02-10-2015'}],
#  'success': True}
