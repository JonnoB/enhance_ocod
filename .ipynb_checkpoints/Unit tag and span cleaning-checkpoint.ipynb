# %% [markdown]
# # Unit tag and Span cleaning
#
# This script combines two steps in the OCOD processing pipeline.
#
# * unit tagging
# * Removing overlapping spans
#
# These two processes are separated by the weak labelling in humanloop but as they are relatively simple they are included in a single script
#
# * **Raw CSV loaded and lightly processed. Output**: two column csv columns, property address, unit tag
# * Data labelled in programmatic. Output: json file of entities.
# * **Data programmatic output json cleaned ordered and overlaps removed**. Output: json file
# * Clean json converted to dataframe and multi-addresses expanded. Output: CSV
# * Count and locate addresses
# * Create address matcher and match businesses
# * Classify address types
#
# ## Unit tagging
#
# This park of the pipeline adds in a binary value indicating whether the line contains flats/units/stores etc which are likely to have unit level ID. This is important as such addresses are likely to have a unit ID AND an street number and as such need to be treated with care

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
import pandas as pd
import numpy as np
import re
import random
from helper_functions import *
# Out:
# <style>.container { width:90% !important; }</style>

# %%
ocod_data =  pd.read_csv('/tf/empty_homes_data/' +
                    'OCOD_FULL_2022_02.csv',
                   encoding_errors= 'ignore').rename(columns = lambda x: x.lower().replace(" ", "_"))
ocod_data['postcode'] = ocod_data['postcode'].str.upper()
#empty addresses cannot be used. however there are only three so not a problem
ocod_data = ocod_data.dropna(subset = 'property_address')
ocod_data.reset_index(inplace = True, drop = True)
ocod_data['property_address'] = ocod_data['property_address'].str.lower()

#different words associated with unit ID's
flatregex = r"(flat|apartment|penthouse|unit)" #unit|store|storage these a

#This is not an exhaustive list of road names but it covers about 80% of all road types in the VOA business register.
#The cardinal directions are includted as an option as they can appear after the road type. However they serve no real purpose in this particular regex and are 
#included for completness
road_regex  = r"((road|street|lane|way|gate|avenue|close|drive|hill|place|terrace|crescent|gardens|square|walk|grove|mews|row|view|boulevard|pleasant|vale|yard|chase|rise|green|passage|friars|viaduct|promenade|end|ridge|embankment|villas|circus))\b( east| west| north| south)?"
#These names may be followed by a road type e.g. Earls court road. A negative lookahead is used to prevent these roads being tagged as units.
flatregex2 = r"(mansions|villa|court)\b(?!(\s"+road_regex+"))"

#flat_tag is used for legacy reasons but refers to sub-units in general
ocod_data['flat_tag'] = ocod_data['property_address'].str.contains(flatregex + '|'+flatregex2, case = False)

ocod_data['commercial_park_tag'] = ocod_data['property_address'].str.contains(r"(retail|industrial|commercial|business|distribution|car)", case = False)

#typo in the data leads to a large number of fake flats
ocod_data.loc[:, 'property_address'] = ocod_data['property_address'].str.replace("stanley court ", "stanley court, ")

#only two columns are needed for the humanloop labelling process
ocod_data[['property_address', 'flat_tag', 'commercial_park_tag', 'title_number']].rename(columns = {'property_address':'text'}).to_csv('/tf/empty_homes_data/property_address_only.csv')
# Out:
# <ipython-input-2-8e8d903289a6>:1: DtypeWarning: Columns (24,28,30,32,33,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   ocod_data =  pd.read_csv('/tf/empty_homes_data/' +
# <ipython-input-2-8e8d903289a6>:21: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   ocod_data['flat_tag'] = ocod_data['property_address'].str.contains(flatregex + '|'+flatregex2, case = False)
# <ipython-input-2-8e8d903289a6>:23: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   ocod_data['commercial_park_tag'] = ocod_data['property_address'].str.contains(r"(retail|industrial|commercial|business|distribution|car)", case = False)

# %%
#Create the index for the ground truth
random.seed(2017)
test_set = random.sample([*range(0, ocod_data.shape[0])], 1000) 

test_set = ocod_data.loc[test_set, 'title_number'].reset_index().rename(columns = {'index':'datapoint_id'})

test_set.to_csv('/tf/empty_homes_data/test_set_indices.csv')

# %% [markdown]
# ## Labelling in Humanloop
#
# This part of process uses the humanloop programmatic app and is an external process. Once the labelling step is complete the process outputs a json file containing the labels and spans, this is then cleaned in the next step.
#
# ## Removing overlapping spans
#
# During the humanloop tagging process the rules may result in the same words being tagged as part of multiple spans, this often occures for road names made up of multiple parts
# e.g. Canberra Crescent Gardens may be tagges as Canberra Cresecent and Canberra Crescent Gardens. The overlaps need to be removed before further prcoessing.
# For simplicity the largest span of any two overlapping spans is kept and the smaller of the two is removed.

# %%
#These libraries are specific to this part of the process
import json
import requests 
import config #contains hidden api key
import operator #used for sorting the label dictionaries by start point. This is the basis for removing overlaps

# %%
# Opening JSON file
f =open("/tf/empty_homes_data/humanloop_11_04_22_t0915.json")  #aggregate and download button

# returns JSON object as 
# a dictionary
data = json.load(f)

#this makes a list of all the observation rows. These refer to the row of the orginal observation text and so can be linked back to the original OCOD dataset.

# %%
datapoint_id_list = [*range(0,len(data['datapoints']))]

data_and_labels = []
data_labels_dict = []

count_it = 0
for i in set(datapoint_id_list):

    count_it += 1
    if count_it % 100 == 0: 
        print('count = {}'.format(count_it))
        
    #single_id_index = np.where(np.array(datapoint_id_list)==i)
    ##these labels are in tuple form
   # list_of_labels = [(data[x]['start'], data[x]['end'], data[x]['label']) for x in single_id_index[0].tolist()]
    list_of_labels_dict = results_list = data['datapoints'][i]['programmatic']['results']
    ##these labels are in dictionary form
#     list_of_labels_dict = [{'start': x['start'], 
#                             'end':x['end'], 
#                             'label': x['label'], 
#                             'label_text': x['text'] } for x in results_list]
    
    #this inplace sorting using operator orders the dictionary by the start point. ties are automatically broken
    #it required the operator library
    list_of_labels_dict.sort(key=operator.itemgetter('start'))
    
    list_of_labels_dict = remove_overlapping_spans2(list_of_labels_dict)

    #create the NER dataset structure shown on the spacy website
   # data_and_labels = data_and_labels + [ ( ocod_data['property_address'][i], list_of_labels ) ]
    #create a list of dictionaries using a similar structure to save as a json
    data_labels_dict = data_labels_dict + [
        {
            'text' : ocod_data['property_address'][i],
            'labels' : list_of_labels_dict,
            'datapoint_id': i,
            'title_number':ocod_data['title_number'][i]
        }
    ]
    
#Save the cleaned data back as a json file ready to be processed further  
with open('/tf/empty_homes_data/full_dataset_no_overlaps.json', 'w') as f:
    json.dump(data_labels_dict, f)
# Out:
# count = 100
# count = 200
# count = 300
# count = 400
# count = 500
# count = 600
# count = 700
# count = 800
# count = 900
# count = 1000
# count = 1100
# count = 1200
# count = 1300
# count = 1400
# count = 1500
# count = 1600
# count = 1700
# count = 1800
# count = 1900
# count = 2000
# count = 2100
# count = 2200
# count = 2300
# count = 2400
# count = 2500
# count = 2600
# count = 2700
# count = 2800
# count = 2900
# count = 3000
# count = 3100
# count = 89600
# count = 89700
# count = 89800
# count = 89900
# count = 90000
# count = 90100
# count = 90200
# count = 90300
# count = 90400
# count = 90500
# count = 90600
# count = 90700
# count = 90800
# count = 90900
# count = 91000
# count = 91100
# count = 91200
# count = 91300
# count = 91400
# count = 91500
# count = 91600
# count = 91700
# count = 91800
# count = 91900
# count = 92000
# count = 92100
# count = 92200
# count = 92300
# count = 92400
# count = 92500
# count = 92600
# count = 92700
# count = 92800
# count = 92900
# count = 93000
# count = 93100
# count = 93200
# count = 93300
# count = 93400
# count = 93500
# count = 93600
# count = 93700
# count = 93800
# count = 93900
# count = 94000

# %% [markdown]
# ### Uploading to humanloop cloud
#
# This allows a sample of the data to be uploaded to the humanloop cloud so that an example model can be made.
# The model provides another way to check the quality of the weak labelling. However, only 10k obersvations can be uploaded, as such a sub-sample is used.

# %%
jason_test_data ={
     "name": "test_set_24_04_22",
     "description": "the ground truth test set for labelling",
     "fields": [
         {"name": "text", 
          "data_type": "text"
         },
         {"name": "labels", 
          "data_type": "character_offsets"},
         {"name": "datapoint_id", 
          "data_type": "text"
         }
     ],
     "data": [data_labels_dict[x] for x in test_set.loc[:,'datapoint_id']]#, #upload only data from the test set
   # "complete":False
}

#url = "https://api.humanloop.com/datasets"
url = "https://api.humanloop.com/projects/1369/add-tasks"
# replace payload with your actual dataset...
payload= json.dumps(jason_test_data)
headers = {
  'X-API-Key': config.api_key,#the api key is hidden in a config file
  'Content-Type': 'application/json'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"detail":{"loc":["data"],"msg":"The following fields were specified but did not exist in your dataset: span_tagging","description":"The following fields were specified but did not exist in your dataset: span_tagging","type":"value_error"}}

# %%
# Out:
# {'name': 'test_set_24_04_22',
#  'description': 'the ground truth test set for labelling',
#  'fields': [{'name': 'text', 'data_type': 'text'},
#   {'name': 'labels', 'data_type': 'character_offsets'},
#   {'name': 'datapoint_id', 'data_type': 'text'}],
#  'data': [{'text': 'land on the south-east side of folly lane, east cowes',
#    'labels': [{'start': 0,
#      'end': 4,
#      'text': 'land',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 14,
#      'groundTruthId': None},
#     {'start': 31,
#      'end': 41,
#      'text': 'folly lane',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 48,
#      'end': 53,
#      'text': 'cowes',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 13,
#      'groundTruthId': None}],
#    'datapoint_id': 26104,
#    'title_number': 'IW82373'},
#   {'text': '3 hyde park square mews, london',
#    'labels': [{'start': 0,
#      'end': 1,
#      'text': '3',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 6,
#      'groundTruthId': None},
#     {'start': 2,
#      'end': 23,
#      'text': 'hyde park square mews',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 25,
#      'end': 31,
#      'text': 'london',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 13,
#      'groundTruthId': None}],
#    'datapoint_id': 58310,
#    'title_number': 'LN48410'},
#   {'text': '300 sheffield road, birdwell, barnsley (s70 5tg)',
#    'labels': [{'start': 0,
#      'end': 3,
#      'text': '300',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 6,
#      'groundTruthId': None},
#     {'start': 4,
#      'end': 18,
#      'text': 'sheffield road',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 30,
#      'end': 39,
#      'text': 'barnsley ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 40,
#      'end': 47,
#      'text': 's70 5tg',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 44963,
#    'title_number': 'SYK569894'},
#   {'text': 'car parking space 5, 45 millharbour, london (e14 9tr)',
#    'labels': [{'start': 0,
#      'end': 17,
#      'text': 'car parking space',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 16,
#      'groundTruthId': None},
#     {'start': 21,
#      'end': 23,
#      'text': '45',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 9,
#      'groundTruthId': None},
#     {'start': 24,
#      'end': 35,
#      'text': 'millharbour',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 59,
#      'groundTruthId': None},
#     {'start': 37,
#      'end': 44,
#      'text': 'london ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 45,
#      'end': 52,
#      'text': 'e14 9tr',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 42099,
#    'title_number': 'AGL450542'},
#   {'text': '148 kensington park road, london (w11 2ep)',
#    'labels': [{'start': 0,
#      'end': 3,
#      'text': '148',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 6,
#      'groundTruthId': None},
#     {'start': 4,
#      'end': 24,
#      'text': 'kensington park road',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 26,
#      'end': 33,
#      'text': 'london ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 34,
#      'end': 41,
#      'text': 'w11 2ep',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 66945,
#    'title_number': 'NGL238009'},
#   {'text': 'flat 6, cavendish court 52-54 hadlow road, tonbridge (tn9 1nz)',
#    'labels': [{'start': 0,
#      'end': 4,
#      'text': 'flat',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 18,
#      'groundTruthId': None},
#     {'start': 24,
#      'end': 29,
#      'text': '52-54',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 7,
#      'groundTruthId': None},
#     {'start': 30,
#      'end': 41,
#      'text': 'hadlow road',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 43,
#      'end': 53,
#      'text': 'tonbridge ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 54,
#      'end': 61,
#      'text': 'tn9 1nz',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 27428,
#    'title_number': 'K881389'},
#   {'text': '60 lysia street, london (sw6 6ng)',
#    'labels': [{'start': 0,
#      'end': 2,
#      'text': '60',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 6,
#      'groundTruthId': None},
#     {'start': 3,
#      'end': 15,
#      'text': 'lysia street',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 17,
#      'end': 24,
#      'text': 'london ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 25,
#      'end': 32,
#      'text': 'sw6 6ng',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 8726,
#    'title_number': 'LN227153'},
#   {'text': 'apartment 209, 9 woden street, salford (m5 4yg)',
#    'labels': [{'start': 0,
#      'end': 9,
#      'text': 'apartment',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 18,
#      'groundTruthId': None},
#     {'start': 10,
#      'end': 13,
#      'text': '209',
#      'labelId': '14',
#      'label': 'unit_id',
#      'labellingFunctionId': 47,
#      'groundTruthId': None},
#     {'start': 15,
#      'end': 16,
#      'text': '9',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 9,
#      'groundTruthId': None},
#     {'start': 17,
#      'end': 29,
#      'text': 'woden street',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 31,
#      'end': 39,
#      'text': 'salford ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 40,
#      'end': 46,
#      'text': 'm5 4yg',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 67227,
#    'title_number': 'MAN369162'},
#   {'text': 'flat 49a, albert hall mansions, kensington gore, london (sw7 2ag)',
#    'labels': [{'start': 0,
#      'end': 4,
#      'text': 'flat',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 18,
#      'groundTruthId': None},
#     {'start': 5,
#      'end': 8,
#      'text': '49a',
#      'labelId': '14',
#      'label': 'unit_id',
#      'labellingFunctionId': 50,
#      'groundTruthId': None},
#     {'start': 10,
#      'end': 30,
#      'text': 'albert hall mansions',
#      'labelId': '10',
#      'label': 'building_name',
#      'labellingFunctionId': 34,
#      'groundTruthId': None},
#     {'start': 49,
#      'end': 56,
#      'text': 'london ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 57,
#      'end': 64,
#      'text': 'sw7 2ag',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 60086,
#    'title_number': 'NGL978701'},
#   {'text': 'flat 9, 7 elm park',
#    'labels': [{'start': 0,
#      'end': 4,
#      'text': 'flat',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 18,
#      'groundTruthId': None},
#     {'start': 9,
#      'end': 18,
#      'text': ' elm park',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 60,
#      'groundTruthId': None}],
#    'datapoint_id': 70106,
#    'title_number': 'NGL417191'},
#   {'text': 'land on the north of hallens drive, wednesbury',
#    'labels': [{'start': 0,
#      'end': 4,
#      'text': 'land',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 14,
#      'groundTruthId': None},
#     {'start': 21,
#      'end': 34,
#      'text': 'hallens drive',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 36,
#      'end': 46,
#      'text': 'wednesbury',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 13,
#      'groundTruthId': None}],
#    'datapoint_id': 15095,
#    'title_number': 'WM801424'},
#   {'text': '15 sprimont place, london (sw3 3ht)',
#    'labels': [{'start': 0,
#      'end': 2,
#      'text': '15',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 6,
#      'groundTruthId': None},
#     {'start': 3,
#      'end': 17,
#      'text': 'sprimont place',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 19,
#      'end': 26,
#      'text': 'london ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 27,
#      'end': 34,
#      'text': 'sw3 3ht',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 31263,
#    'title_number': 'NGL648690'},
#   {'text': '46 pen y lan road, cardiff (cf24 3pf)',
#    'labels': [{'start': 0,
#      'end': 2,
#      'text': '46',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 6,
#      'groundTruthId': None},
#     {'start': 3,
#      'end': 17,
#      'text': 'pen y lan road',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 19,
#      'end': 27,
#      'text': 'cardiff ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 28,
#      'end': 36,
#      'text': 'cf24 3pf',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 78749,
#    'title_number': 'WA901648'},
#   {'text': '5c cornelia street, london (n7 8ba)',
#    'labels': [{'start': 0,
#      'end': 2,
#      'text': '5c',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 6,
#      'groundTruthId': None},
#     {'start': 3,
#      'end': 18,
#      'text': 'cornelia street',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 20,
#      'end': 27,
#      'text': 'london ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 28,
#      'end': 34,
#      'text': 'n7 8ba',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 51211,
#    'title_number': 'EGL565084'},
#   {'text': '11 homelawn house, brookfield road, bexhill-on-sea (tn40 1pn)',
#    'labels': [{'start': 0,
#      'end': 2,
#      'text': '11',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 6,
#      'groundTruthId': None},
#     {'start': 3,
#      'end': 17,
#      'text': 'homelawn house',
#      'labelId': '10',
#      'label': 'building_name',
#      'labellingFunctionId': 30,
#      'groundTruthId': None},
#     {'start': 19,
#      'end': 34,
#      'text': 'brookfield road',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 52,
#      'end': 60,
#      'text': 'tn40 1pn',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 69065,
#    'title_number': 'ESX139376'},
#   {'text': "roof space, 8 d'arblay street, (w1f 8dp)",
#    'labels': [{'start': 0,
#      'end': 10,
#      'text': 'roof space',
#      'labelId': '10',
#      'label': 'building_name',
#      'labellingFunctionId': 77,
#      'groundTruthId': None},
#     {'start': 12,
#      'end': 13,
#      'text': '8',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 9,
#      'groundTruthId': None},
#     {'start': 14,
#      'end': 29,
#      'text': "d'arblay street",
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 32,
#      'end': 39,
#      'text': 'w1f 8dp',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 88368,
#    'title_number': 'NGL807866'},
#   {'text': 'flat 9, 6 charles street, london (w1j 5dg)',
#    'labels': [{'start': 0,
#      'end': 4,
#      'text': 'flat',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 18,
#      'groundTruthId': None},
#     {'start': 8,
#      'end': 9,
#      'text': '6',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 9,
#      'groundTruthId': None},
#     {'start': 10,
#      'end': 24,
#      'text': 'charles street',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 26,
#      'end': 33,
#      'text': 'london ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 34,
#      'end': 41,
#      'text': 'w1j 5dg',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 31767,
#    'title_number': 'NGL791005'},
#   {'text': 'flats 1 to 10, the briar, 43 thicket road, sutton (sm1 4qy) and storage area',
#    'labels': [{'start': 6,
#      'end': 13,
#      'text': '1 to 10',
#      'labelId': '14',
#      'label': 'unit_id',
#      'labellingFunctionId': 39,
#      'groundTruthId': None},
#     {'start': 26,
#      'end': 28,
#      'text': '43',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 9,
#      'groundTruthId': None},
#     {'start': 29,
#      'end': 41,
#      'text': 'thicket road',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 43,
#      'end': 50,
#      'text': 'sutton ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 51,
#      'end': 58,
#      'text': 'sm1 4qy',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None},
#     {'start': 64,
#      'end': 71,
#      'text': 'storage',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 76,
#      'groundTruthId': None},
#     {'start': 72,
#      'end': 76,
#      'text': 'area',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 13,
#      'groundTruthId': None}],
#    'datapoint_id': 844,
#    'title_number': 'SGL640152'},
#   {'text': 'the first floor apartment 34 wharfside, heritage way, wigan (wn3 4at)',
#    'labels': [{'start': 16,
#      'end': 25,
#      'text': 'apartment',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 18,
#      'groundTruthId': None},
#     {'start': 26,
#      'end': 28,
#      'text': '34',
#      'labelId': '14',
#      'label': 'unit_id',
#      'labellingFunctionId': 47,
#      'groundTruthId': None},
#     {'start': 40,
#      'end': 52,
#      'text': 'heritage way',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 54,
#      'end': 60,
#      'text': 'wigan ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 61,
#      'end': 68,
#      'text': 'wn3 4at',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 10563,
#    'title_number': 'MAN93764'},
#   {'text': 'flat 11, 43 lowndes square, chelsea, (sw1x 9jl)',
#    'labels': [{'start': 0,
#      'end': 4,
#      'text': 'flat',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 18,
#      'groundTruthId': None},
#     {'start': 9,
#      'end': 11,
#      'text': '43',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 9,
#      'groundTruthId': None},
#     {'start': 12,
#      'end': 26,
#      'text': 'lowndes square',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 38,
#      'end': 46,
#      'text': 'sw1x 9jl',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 35064,
#    'title_number': 'BGL30101'},
#   {'text': '52 bourne street, london (sw1w 8jd)',
#    'labels': [{'start': 0,
#      'end': 2,
#      'text': '52',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 6,
#      'groundTruthId': None},
#     {'start': 3,
#      'end': 16,
#      'text': 'bourne street',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 18,
#      'end': 25,
#      'text': 'london ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 26,
#      'end': 34,
#      'text': 'sw1w 8jd',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 32046,
#    'title_number': 'NGL840117'},
#   {'text': 'apartment 54, orion, 9 the boardwalk, brighton marina village, brighton (bn2 5zd)',
#    'labels': [{'start': 0,
#      'end': 9,
#      'text': 'apartment',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 18,
#      'groundTruthId': None},
#     {'start': 10,
#      'end': 12,
#      'text': '54',
#      'labelId': '14',
#      'label': 'unit_id',
#      'labellingFunctionId': 47,
#      'groundTruthId': None},
#     {'start': 21,
#      'end': 22,
#      'text': '9',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 9,
#      'groundTruthId': None},
#     {'start': 23,
#      'end': 36,
#      'text': 'the boardwalk',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 63,
#      'end': 72,
#      'text': 'brighton ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 73,
#      'end': 80,
#      'text': 'bn2 5zd',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 18660,
#    'title_number': 'ESX377363'},
#   {'text': 'apartment 27.03, 26 hertsmere road, london and parking space 74 (e14 4ef)',
#    'labels': [{'start': 0,
#      'end': 9,
#      'text': 'apartment',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 18,
#      'groundTruthId': None},
#     {'start': 10,
#      'end': 15,
#      'text': '27.03',
#      'labelId': '14',
#      'label': 'unit_id',
#      'labellingFunctionId': 72,
#      'groundTruthId': None},
#     {'start': 17,
#      'end': 19,
#      'text': '26',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 9,
#      'groundTruthId': None},
#     {'start': 20,
#      'end': 34,
#      'text': 'hertsmere road',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 47,
#      'end': 60,
#      'text': 'parking space',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 75,
#      'groundTruthId': None},
#     {'start': 65,
#      'end': 72,
#      'text': 'e14 4ef',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 25151,
#    'title_number': 'EGL497158'},
#   {'text': "9 wellington mansions, queen's club gardens, london (w14 9tf)",
#    'labels': [{'start': 2,
#      'end': 21,
#      'text': 'wellington mansions',
#      'labelId': '10',
#      'label': 'building_name',
#      'labellingFunctionId': 34,
#      'groundTruthId': None},
#     {'start': 23,
#      'end': 43,
#      'text': "queen's club gardens",
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 45,
#      'end': 52,
#      'text': 'london ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 53,
#      'end': 60,
#      'text': 'w14 9tf',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 17946,
#    'title_number': 'BGL10451'},
#   {'text': 'land at hambleden',
#    'labels': [{'start': 0,
#      'end': 4,
#      'text': 'land',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 14,
#      'groundTruthId': None},
#     {'start': 8,
#      'end': 17,
#      'text': 'hambleden',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 13,
#      'groundTruthId': None}],
#    'datapoint_id': 36153,
#    'title_number': 'BM212011'},
#   {'text': '42 and 46 clerkenwell close, london (ec1r 0az)',
#    'labels': [{'start': 0,
#      'end': 2,
#      'text': '42',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 6,
#      'groundTruthId': None},
#     {'start': 7,
#      'end': 9,
#      'text': '46',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 4,
#      'groundTruthId': None},
#     {'start': 10,
#      'end': 27,
#      'text': 'clerkenwell close',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 29,
#      'end': 36,
#      'text': 'london ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 37,
#      'end': 45,
#      'text': 'ec1r 0az',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 30669,
#    'title_number': 'NGL733286'},
#   {'text': 'flat 11, goldhawk house, 10 beaufort square, london (nw9 5sq)',
#    'labels': [{'start': 0,
#      'end': 4,
#      'text': 'flat',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 18,
#      'groundTruthId': None},
#     {'start': 9,
#      'end': 23,
#      'text': 'goldhawk house',
#      'labelId': '10',
#      'label': 'building_name',
#      'labellingFunctionId': 30,
#      'groundTruthId': None},
#     {'start': 25,
#      'end': 27,
#      'text': '10',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 9,
#      'groundTruthId': None},
#     {'start': 28,
#      'end': 43,
#      'text': 'beaufort square',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 45,
#      'end': 52,
#      'text': 'london ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 53,
#      'end': 60,
#      'text': 'nw9 5sq',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 92541,
#    'title_number': 'AGL397939'},
#   {'text': '33 northampton road, blisworth, northampton (nn7 3dw)',
#    'labels': [{'start': 0,
#      'end': 2,
#      'text': '33',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 6,
#      'groundTruthId': None},
#     {'start': 3,
#      'end': 19,
#      'text': 'northampton road',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 32,
#      'end': 44,
#      'text': 'northampton ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 45,
#      'end': 52,
#      'text': 'nn7 3dw',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 68315,
#    'title_number': 'NN318073'},
#   {'text': 'flat 2, 34 lennox gardens, london (sw1x 0dh)',
#    'labels': [{'start': 0,
#      'end': 4,
#      'text': 'flat',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 18,
#      'groundTruthId': None},
#     {'start': 8,
#      'end': 10,
#      'text': '34',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 9,
#      'groundTruthId': None},
#     {'start': 11,
#      'end': 25,
#      'text': 'lennox gardens',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 27,
#      'end': 34,
#      'text': 'london ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 35,
#      'end': 43,
#      'text': 'sw1x 0dh',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 85601,
#    'title_number': 'BGL72175'},
#   {'text': 'room 1539, park plaza westminster bridge, 200 westminster bridge road, london (se1 7ut)',
#    'labels': [{'start': 0,
#      'end': 4,
#      'text': 'room',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 17,
#      'groundTruthId': None},
#     {'start': 5,
#      'end': 9,
#      'text': '1539',
#      'labelId': '14',
#      'label': 'unit_id',
#      'labellingFunctionId': 38,
#      'groundTruthId': None},
#     {'start': 11,
#      'end': 40,
#      'text': 'park plaza westminster bridge',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 42,
#      'end': 45,
#      'text': '200',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 9,
#      'groundTruthId': None},
#     {'start': 46,
#      'end': 69,
#      'text': 'westminster bridge road',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 71,
#      'end': 78,
#      'text': 'london ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 79,
#      'end': 86,
#      'text': 'se1 7ut',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 65754,
#    'title_number': 'TGL349123'},
#   {'text': 'land and buildings lying to the north west of quarry lane, chichester (po19 8pa)',
#    'labels': [{'start': 0,
#      'end': 4,
#      'text': 'land',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 14,
#      'groundTruthId': None},
#     {'start': 46,
#      'end': 57,
#      'text': 'quarry lane',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 59,
#      'end': 70,
#      'text': 'chichester ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 71,
#      'end': 79,
#      'text': 'po19 8pa',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 51167,
#    'title_number': 'WSX294786'},
#   {'text': "flat 93, boydell court, st john's wood park, hampstead,  london (nw8 6nh)",
#    'labels': [{'start': 0,
#      'end': 4,
#      'text': 'flat',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 18,
#      'groundTruthId': None},
#     {'start': 9,
#      'end': 22,
#      'text': 'boydell court',
#      'labelId': '10',
#      'label': 'building_name',
#      'labellingFunctionId': 32,
#      'groundTruthId': None},
#     {'start': 24,
#      'end': 43,
#      'text': "st john's wood park",
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 60,
#      'groundTruthId': None},
#     {'start': 56,
#      'end': 64,
#      'text': ' london ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 65,
#      'end': 72,
#      'text': 'nw8 6nh',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 72197,
#    'title_number': 'NGL773175'},
#   {'text': 'part of quadrant house, 55, 56, 57 and 58 pall mall and 2, 3, 4 and 5 crown passage, london',
#    'labels': [{'start': 0,
#      'end': 22,
#      'text': 'part of quadrant house',
#      'labelId': '10',
#      'label': 'building_name',
#      'labellingFunctionId': 77,
#      'groundTruthId': None},
#     {'start': 24,
#      'end': 26,
#      'text': '55',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 8,
#      'groundTruthId': None},
#     {'start': 28,
#      'end': 30,
#      'text': '56',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 8,
#      'groundTruthId': None},
#     {'start': 32,
#      'end': 34,
#      'text': '57',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 9,
#      'groundTruthId': None},
#     {'start': 39,
#      'end': 41,
#      'text': '58',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 4,
#      'groundTruthId': None},
#     {'start': 42,
#      'end': 51,
#      'text': 'pall mall',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 59,
#      'groundTruthId': None},
#     {'start': 56,
#      'end': 57,
#      'text': '2',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 4,
#      'groundTruthId': None},
#     {'start': 59,
#      'end': 60,
#      'text': '3',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 8,
#      'groundTruthId': None},
#     {'start': 62,
#      'end': 63,
#      'text': '4',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 9,
#      'groundTruthId': None},
#     {'start': 68,
#      'end': 69,
#      'text': '5',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 4,
#      'groundTruthId': None},
#     {'start': 70,
#      'end': 83,
#      'text': 'crown passage',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 85,
#      'end': 91,
#      'text': 'london',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 13,
#      'groundTruthId': None}],
#    'datapoint_id': 77313,
#    'title_number': 'LN210818'},
#   {'text': 'part of level 6 and being flat 65, 9 queensland road, london (n7 7fh)',
#    'labels': [{'start': 14,
#      'end': 15,
#      'text': '6',
#      'labelId': '14',
#      'label': 'unit_id',
#      'labellingFunctionId': 44,
#      'groundTruthId': None},
#     {'start': 26,
#      'end': 30,
#      'text': 'flat',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 18,
#      'groundTruthId': None},
#     {'start': 35,
#      'end': 36,
#      'text': '9',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 9,
#      'groundTruthId': None},
#     {'start': 37,
#      'end': 52,
#      'text': 'queensland road',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 54,
#      'end': 61,
#      'text': 'london ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 62,
#      'end': 68,
#      'text': 'n7 7fh',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 14188,
#    'title_number': 'AGL334510'},
#   {'text': '355 london road, westcliff-on-sea (ss0 7ht)',
#    'labels': [{'start': 0,
#      'end': 3,
#      'text': '355',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 6,
#      'groundTruthId': None},
#     {'start': 4,
#      'end': 15,
#      'text': 'london road',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 35,
#      'end': 42,
#      'text': 'ss0 7ht',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 39695,
#    'title_number': 'EX364569'},
#   {'text': '43 and 43b sandford lane, kennington, oxford (ox1 5rw)',
#    'labels': [{'start': 0,
#      'end': 2,
#      'text': '43',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 6,
#      'groundTruthId': None},
#     {'start': 11,
#      'end': 24,
#      'text': 'sandford lane',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 38,
#      'end': 45,
#      'text': 'oxford ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 46,
#      'end': 53,
#      'text': 'ox1 5rw',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 28748,
#    'title_number': 'ON44714'},
#   {'text': 'unit 28, kernick industrial estate, parkengue, kernick, penryn (tr10 9ep)',
#    'labels': [{'start': 0,
#      'end': 4,
#      'text': 'unit',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 14,
#      'groundTruthId': None},
#     {'start': 5,
#      'end': 7,
#      'text': '28',
#      'labelId': '14',
#      'label': 'unit_id',
#      'labellingFunctionId': 48,
#      'groundTruthId': None},
#     {'start': 56,
#      'end': 63,
#      'text': 'penryn ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 64,
#      'end': 72,
#      'text': 'tr10 9ep',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 89464,
#    'title_number': 'CL356637'},
#   {'text': 'unit a, gas street, birmingham',
#    'labels': [{'start': 0,
#      'end': 6,
#      'text': 'unit a',
#      'labelId': '10',
#      'label': 'building_name',
#      'labellingFunctionId': 77,
#      'groundTruthId': None},
#     {'start': 8,
#      'end': 18,
#      'text': 'gas street',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 20,
#      'end': 30,
#      'text': 'birmingham',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 13,
#      'groundTruthId': None}],
#    'datapoint_id': 92748,
#    'title_number': 'WM753989'},
#   {'text': 'land on the east side of commercial road, goldthorpe, rotherham',
#    'labels': [{'start': 0,
#      'end': 4,
#      'text': 'land',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 14,
#      'groundTruthId': None},
#     {'start': 25,
#      'end': 40,
#      'text': 'commercial road',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 54,
#      'end': 63,
#      'text': 'rotherham',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 13,
#      'groundTruthId': None}],
#    'datapoint_id': 64268,
#    'title_number': 'SYK526026'},
#   {'text': 'apartment 30, 52 bedford road, london (sw4 7hj)',
#    'labels': [{'start': 0,
#      'end': 9,
#      'text': 'apartment',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 18,
#      'groundTruthId': None},
#     {'start': 10,
#      'end': 12,
#      'text': '30',
#      'labelId': '14',
#      'label': 'unit_id',
#      'labellingFunctionId': 47,
#      'groundTruthId': None},
#     {'start': 14,
#      'end': 16,
#      'text': '52',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 9,
#      'groundTruthId': None},
#     {'start': 17,
#      'end': 29,
#      'text': 'bedford road',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 31,
#      'end': 38,
#      'text': 'london ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 39,
#      'end': 46,
#      'text': 'sw4 7hj',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 66415,
#    'title_number': 'TGL458237'},
#   {'text': '8a and 9a greenhill parade, great north road',
#    'labels': [{'start': 0,
#      'end': 2,
#      'text': '8a',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 6,
#      'groundTruthId': None},
#     {'start': 28,
#      'end': 44,
#      'text': 'great north road',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None}],
#    'datapoint_id': 68792,
#    'title_number': 'NGL528392'},
#   {'text': 'units 9 and 13, 20-30 wilds rents, london (se1 4qg)',
#    'labels': [{'start': 0,
#      'end': 4,
#      'text': 'unit',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 14,
#      'groundTruthId': None},
#     {'start': 6,
#      'end': 7,
#      'text': '9',
#      'labelId': '14',
#      'label': 'unit_id',
#      'labellingFunctionId': 44,
#      'groundTruthId': None},
#     {'start': 12,
#      'end': 14,
#      'text': '13',
#      'labelId': '14',
#      'label': 'unit_id',
#      'labellingFunctionId': 52,
#      'groundTruthId': None},
#     {'start': 16,
#      'end': 21,
#      'text': '20-30',
#      'labelId': '14',
#      'label': 'unit_id',
#      'labellingFunctionId': 39,
#      'groundTruthId': None},
#     {'start': 35,
#      'end': 42,
#      'text': 'london ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 43,
#      'end': 50,
#      'text': 'se1 4qg',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 46171,
#    'title_number': 'TGL197999'},
#   {'text': 'hewitts farm, hewitts road, chelsfield, (br6 7qr)',
#    'labels': [{'start': 0,
#      'end': 12,
#      'text': 'hewitts farm',
#      'labelId': '10',
#      'label': 'building_name',
#      'labellingFunctionId': 77,
#      'groundTruthId': None},
#     {'start': 14,
#      'end': 26,
#      'text': 'hewitts road',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 41,
#      'end': 48,
#      'text': 'br6 7qr',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 92052,
#    'title_number': 'SGL430299'},
#   {'text': '55 cadogan place and 60 cadogan lane, london',
#    'labels': [{'start': 0,
#      'end': 2,
#      'text': '55',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 6,
#      'groundTruthId': None},
#     {'start': 3,
#      'end': 16,
#      'text': 'cadogan place',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 21,
#      'end': 23,
#      'text': '60',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 4,
#      'groundTruthId': None},
#     {'start': 24,
#      'end': 36,
#      'text': 'cadogan lane',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 38,
#      'end': 44,
#      'text': 'london',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 13,
#      'groundTruthId': None}],
#    'datapoint_id': 38293,
#    'title_number': 'BGL47658'},
#   {'text': '18 beresford court, park road, twickenham (tw1 2pu)',
#    'labels': [{'start': 0,
#      'end': 2,
#      'text': '18',
#      'labelId': '14',
#      'label': 'unit_id',
#      'labellingFunctionId': 43,
#      'groundTruthId': None},
#     {'start': 3,
#      'end': 18,
#      'text': 'beresford court',
#      'labelId': '10',
#      'label': 'building_name',
#      'labellingFunctionId': 32,
#      'groundTruthId': None},
#     {'start': 20,
#      'end': 29,
#      'text': 'park road',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 31,
#      'end': 42,
#      'text': 'twickenham ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 43,
#      'end': 50,
#      'text': 'tw1 2pu',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 8304,
#    'title_number': 'TGL315959'},
#   {'text': 'the tennis court adjacent to church close, kensington church street, london',
#    'labels': [{'start': 0,
#      'end': 41,
#      'text': 'the tennis court adjacent to church close',
#      'labelId': '10',
#      'label': 'building_name',
#      'labellingFunctionId': 77,
#      'groundTruthId': None},
#     {'start': 43,
#      'end': 67,
#      'text': 'kensington church street',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 69,
#      'end': 75,
#      'text': 'london',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 13,
#      'groundTruthId': None}],
#    'datapoint_id': 85262,
#    'title_number': 'BGL43071'},
#   {'text': '4 bolton lane end, cliburn, penrith (ca10 3ap)',
#    'labels': [{'start': 0,
#      'end': 1,
#      'text': '4',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 6,
#      'groundTruthId': None},
#     {'start': 2,
#      'end': 17,
#      'text': 'bolton lane end',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 28,
#      'end': 36,
#      'text': 'penrith ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 37,
#      'end': 45,
#      'text': 'ca10 3ap',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 18155,
#    'title_number': 'CU269875'},
#   {'text': 'land at the back of 19 park way, havant (po9 1hh)',
#    'labels': [{'start': 0,
#      'end': 4,
#      'text': 'land',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 14,
#      'groundTruthId': None},
#     {'start': 23,
#      'end': 31,
#      'text': 'park way',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 33,
#      'end': 40,
#      'text': 'havant ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 41,
#      'end': 48,
#      'text': 'po9 1hh',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 15163,
#    'title_number': 'SH21157'},
#   {'text': 'flat 212, rodney house, dolphin square, london and car parking space h4 (sw1v 3ls)',
#    'labels': [{'start': 0,
#      'end': 4,
#      'text': 'flat',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 18,
#      'groundTruthId': None},
#     {'start': 10,
#      'end': 22,
#      'text': 'rodney house',
#      'labelId': '10',
#      'label': 'building_name',
#      'labellingFunctionId': 30,
#      'groundTruthId': None},
#     {'start': 24,
#      'end': 38,
#      'text': 'dolphin square',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 51,
#      'end': 68,
#      'text': 'car parking space',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 75,
#      'groundTruthId': None},
#     {'start': 73,
#      'end': 81,
#      'text': 'sw1v 3ls',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 81321,
#    'title_number': 'NGL882796'},
#   {'text': '20 high street, uxbridge (ub8 1jn)',
#    'labels': [{'start': 0,
#      'end': 2,
#      'text': '20',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 6,
#      'groundTruthId': None},
#     {'start': 3,
#      'end': 14,
#      'text': 'high street',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 16,
#      'end': 25,
#      'text': 'uxbridge ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 26,
#      'end': 33,
#      'text': 'ub8 1jn',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 19870,
#    'title_number': 'NGL556521'},
#   {'text': '541 tong street, bradford (bd4 6nl)',
#    'labels': [{'start': 0,
#      'end': 3,
#      'text': '541',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 6,
#      'groundTruthId': None},
#     {'start': 4,
#      'end': 15,
#      'text': 'tong street',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 17,
#      'end': 26,
#      'text': 'bradford ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 27,
#      'end': 34,
#      'text': 'bd4 6nl',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 6718,
#    'title_number': 'WYK483778'},
#   {'text': 'flat 47, carnegie house, 21 peterborough road, harrow (ha1 2ax)',
#    'labels': [{'start': 0,
#      'end': 4,
#      'text': 'flat',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 18,
#      'groundTruthId': None},
#     {'start': 9,
#      'end': 23,
#      'text': 'carnegie house',
#      'labelId': '10',
#      'label': 'building_name',
#      'labellingFunctionId': 30,
#      'groundTruthId': None},
#     {'start': 25,
#      'end': 27,
#      'text': '21',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 9,
#      'groundTruthId': None},
#     {'start': 28,
#      'end': 45,
#      'text': 'peterborough road',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 47,
#      'end': 54,
#      'text': 'harrow ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 55,
#      'end': 62,
#      'text': 'ha1 2ax',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 80382,
#    'title_number': 'AGL395276'},
#   {'text': "sixth floor square suite, 3 st james's square, london (sw1y 4ju)",
#    'labels': [{'start': 26,
#      'end': 27,
#      'text': '3',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 9,
#      'groundTruthId': None},
#     {'start': 28,
#      'end': 45,
#      'text': "st james's square",
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 47,
#      'end': 54,
#      'text': 'london ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 55,
#      'end': 63,
#      'text': 'sw1y 4ju',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 31368,
#    'title_number': 'NGL970070'},
#   {'text': 'iguzzini illuminazione, astolat way, peasmarsh, guildford (gu3 1ne)',
#    'labels': [{'start': 0,
#      'end': 22,
#      'text': 'iguzzini illuminazione',
#      'labelId': '10',
#      'label': 'building_name',
#      'labellingFunctionId': 77,
# ...
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 59,
#      'end': 67,
#      'text': 'wc1e 6jp',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 87309,
#    'title_number': 'NGL971194'},
#   {'text': 'airspace above 4 bevin place, rawmarsh, rotherham (s62 5la)',
#    'labels': [{'start': 0,
#      'end': 8,
#      'text': 'airspace',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 14,
#      'groundTruthId': None},
#     {'start': 17,
#      'end': 28,
#      'text': 'bevin place',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 40,
#      'end': 50,
#      'text': 'rotherham ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 51,
#      'end': 58,
#      'text': 's62 5la',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 62315,
#    'title_number': 'SYK594264'},
#   {'text': '9c avery row, london (w1k 4al)',
#    'labels': [{'start': 0,
#      'end': 2,
#      'text': '9c',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 6,
#      'groundTruthId': None},
#     {'start': 3,
#      'end': 12,
#      'text': 'avery row',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 14,
#      'end': 21,
#      'text': 'london ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 22,
#      'end': 29,
#      'text': 'w1k 4al',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 89299,
#    'title_number': 'NGL791272'},
#   {'text': 'land at higher rosewarne, camborne',
#    'labels': [{'start': 0,
#      'end': 4,
#      'text': 'land',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 14,
#      'groundTruthId': None},
#     {'start': 26,
#      'end': 34,
#      'text': 'camborne',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 13,
#      'groundTruthId': None}],
#    'datapoint_id': 32366,
#    'title_number': 'CL205663'},
#   {'text': 'second floor, devon house, 171-177 great portland street, london (w1w 5pg)',
#    'labels': [{'start': 14,
#      'end': 25,
#      'text': 'devon house',
#      'labelId': '10',
#      'label': 'building_name',
#      'labellingFunctionId': 30,
#      'groundTruthId': None},
#     {'start': 27,
#      'end': 34,
#      'text': '171-177',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 7,
#      'groundTruthId': None},
#     {'start': 35,
#      'end': 56,
#      'text': 'great portland street',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 58,
#      'end': 65,
#      'text': 'london ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 66,
#      'end': 73,
#      'text': 'w1w 5pg',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 87562,
#    'title_number': 'NGL926766'},
#   {'text': '158 walton street, london (sw3 2jl)',
#    'labels': [{'start': 0,
#      'end': 3,
#      'text': '158',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 6,
#      'groundTruthId': None},
#     {'start': 4,
#      'end': 17,
#      'text': 'walton street',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 19,
#      'end': 26,
#      'text': 'london ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 27,
#      'end': 34,
#      'text': 'sw3 2jl',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 23794,
#    'title_number': '433236'},
#   {'text': 'flat 48, pinto tower, 4 hebden place, london (sw8 2fs)',
#    'labels': [{'start': 0,
#      'end': 4,
#      'text': 'flat',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 18,
#      'groundTruthId': None},
#     {'start': 9,
#      'end': 20,
#      'text': 'pinto tower',
#      'labelId': '10',
#      'label': 'building_name',
#      'labellingFunctionId': 33,
#      'groundTruthId': None},
#     {'start': 22,
#      'end': 23,
#      'text': '4',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 9,
#      'groundTruthId': None},
#     {'start': 24,
#      'end': 36,
#      'text': 'hebden place',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 38,
#      'end': 45,
#      'text': 'london ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 46,
#      'end': 53,
#      'text': 'sw8 2fs',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 51046,
#    'title_number': 'TGL452296'},
#   {'text': '19a west fen road, ely (cb6 1an)',
#    'labels': [{'start': 0,
#      'end': 3,
#      'text': '19a',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 6,
#      'groundTruthId': None},
#     {'start': 4,
#      'end': 17,
#      'text': 'west fen road',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 19,
#      'end': 23,
#      'text': 'ely ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 24,
#      'end': 31,
#      'text': 'cb6 1an',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 90323,
#    'title_number': 'CB327977'},
#   {'text': 'room 302, 75 market street, lancaster (la1 1jg)',
#    'labels': [{'start': 0,
#      'end': 4,
#      'text': 'room',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 17,
#      'groundTruthId': None},
#     {'start': 5,
#      'end': 8,
#      'text': '302',
#      'labelId': '14',
#      'label': 'unit_id',
#      'labellingFunctionId': 38,
#      'groundTruthId': None},
#     {'start': 10,
#      'end': 12,
#      'text': '75',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 9,
#      'groundTruthId': None},
#     {'start': 13,
#      'end': 26,
#      'text': 'market street',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 28,
#      'end': 38,
#      'text': 'lancaster ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 39,
#      'end': 46,
#      'text': 'la1 1jg',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 16554,
#    'title_number': 'LAN158657'},
#   {'text': 'apartment 514, 50 bolsover street, london (w1w 5ng)',
#    'labels': [{'start': 0,
#      'end': 9,
#      'text': 'apartment',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 18,
#      'groundTruthId': None},
#     {'start': 10,
#      'end': 13,
#      'text': '514',
#      'labelId': '14',
#      'label': 'unit_id',
#      'labellingFunctionId': 47,
#      'groundTruthId': None},
#     {'start': 15,
#      'end': 17,
#      'text': '50',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 9,
#      'groundTruthId': None},
#     {'start': 18,
#      'end': 33,
#      'text': 'bolsover street',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 35,
#      'end': 42,
#      'text': 'london ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 43,
#      'end': 50,
#      'text': 'w1w 5ng',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 89249,
#    'title_number': 'NGL908951'},
#   {'text': 'kingsmead industrial estate, princess elizabeth way, cheltenham (gl51 7re)',
#    'labels': [{'start': 29,
#      'end': 51,
#      'text': 'princess elizabeth way',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 53,
#      'end': 64,
#      'text': 'cheltenham ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 65,
#      'end': 73,
#      'text': 'gl51 7re',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 79039,
#    'title_number': 'GR159662'},
#   {'text': '3 kd plaza, cotterells, hemel hempstead (hp1 1ax)',
#    'labels': [{'start': 0,
#      'end': 1,
#      'text': '3',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 6,
#      'groundTruthId': None},
#     {'start': 24,
#      'end': 40,
#      'text': 'hemel hempstead ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 41,
#      'end': 48,
#      'text': 'hp1 1ax',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 79727,
#    'title_number': 'HD511757'},
#   {'text': 'unit 28, hever hotel & country club, hever road, hever (tn8 7np)',
#    'labels': [{'start': 0,
#      'end': 4,
#      'text': 'unit',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 14,
#      'groundTruthId': None},
#     {'start': 5,
#      'end': 7,
#      'text': '28',
#      'labelId': '14',
#      'label': 'unit_id',
#      'labellingFunctionId': 48,
#      'groundTruthId': None},
#     {'start': 9,
#      'end': 35,
#      'text': 'hever hotel & country club',
#      'labelId': '10',
#      'label': 'building_name',
#      'labellingFunctionId': 63,
#      'groundTruthId': None},
#     {'start': 37,
#      'end': 47,
#      'text': 'hever road',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 49,
#      'end': 55,
#      'text': 'hever ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 56,
#      'end': 63,
#      'text': 'tn8 7np',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 8759,
#    'title_number': 'TT9019'},
#   {'text': 'land at grange farm, gayton le marsh',
#    'labels': [{'start': 0,
#      'end': 4,
#      'text': 'land',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 14,
#      'groundTruthId': None},
#     {'start': 8,
#      'end': 19,
#      'text': 'grange farm',
#      'labelId': '10',
#      'label': 'building_name',
#      'labellingFunctionId': 30,
#      'groundTruthId': None},
#     {'start': 31,
#      'end': 36,
#      'text': 'marsh',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 13,
#      'groundTruthId': None}],
#    'datapoint_id': 78252,
#    'title_number': 'LL353041'},
#   {'text': '93 sladefield road, ward end, birmingham (b8 3pf)',
#    'labels': [{'start': 0,
#      'end': 2,
#      'text': '93',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 6,
#      'groundTruthId': None},
#     {'start': 3,
#      'end': 18,
#      'text': 'sladefield road',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 20,
#      'end': 28,
#      'text': 'ward end',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 30,
#      'end': 41,
#      'text': 'birmingham ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 42,
#      'end': 48,
#      'text': 'b8 3pf',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 82940,
#    'title_number': 'WM655017'},
#   {'text': 'land and buildings on the north east side of gibraltar street, sheffield',
#    'labels': [{'start': 0,
#      'end': 4,
#      'text': 'land',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 14,
#      'groundTruthId': None},
#     {'start': 45,
#      'end': 61,
#      'text': 'gibraltar street',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 63,
#      'end': 72,
#      'text': 'sheffield',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 13,
#      'groundTruthId': None}],
#    'datapoint_id': 62687,
#    'title_number': 'SYK372232'},
#   {'text': '14 viscount court, pembridge villas, (w2 4xa)',
#    'labels': [{'start': 0,
#      'end': 2,
#      'text': '14',
#      'labelId': '14',
#      'label': 'unit_id',
#      'labellingFunctionId': 43,
#      'groundTruthId': None},
#     {'start': 3,
#      'end': 17,
#      'text': 'viscount court',
#      'labelId': '10',
#      'label': 'building_name',
#      'labellingFunctionId': 32,
#      'groundTruthId': None},
#     {'start': 19,
#      'end': 35,
#      'text': 'pembridge villas',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 38,
#      'end': 44,
#      'text': 'w2 4xa',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 53442,
#    'title_number': 'NGL402808'},
#   {'text': 'apartment 80, 4 leigh street, liverpool (l1 1nt)',
#    'labels': [{'start': 0,
#      'end': 9,
#      'text': 'apartment',
#      'labelId': '15',
#      'label': 'unit_type',
#      'labellingFunctionId': 18,
#      'groundTruthId': None},
#     {'start': 10,
#      'end': 12,
#      'text': '80',
#      'labelId': '14',
#      'label': 'unit_id',
#      'labellingFunctionId': 47,
#      'groundTruthId': None},
#     {'start': 14,
#      'end': 15,
#      'text': '4',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 9,
#      'groundTruthId': None},
#     {'start': 16,
#      'end': 28,
#      'text': 'leigh street',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 30,
#      'end': 40,
#      'text': 'liverpool ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 41,
#      'end': 47,
#      'text': 'l1 1nt',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 55701,
#    'title_number': 'MS679002'},
#   {'text': '25 and 26 george street, stroud (gl5 3dp)',
#    'labels': [{'start': 0,
#      'end': 2,
#      'text': '25',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 6,
#      'groundTruthId': None},
#     {'start': 7,
#      'end': 9,
#      'text': '26',
#      'labelId': '13',
#      'label': 'street_number',
#      'labellingFunctionId': 4,
#      'groundTruthId': None},
#     {'start': 10,
#      'end': 23,
#      'text': 'george street',
#      'labelId': '12',
#      'label': 'street_name',
#      'labellingFunctionId': 23,
#      'groundTruthId': None},
#     {'start': 25,
#      'end': 32,
#      'text': 'stroud ',
#      'labelId': '3',
#      'label': 'city',
#      'labellingFunctionId': 12,
#      'groundTruthId': None},
#     {'start': 33,
#      'end': 40,
#      'text': 'gl5 3dp',
#      'labelId': '11',
#      'label': 'postcode',
#      'labellingFunctionId': 36,
#      'groundTruthId': None}],
#    'datapoint_id': 55070,
#    'title_number': 'GR73732'}]}

# %%
datapoint_id_list = test_set.loc[:,'datapoint_id'].to_list()

data_and_labels = []
data_labels_dict2 = []

count_it = 0
for i in datapoint_id_list:

    count_it += 1
    if count_it % 100 == 0: 
        print('count = {}'.format(count_it))
        
    list_of_labels_dict = results_list = data['datapoints'][i]['programmatic']['results']
    
    #this inplace sorting using operator orders the dictionary by the start point. ties are automatically broken
    #it required the operator library
    list_of_labels_dict.sort(key=operator.itemgetter('start'))
    
    list_of_labels_dict = remove_overlapping_spans2(list_of_labels_dict)
    #create a list of dictionaries using a similar structure to save as a json
    data_labels_dict2 = data_labels_dict + [
        {
            'text' : ocod_data['property_address'][i],
            'entities' : list_of_labels_dict,
            'datapoint_id': i,
          #  'title_number':ocod_data['title_number'][i]
        }
    ]
# Out:
# count = 100
# count = 200
# count = 300
# count = 400
# count = 500
# count = 600
# count = 700
# count = 800
# count = 900
# count = 1000

# %%
jason_test_data ={
     "name": "test_set_24_04_22",
     "description": "the ground truth test set for labelling",
     "fields": [
         {"name": "text", 
          "data_type": "text"
         },
         {"name": "labels", 
          "data_type": "character_offsets"},
         {"name": "datapoint_id", 
          "data_type": "text"
         }
     ],
     "data": [data_labels_dict[x] for x in test_set.loc[:,'datapoint_id']]#, #upload only data from the test set
}

# %% [markdown]
# # Create new project with unlabelled data

# %%
"""
Step 1: Specify URL and headers for your API requests and some helper methods 
Reference: https://api.humanloop.com/docs#section/Authentication
Notes: 
    - If you don't already have a Humanloop account,
      signup @ https://app.humanloop.com/signup
    - Replace <INSERT YOUR API KEY HERE> with your users X-API-KEY 
      @ https://app.humanloop.com/profile
"""
base_url = "https://api.humanloop.com"
headers = {
    "Content-Type": "application/json",
    "X-API-KEY":  config.api_key,#the api key is hidden in a config file
}
# use the email associated to your Humanloop account
project_owner = "jonathan.s.bourne@gmail.com"


def get_field_id_by_name(name: str, fields):
    """Helper method for parsing field_id from dataset.fields given the name"""
    return [field for field in fields if field["name"] == name][0]["id"]


""" 
Step 2: Create a dataset
Reference: https://api.humanloop.com/docs#operation/upload_data_datasets_post
Notes:
    - It can be helpful to include your own unique identifiers for your data-points
      if available so that you can easily correlate any annotations and predictions 
      created by Humanloop back to your system.
    - If using large datasets (> 10k rows), you will have to upload it in multiple 
      batches using the API. Starting with the POST as shown below, then adding 
      subsequent batches using the PUT against the newly created dataset 
      (https://api.humanloop.com/docs#operation/update_data_datasets__id__put.)
"""

dataset_fields = requests.post(
    url=f"{base_url}/datasets", data=json.dumps(jason_test_data), headers=headers
).json()["fields"]


"""
Step 3: Create a project
Reference: https://api.humanloop.com/docs#operation/create_project_projects_post
Notes:
    - A Humanloop project is made up of one or more datasets, a team of annotators 
      and a model. As your team begin to annotate the data, a model is trained in real 
      time and used to prioritise what data your annotators should focus on next 
      (see https://humanloop.com/blog/why-you-should-be-using-active-learning).
    - The project inputs specify those dataset fields you wish to show to 
      your annotators and the model. 
    - The project output specifies the type of model you wish to train and the 
      corresponding label taxonomy. 
    - If your dataset has a field with existing annotations, you can use this to 
      warm start your project as shown in the following examples. 
      If you want your team to first review these existing annotations in Humanloop, 
      set "review_existing_annotations" to True, otherwise they will be used 
      automatically to train an initial model.
    - Both classification (single and multi-label) and extraction
      projects are supported.
    - You can update your project with more data by either connecting another dataset 
      or simply adding additional data-points to your existing dataset. 
      Alternatively, you can submit tasks for your model and/or team to complete
      (see our Human-in-the-loop tutorial for more information on this!).
"""


"""
Step 3b: Span extraction project 
"""
extraction_project_request = {
    "name": "Ground truth for offshore empties",
    "inputs": [
        {
            "name": "text",
            "data_type": "text",
            "description": "unparsed addresses",
            "data_sources": [
                {"field_id": get_field_id_by_name("text", dataset_fields)}
            ],
        },
        {
            "name": "datapoint_id",
            "data_type": "text",
            "description": "The original row the data is on",
            "display_only": True,
            "data_sources": [
                {"field_id": get_field_id_by_name("datapoint_id", dataset_fields)}
            ],
        },
    ],
    "outputs": [
        {
            "name": "labels",
            "description": "entities address parts",
            "task_type": "sequence_tagging",
            "data_sources": [
                {"field_id": get_field_id_by_name("labels", dataset_fields)}
            ],
            # which input you wish your model to extract from
            "input": "text",
        }
    ],
    "users": [project_owner],
    "guidelines": "Insert your markdown annotator guidelines here",
    "review_existing_annotations": True,
}

extraction_project_id = requests.post(
    url=f"{base_url}/projects",
    data=json.dumps(extraction_project_request),
    headers=headers,
).json()["id"]

print(f"Navigate to https://app.humanloop.com/projects/{extraction_project_id}")
# Out:
# Navigate to https://app.humanloop.com/projects/1388

# %% [markdown]
# ## create spacy old format

# %%
datapoint_id_list = [*range(0,len(data['datapoints']))]
data_and_labels = []
data_labels_dict = []

count_it = 0
for i in set(datapoint_id_list):
    count_it += 1
    if count_it % 1000 == 0: 
        print('count = {}'.format(count_it))
        
    single_id_index = np.where(np.array(datapoint_id_list)==i)
    ##these labels are in tuple form
    
    results_list = data['datapoints'][i]['programmatic']['results']
    list_of_labels =[(x['start'],x['end'],x['label'] ) for x in results_list]
    
    #list_of_labels = [(data[x]['start'], data[x]['end'], data[x]['label']) for x in single_id_index[0].tolist()]
    
    list_of_labels.sort(key=lambda y: y[0])
    
    list_of_labels = remove_overlapping_spans_tuples(list_of_labels)
    #print(list_of_labels)
    #create the NER dataset structure shown on the spacy website
    data_and_labels = data_and_labels + [ {
        'datapoint_id': i,
        'text':ocod_data['property_address'][i], 
                                           'entities':list_of_labels}  ]

print(data_and_labels)
#Save the cleaned data back as a json file ready to be processed further  
with open('/tf/empty_homes_data/humanloop_spacy_format.json', 'w') as f:
    json.dump(data_labels_dict, f)
# Out:
# count = 100
# count = 200
# count = 300
# count = 400
# count = 500
# count = 600
# count = 700
# count = 800
# count = 900
# count = 1000
# count = 1100
# count = 1200
# count = 1300
# count = 1400
# count = 1500
# count = 1600
# count = 1700
# count = 1800
# count = 1900
# count = 2000
# count = 2100
# count = 2200
# count = 2300
# count = 2400
# count = 2500
# count = 2600
# count = 2700
# count = 2800
# count = 2900
# count = 3000
# count = 3100
# count = 3200
# count = 3300
# count = 3400
# count = 3500
# count = 3600
# count = 3700
# count = 3800
# count = 3900
# count = 4000
# count = 4100
# count = 4200
# count = 4300
# count = 4400
# count = 4500
# count = 4600
# count = 4700
# count = 4800
# count = 4900
# count = 5000
# count = 5100
# count = 5200
# count = 5300
# count = 5400
# count = 5500
# count = 5600
# count = 5700
# count = 5800
# count = 5900
# count = 6000
# count = 6100
# count = 6200
# count = 6300
# count = 6400
# count = 6500
# count = 6600
# count = 6700
# count = 6800
# count = 6900
# count = 7000
# count = 7100
# count = 7200
# count = 7300
# count = 7400
# count = 7500
# count = 7600
