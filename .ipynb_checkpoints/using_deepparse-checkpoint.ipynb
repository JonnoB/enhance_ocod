# %%
import pandas as pd

# %%
from deepparse.parser import AddressParser

address_parser = AddressParser(model_type="bpemb", device=0)
address_parser_att = AddressParser(model_type="bpemb", attention_mechanism=True)
# Out:
# Loading the embeddings model
# Loading the embeddings model

# %% [markdown]
# # Create example addresses
#
# This block is designed to give a structured example of how the parser's fail.

# %%
flat_type = "Flat"
flat_number_1 = "8"
flat_number_2 = "C"
building_name = "Easting Mansions"
street_number = "23"
street_number_2 = "23-26"
street_name = "Broadfield Road"
postcode = "SW56 1ZZ"
city = "London"
country = "England"

# %%
house_1 = ', '.join([f'{street_number} {street_name}', postcode, city, country])
house_2 = ', '.join([f'{street_number} {street_name}', postcode, city])
flat_1 = ', '.join([f'{flat_type} {flat_number_1}', f'{street_number} {street_name}', postcode, city, country])
flat_2 = ', '.join([flat_number_1, f'{street_number} {street_name}', postcode, city, country])
flat_3 = ', '.join([f'{flat_number_1} {building_name}', f'{street_number} {street_name}', postcode, city, country])
flat_3 = ', '.join([f'{flat_number_1} {building_name}', f'{street_number_2} {street_name}', postcode, city, country])
flat_4 = ', '.join([f'{flat_number_1} {building_name}', street_name, postcode, city, country])

address_list = [house_1, house_2, flat_1, flat_2, flat_3, flat_4]

# %%
pd.DataFrame(address_list)
# Out:
#                                                    0
# 0      23 Broadfield Road, SW56 1ZZ, London, England
# 1               23 Broadfield Road, SW56 1ZZ, London
# 2  Flat 8, 23 Broadfield Road, SW56 1ZZ, London, ...
# 3   8, 23 Broadfield Road, SW56 1ZZ, London, England
# 4  8 Easting Mansions, 23-26 Broadfield Road, SW5...
# 5  8 Easting Mansions, Broadfield Road, SW56 1ZZ,...

# %%
parsed_address_list = address_parser(address_list)
address_errors = pd.DataFrame([x.to_dict() for x in parsed_address_list]).drop(
    ["Orientation", "GeneralDelivery", "EOS"], axis  = 1)
address_errors
# Out:
#   StreetNumber        StreetName                        Unit Municipality  \
# 0           23   broadfield road                        None       london
# 1      23 sw56   broadfield road                  1zz london         None
# 2         sw56   broadfield road                   flat 8 23       london
# 3         sw56              road             8 23 broadfield       london
# 4            8  easting mansions  23-26 broadfield road sw56       london
# 5            8  easting mansions        broadfield road sw56       london
#
#   Province PostalCode
# 0  england   sw56 1zz
# 1     None       None
# 2  england        1zz
# 3  england        1zz
# 4  england        1zz
# 5  england        1zz

# %% [markdown]
# As can be seen above, the basic parser is not very good

# %%
parsed_address_list_att = address_parser_att(address_list)
address_errors = pd.DataFrame([x.to_dict() for x in parsed_address_list_att]).drop(
    ["Orientation", "GeneralDelivery", "EOS"], axis  = 1)
address_errors
# Out:
#   StreetNumber                         StreetName    Unit Municipality  \
# 0           23                    broadfield road    None       london
# 1           23                    broadfield road    None         None
# 2           23                    broadfield road  flat 8       london
# 3         8 23                    broadfield road    None       london
# 4            8  easting mansions 23-26 broadfield    road       london
# 5            8   easting mansions broadfield road    None       london
#
#   Province PostalCode
# 0  england   sw56 1zz
# 1   london   sw56 1zz
# 2  england   sw56 1zz
# 3  england   sw56 1zz
# 4  england   sw56 1zz
# 5  england   sw56 1zz

# %% [markdown]
# ## VOA column headers
#
# I can't find the VOA column headers so have had to take them from the data description pdf [here](https://voaratinglists.blob.core.windows.net/html/documents/2017%20Compiled%20List%20and%20SMV%20Data%20Specification.pdf)

# %%
VOA_headers_raw= ["Incrementing Entry Number", "Billing Authority Code", "NDR Community Code", 
 "BA Reference Number", "Primary And Secondary Description Code", "Primary Description Text",
"Unique Address Reference Number UARN", "Full Property Identifier", "Firms Name", "Number Or Name",
"Street", "Town", "Postal District", "County", "Postcode", "Effective Date", "Composite Indicator",
 "Rateable Value", "Appeal Settlement Code", "Assessment Reference", "List Alteration Date", "SCAT Code And Suffix",
 "Sub Street level 3", "Sub Street level 2", "Sub Street level 1", "Case Number", 
 "Current From Date", "Current To Date", 
]

#set to lower and replace spaces with underscore to turn the names into appropriate column names
VOA_headers = [x.lower().replace(" ", "_") for x in VOA_headers_raw]

# %% [markdown]
# Using the attention mechanism dramatically improves the quality of the results, but there are still some substantial issues

# %%
test =  pd.read_csv('/tf/empty_homes_data/' +
                    'uk-englandwales-ndr-2017-listentries-compiled-epoch-0029-baseline-csv.csv',
                   sep = "*",
                   encoding_errors= 'ignore',
                    header=None,
                   names = VOA_headers[1:],
                    usecols = list(range(1,28))
                   )
# Out:
# <ipython-input-29-bde94ae726ae>:1: DtypeWarning: Columns (1,2,6,12,13,17,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   test =  pd.read_csv('/tf/empty_homes_data/' +

# %%
len(VOA_headers[1:])
# Out:
# 27

# %%
test
# Out:
#         billing_authority_code ndr_community_code ba_reference_number  \
# 0                          235                NaN             3000837
# 1                          235                NaN             3000449
# 2                          235                NaN             3001255
# 3                          235                NaN             1077209
# 4                          235                NaN             1132714
# ...                        ...                ...                 ...
# 2553594                   3545                NaN        401107480030
# 2553595                   3545                NaN        400718980142
# 2553596                   3545                NaN        401146540116
# 2553597                   3545                NaN        401146540114
# 2553598                   3545                NaN        439110070082
#
#         primary_and_secondary_description_code  \
# 0                                           MH
# 1                                           EL
# 2                                           IF
# 3                                          IF3
# 4                                           IF
# ...                                        ...
# 2553594                                     CO
# 2553595                                     CO
# 2553596                                     CO
# 2553597                                     CO
# 2553598                                    CH1
#
#                         primary_description_text  \
# 0                           SURGERY AND PREMISES
# 1                            SCHOOL AND PREMISES
# 2                           FACTORY AND PREMISES
# 3                          WORKSHOP AND PREMISES
# 4                           FACTORY AND PREMISES
# ...                                          ...
# 2553594                     OFFICES AND PREMISES
# 2553595                     OFFICES AND PREMISES
# 2553596                      OFFICE AND PREMISES
# 2553597                      OFFICE AND PREMISES
# 2553598  SELF CATERING HOLIDAY UNIT AND PREMISES
#
#         unique_address_reference_number_uarn  \
# 0                                 4159370000
# 1                                 8871511000
# 2                                  287299011
# 3                                  456757000
# 4                                  287049011
# ...                                      ...
# 2553594                          13296010000
# 2553595                          13296011000
# 2553596                          13511012000
# 2553597                          13511008000
# 2553598                          13511033000
#
#                                   full_property_identifier firms_name  \
# 0             MEDICAL CENTRE, ABBEYFIELDS, ELSTOW, BEDFORD        NaN
# 1              ELSTOW SCHOOL, ABBEYFIELDS, ELSTOW, BEDFORD        NaN
# 2                        5, ADAMS CLOSE, KEMPSTON, BEDFORD        NaN
# 3           WOBURN HOUSE 3, ADAMS CLOSE, KEMPSTON, BEDFORD        NaN
# 4                        1, ADAMS CLOSE, KEMPSTON, BEDFORD        NaN
# ...                                                    ...        ...
# 2553594  OFFICES 6-8  1ST FLOOR, WEAVERS BUSINESS CENTR...        NaN
# 2553595  ROOMS G/H, HOSTE HOUSE REFORMED CHURCH, WHITIN...        NaN
# 2553596  UNIT 6, MENTA BUSINESS CENTRE 21-27, HOLLANDS ...        NaN
# 2553597  UNIT 5, MENTA BUSINESS CENTRE 21-27, HOLLANDS ...        NaN
# 2553598  82, SANDPIPER, ISLEHAM MARINA, FEN BANK, ISLEH...        NaN
#
#                  number_or_name          street  ... appeal_settlement_code  \
# 0                MEDICAL CENTRE     ABBEYFIELDS  ...                    NaN
# 1                 ELSTOW SCHOOL     ABBEYFIELDS  ...                    NaN
# 2                             5     ADAMS CLOSE  ...                    NaN
# 3                WOBURN HOUSE 3     ADAMS CLOSE  ...                    NaN
# 4                             1     ADAMS CLOSE  ...                    NaN
# ...                         ...             ...  ...                    ...
# 2553594  OFFICES 6-8  1ST FLOOR     HAMLET ROAD  ...                    NaN
# 2553595               ROOMS G/H  WHITING STREET  ...                    NaN
# 2553596                  UNIT 6   HOLLANDS ROAD  ...                    NaN
# 2553597                  UNIT 5   HOLLANDS ROAD  ...                    NaN
# 2553598                      82        FEN BANK  ...                    NaN
#
#         assessment_reference list_alteration_date scat_code_and_suffix  \
# 0               2.345050e+10          01-JUL-2020                 436G
# 1               2.038070e+10          11-MAR-2019                 159G
# 2               1.574437e+10                  NaN                 096G
# 3               1.574433e+10                  NaN                 096G
# 4               2.145827e+10          06-NOV-2019                 096G
# ...                      ...                  ...                  ...
# 2553594         2.389786e+10          25-MAY-2021                 203G
# 2553595         2.389786e+10          25-MAY-2021                 203G
# 2553596         2.431176e+10          08-NOV-2021                 203G
# 2553597         2.431171e+10          08-NOV-2021                 203G
# 2553598         2.422966e+10          25-OCT-2021                 131G
#
#         sub_street_level_3 sub_street_level_2           sub_street_level_1  \
# 0                      NaN                NaN                          NaN
# 1                      NaN                NaN                          NaN
# 2                      NaN                NaN                          NaN
# 3                      NaN                NaN                          NaN
# 4                      NaN                NaN                          NaN
# ...                    ...                ...                          ...
# 2553594                NaN                NaN   WEAVERS BUSINESS CENTRE  6
# 2553595                NaN                NaN  HOSTE HOUSE REFORMED CHURCH
# 2553596                NaN                NaN  MENTA BUSINESS CENTRE 21-27
# 2553597                NaN                NaN  MENTA BUSINESS CENTRE 21-27
# 2553598                NaN          SANDPIPER               ISLEHAM MARINA
#
#           case_number  current_from_date current_to_date
# 0        3.427498e+10        01-JUL-2020             NaN
# 1        3.334318e+10        11-MAR-2019             NaN
# 2        2.096310e+10        01-APR-2017             NaN
# 3        2.092087e+10        01-APR-2017             NaN
# 4        3.363070e+10        06-NOV-2019             NaN
# ...               ...                ...             ...
# 2553594  3.534281e+10        25-MAY-2021             NaN
# 2553595  3.534281e+10        25-MAY-2021             NaN
# 2553596  3.560966e+10        08-NOV-2021             NaN
# 2553597  3.560965e+10        08-NOV-2021             NaN
# 2553598  3.560971e+10        25-OCT-2021             NaN
#
# [2553599 rows x 27 columns]

# %%
test.iloc[:, 6:14]
# Out:
#                                   full_property_identifier firms_name  \
# 0             MEDICAL CENTRE, ABBEYFIELDS, ELSTOW, BEDFORD        NaN
# 1              ELSTOW SCHOOL, ABBEYFIELDS, ELSTOW, BEDFORD        NaN
# 2                        5, ADAMS CLOSE, KEMPSTON, BEDFORD        NaN
# 3           WOBURN HOUSE 3, ADAMS CLOSE, KEMPSTON, BEDFORD        NaN
# 4                        1, ADAMS CLOSE, KEMPSTON, BEDFORD        NaN
# ...                                                    ...        ...
# 2553594  OFFICES 6-8  1ST FLOOR, WEAVERS BUSINESS CENTR...        NaN
# 2553595  ROOMS G/H, HOSTE HOUSE REFORMED CHURCH, WHITIN...        NaN
# 2553596  UNIT 6, MENTA BUSINESS CENTRE 21-27, HOLLANDS ...        NaN
# 2553597  UNIT 5, MENTA BUSINESS CENTRE 21-27, HOLLANDS ...        NaN
# 2553598  82, SANDPIPER, ISLEHAM MARINA, FEN BANK, ISLEH...        NaN
#
#                  number_or_name          street             town  \
# 0                MEDICAL CENTRE     ABBEYFIELDS          BEDFORD
# 1                 ELSTOW SCHOOL     ABBEYFIELDS          BEDFORD
# 2                             5     ADAMS CLOSE          BEDFORD
# 3                WOBURN HOUSE 3     ADAMS CLOSE          BEDFORD
# 4                             1     ADAMS CLOSE          BEDFORD
# ...                         ...             ...              ...
# 2553594  OFFICES 6-8  1ST FLOOR     HAMLET ROAD        HAVERHILL
# 2553595               ROOMS G/H  WHITING STREET  BURY ST EDMUNDS
# 2553596                  UNIT 6   HOLLANDS ROAD        HAVERHILL
# 2553597                  UNIT 5   HOLLANDS ROAD        HAVERHILL
# 2553598                      82        FEN BANK              ELY
#
#         postal_district   county  postcode
# 0                ELSTOW      NaN  MK42 9GP
# 1                ELSTOW      NaN  MK42 9GP
# 2              KEMPSTON      NaN  MK42 7JE
# 3              KEMPSTON      NaN  MK42 7JE
# 4              KEMPSTON      NaN  MK42 7JE
# ...                 ...      ...       ...
# 2553594             NaN  SUFFOLK   CB9 8EE
# 2553595             NaN  SUFFOLK  IP33 1NR
# 2553596             NaN  SUFFOLK   CB9 8PU
# 2553597             NaN  SUFFOLK   CB9 8PU
# 2553598         ISLEHAM    CAMBS   CB7 5SL
#
# [2553599 rows x 8 columns]

# %%
address_list = test['full_property_identifier'].tolist()[0:100]
parsed_address_list_att = address_parser_att(address_list)
# Out:
# Vectorizing the address

# %%
address_errors = pd.DataFrame([x.to_dict() for x in parsed_address_list_att]).drop(
    ["Orientation", "GeneralDelivery", "EOS"], axis  = 1)
address_errors["address"] = address_list
address_errors
# Out:
#    StreetNumber StreetName  Unit  \
# 0          None    medical  None
# 1          None     elstow  None
# 2             5      adams  None
# 3          None     woburn  None
# 4             1      adams  None
# ..          ...        ...   ...
# 95           3g  hutchison  None
# 96         None        r/o  None
# 97           36       None  None
# 98        35-37       None  None
# 99         None        r/o  None
#
#                                       Municipality Province      PostalCode  \
# 0                               abbeyfields elstow  bedford          centre
# 1                               abbeyfields elstow  bedford          school
# 2                                         kempston  bedford           close
# 3                             adams close kempston  bedford         house 3
# 4                                         kempston  bedford           close
# ..                                             ...      ...             ...
# 95  anderson cars alington road eynesbury st neots    cambs  site mk0225 at
# 96                                   ampthill road  bedford             28a
# 97                                            road  bedford        ampthill
# 98                                            road  bedford        ampthill
# 99                                   ampthill road  bedford              17
#
#                                               address
# 0        MEDICAL CENTRE, ABBEYFIELDS, ELSTOW, BEDFORD
# 1         ELSTOW SCHOOL, ABBEYFIELDS, ELSTOW, BEDFORD
# 2                   5, ADAMS CLOSE, KEMPSTON, BEDFORD
# 3      WOBURN HOUSE 3, ADAMS CLOSE, KEMPSTON, BEDFORD
# 4                   1, ADAMS CLOSE, KEMPSTON, BEDFORD
# ..                                                ...
# 95  HUTCHISON 3G SITE MK0225 AT ANDERSON CARS, ALI...
# 96                    R/O 28A, AMPTHILL ROAD, BEDFORD
# 97                         36, AMPTHILL ROAD, BEDFORD
# 98                      35-37, AMPTHILL ROAD, BEDFORD
# 99                     R/O 17, AMPTHILL ROAD, BEDFORD
#
# [100 rows x 7 columns]

# %%
address_list
# Out:
# ['MEDICAL CENTRE, ABBEYFIELDS, ELSTOW, BEDFORD',
#  'ELSTOW SCHOOL, ABBEYFIELDS, ELSTOW, BEDFORD',
#  '5, ADAMS CLOSE, KEMPSTON, BEDFORD',
#  'WOBURN HOUSE 3, ADAMS CLOSE, KEMPSTON, BEDFORD',
#  '1, ADAMS CLOSE, KEMPSTON, BEDFORD',
#  '2, ADAMS CLOSE, KEMPSTON, BEDFORD',
#  '16, ALEXANDRA PLACE, BEDFORD',
#  'THE PANACEA SOCIETY CAMPUS 12-16, ALBANY ROAD, BEDFORD',
#  '34, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'UNITS M1 M1A M1B POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'C24 THE POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'C25 THE POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'C17 THE POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'C14 THE POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'WOOD YARD ADJ C24 THE POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'UNIT 1 POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'C2 AND C18 THE POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'C21 THE POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'C23 THE POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'C13 THE POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'C12 THE POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'C11 THE POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'C10 THE POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'C9 THE POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'C8 THE POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'NENE VALLEY RACEWAY, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'C6 THE POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'C19 THE POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'C31 THE POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'C16 THE POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'C15 THE POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'C26 THE POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'C41 THE POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'C32 THE POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'C39 THE POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'ELL PIECE, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'WOLD FARM FISHERIES & SHOOTING, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'RIDING CENTRE AND PREMISES, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'T- MOBILE SITE 96599, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'WOLD FARM FISHERIES SHOOTING AND FESTIVAL SITE, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'UNIT 1 POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'AIRFIELD FARM WIND FARM, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'THE POLISH CAMP GATE 2, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'LAND WEST OF UNIT 1 POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'UNIT 3 THE OLD SAWMILL, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'UNIT 2 C2058 C2059 C2066 & C23 THE POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'C4 THE POLISH CAMP, AIRFIELD ROAD, PODINGTON, WELLINGBOROUGH, NORTHANTS',
#  'ESTATE OFFICE, ADAMSON COURT, ADAMSON WALK, KEMPSTON, BEDFORD',
#  'GND FLR 14, ADELAIDE SQUARE, BEDFORD',
#  '62, ADELAIDE SQUARE, BEDFORD',
#  '56, ADELAIDE SQUARE, BEDFORD',
#  '1, ADELAIDE SQUARE, BEDFORD',
#  'CAR PARK, ADELAIDE SQUARE, BEDFORD',
#  'CAULDWELL COMMUNITY CENTRE 51, ALTHORPE STREET, BEDFORD',
#  '2, ALTHORPE STREET, BEDFORD',
#  'HOLIDAY LET 37, ALTHORPE STREET, BEDFORD',
#  'GND FLR 2A, ALEXANDRA ROAD, BEDFORD',
#  'R/O 4, ALEXANDRA ROAD, BEDFORD',
#  '29-33, ALEXANDRA ROAD, BEDFORD',
#  'R/O 32, ALEXANDRA ROAD, BEDFORD',
#  '32, ALEXANDRA ROAD, BEDFORD',
#  '48, ALLHALLOWS, BEDFORD',
#  '2, ALLHALLOWS, BEDFORD',
#  '18, ALLHALLOWS, BEDFORD',
#  '38, ALLHALLOWS, BEDFORD',
#  '44, ALLHALLOWS, BEDFORD',
#  '12A, ALLHALLOWS, BEDFORD',
#  '14, ALLHALLOWS, BEDFORD',
#  '28, ALLHALLOWS, BEDFORD',
#  '1ST 2ND FLR 23-27, ALLHALLOWS, BEDFORD',
#  '13, ALLHALLOWS, BEDFORD',
#  '26, ALLHALLOWS, BEDFORD',
#  '24, ALLHALLOWS, BEDFORD',
#  '22, ALLHALLOWS, BEDFORD',
#  '21, ALLHALLOWS, BEDFORD',
#  '15, ALLHALLOWS, BEDFORD',
#  '16, ALLHALLOWS, BEDFORD',
#  '4, ALLHALLOWS, BEDFORD',
#  '5, ALLHALLOWS, BEDFORD',
#  '17-19, ALLHALLOWS, BEDFORD',
#  '30, ALLHALLOWS, BEDFORD',
#  '23-27, ALLHALLOWS, BEDFORD',
#  '12, ALLHALLOWS, BEDFORD',
#  '6, ALLHALLOWS, BEDFORD',
#  '8, ALLHALLOWS, BEDFORD',
#  '10, ALLHALLOWS, BEDFORD',
#  '46, ALLHALLOWS, BEDFORD',
#  '32-36, ALLHALLOWS, BEDFORD',
#  '42, ALLHALLOWS, BEDFORD',
#  '40, ALLHALLOWS, BEDFORD',
#  '20, ALLHALLOWS, BEDFORD',
#  'BEDFORD BUS STATION, ALLHALLOWS, BEDFORD',
#  'STAGECOACH AT BEDFORD BUS STATION, ALLHALLOWS, BEDFORD',
#  '7, ALLHALLOWS, BEDFORD',
#  'VODAFONE SITE 32590, ALINGTON ROAD, EYNESBURY, ST NEOTS, CAMBS',
#  'HUTCHISON 3G SITE MK0225 AT ANDERSON CARS, ALINGTON ROAD, EYNESBURY, ST NEOTS, CAMBS',
#  'R/O 28A, AMPTHILL ROAD, BEDFORD',
#  '36, AMPTHILL ROAD, BEDFORD',
#  '35-37, AMPTHILL ROAD, BEDFORD',
#  'R/O 17, AMPTHILL ROAD, BEDFORD']
