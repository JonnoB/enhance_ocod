# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# # Introduction
# * Raw CSV loaded and lightly processed. Output: two column csv columns, property address, flat tag
# * Data labelled in programmatic. Output: json file of entities.
# * Data programmatic output json cleaned ordered and overlaps removed. Output: json file
# * **Clean json converted to dataframe and multi-addresses expanded.** Output: CSV
# * Count and locate addresses
# * Create address matcher and match businesses
# * Classify address types
#
# This notebook is used so that I can create the code necessary to expand the addresses so that a single property/dwelling is a single line. This means the data will follow the tidy data principles of one observation per line where an observation is what is commonly thought of as a property.

# %%
import json
import pandas as pd
import re
from helper_functions import *
import numpy as np

# %%
with open('/tf/empty_homes_data/humanloop_04_04_22_t1210.json', "r") as read_file:
    all_entities_json = json.load(read_file)

# with open('/tf/empty_homes_data/full_dataset_no_overlaps.json', "r") as read_file:
#     all_entities_json = json.load(read_file)

# %%
all_entities_json['datapoints'][8079]
# Out:
# {'programmatic': {'results': [{'start': 48,
#     'end': 49,
#     'text': '2',
#     'labelId': '13',
#     'label': 'street_number',
#     'labellingFunctionId': 5,
#     'groundTruthId': None},
#    {'start': 50,
#     'end': 51,
#     'text': '3',
#     'labelId': '13',
#     'label': 'street_number',
#     'labellingFunctionId': 5,
#     'groundTruthId': None},
#    {'start': 52,
#     'end': 53,
#     'text': '4',
#     'labelId': '13',
#     'label': 'street_number',
#     'labellingFunctionId': 5,
#     'groundTruthId': None},
#    {'start': 54,
#     'end': 55,
#     'text': '5',
#     'labelId': '13',
#     'label': 'street_number',
#     'labellingFunctionId': 5,
#     'groundTruthId': None},
#    {'start': 46,
#     'end': 47,
#     'text': '1',
#     'labelId': '13',
#     'label': 'street_number',
#     'labellingFunctionId': 8,
#     'groundTruthId': None},
#    {'start': 215,
#     'end': 221,
#     'text': 'london',
#     'labelId': '3',
#     'label': 'city',
#     'labellingFunctionId': 13,
#     'groundTruthId': None},
#    {'start': 0,
#     'end': 44,
#     'text': 'the scottish provident institution buildings',
#     'labelId': '10',
#     'label': 'building_name',
#     'labellingFunctionId': 69,
#     'groundTruthId': None},
#    {'start': 162,
#     'end': 175,
#     'text': 'george street',
#     'labelId': '12',
#     'label': 'street_name',
#     'labellingFunctionId': 23,
#     'groundTruthId': None},
#    {'start': 197,
#     'end': 213,
#     'text': 'st swithins lane',
#     'labelId': '12',
#     'label': 'street_name',
#     'labellingFunctionId': 23,
#     'groundTruthId': None},
#    {'start': 0,
#     'end': 44,
#     'text': 'the scottish provident institution buildings',
#     'labelId': '10',
#     'label': 'building_name',
#     'labellingFunctionId': 77,
#     'groundTruthId': None}],
#   'aggregateResults': [{'start': 0,
#     'end': 44,
#     'text': 'the scottish provident institution buildings',
#     'labelId': 10,
#     'label': 'building_name',
#     'probability': 0.999554125389013},
#    {'start': 46,
#     'end': 57,
#     'text': '1,2,3,4,5,6',
#     'labelId': 13,
#     'label': 'street_number',
#     'probability': 0.037044002247163074},
#    {'start': 162,
#     'end': 175,
#     'text': 'george street',
#     'labelId': 12,
#     'label': 'street_name',
#     'probability': 0.999959353627024},
#    {'start': 197,
#     'end': 213,
#     'text': 'st swithins lane',
#     'labelId': 12,
#     'label': 'street_name',
#     'probability': 0.9999532800156188},
#    {'start': 215,
#     'end': 221,
#     'text': 'london',
#     'labelId': 3,
#     'label': 'city',
#     'probability': 0.9932172244861341}],
#   'groundTruths': []},
#  'data': {'_1': 8079,
#   'text': 'the scottish provident institution buildings, 1,2,3,4,5,6 lombard street abutting in part on lombard street in other part on mansion house place in other part on george street and in other part on st swithins lane, london',
#   'flat_tag': False,
#   'commercial_park_tag': False},
#  'id': 8079}

# %%
#output_dict = [x for x in all_entities_json if int(x['data_stuff.id']) == 42353]

# Transform python object back into json
#output_json = json.dumps(output_dict)

# %%
all_entities_json
# Out:
# {'datapoints': [{'programmatic': {'results': [{'start': 41,
#       'end': 47,
#       'text': 'leigh ',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 12,
#       'groundTruthId': None},
#      {'start': 27,
#       'end': 39,
#       'text': 'nel pan lane',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 24,
#       'groundTruthId': None},
#      {'start': 48,
#       'end': 55,
#       'text': 'wn7 5jt',
#       'labelId': '11',
#       'label': 'postcode',
#       'labellingFunctionId': 36,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 25,
#       'text': 'westleigh lodge care home',
#       'labelId': '10',
#       'label': 'building_name',
#       'labellingFunctionId': 30,
#       'groundTruthId': None},
#      {'start': 27,
#       'end': 39,
#       'text': 'nel pan lane',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 25,
#       'text': 'westleigh lodge care home',
#       'labelId': '10',
#       'label': 'building_name',
#       'labellingFunctionId': 77,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 25,
#       'text': 'westleigh lodge care home',
#       'labelId': 10,
#       'label': 'building_name',
#       'probability': 0.9996499230367323},
#      {'start': 27,
#       'end': 39,
#       'text': 'nel pan lane',
#       'labelId': 12,
#       'label': 'street_name',
#       'probability': 0.9999987093911413},
#      {'start': 41,
#       'end': 46,
#       'text': 'leigh',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.9996843229469498},
#      {'start': 48,
#       'end': 55,
#       'text': 'wn7 5jt',
#       'labelId': 11,
#       'label': 'postcode',
#       'probability': 0.981689301627415}],
#     'groundTruths': []},
#    'data': {'_1': 0,
#     'text': 'westleigh lodge care home, nel pan lane, leigh (wn7 5jt)',
#     'flat_tag': False,
#     'commercial_park_tag': True},
#    'id': 0},
#   {'programmatic': {'results': [{'start': 8,
#       'end': 10,
#       'text': '1a',
#       'labelId': '13',
#       'label': 'street_number',
#       'labellingFunctionId': 9,
#       'groundTruthId': None},
#      {'start': 25,
#       'end': 36,
#       'text': 'manchester ',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 12,
#       'groundTruthId': None},
#      {'start': 37,
#       'end': 43,
#       'text': 'm1 3he',
#       'labelId': '11',
#       'label': 'postcode',
#       'labellingFunctionId': 36,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 4,
#       'text': 'flat',
#       'labelId': '15',
#       'label': 'unit_type',
#       'labellingFunctionId': 18,
#       'groundTruthId': None},
#      {'start': 11,
#       'end': 23,
#       'text': 'canal street',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 4,
#       'text': 'flat',
#       'labelId': 15,
#       'label': 'unit_type',
#       'probability': 0.9999929239264794},
#      {'start': 8,
#       'end': 23,
#       'text': '1a canal street',
#       'labelId': 13,
#       'label': 'street_number',
#       'probability': 0.2548152630895073},
#      {'start': 25,
#       'end': 35,
#       'text': 'manchester',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.9996877948212662},
#      {'start': 37,
#       'end': 43,
#       'text': 'm1 3he',
#       'labelId': 11,
#       'label': 'postcode',
#       'probability': 0.9818163996840167}],
#     'groundTruths': []},
#    'data': {'_1': 1,
#     'text': 'flat 1, 1a canal street, manchester (m1 3he)',
#     'flat_tag': True,
#     'commercial_park_tag': False},
#    'id': 1},
#   {'programmatic': {'results': [{'start': 10,
#       'end': 11,
#       'text': '1',
#       'labelId': '13',
#       'label': 'street_number',
#       'labellingFunctionId': 9,
#       'groundTruthId': None},
#      {'start': 25,
#       'end': 36,
#       'text': 'manchester ',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 12,
#       'groundTruthId': None},
#      {'start': 37,
#       'end': 43,
#       'text': 'm3 4ay',
#       'labelId': '11',
#       'label': 'postcode',
#       'labellingFunctionId': 36,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 4,
#       'text': 'flat',
#       'labelId': '15',
#       'label': 'unit_type',
#       'labellingFunctionId': 18,
#       'groundTruthId': None},
#      {'start': 12,
#       'end': 23,
#       'text': 'regent road',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 4,
#       'text': 'flat',
#       'labelId': 15,
#       'label': 'unit_type',
#       'probability': 0.9999929239264794},
#      {'start': 10,
#       'end': 23,
#       'text': '1 regent road',
#       'labelId': 13,
#       'label': 'street_number',
#       'probability': 0.2548152630895073},
#      {'start': 25,
#       'end': 35,
#       'text': 'manchester',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.9996877948212662},
#      {'start': 37,
#       'end': 43,
#       'text': 'm3 4ay',
#       'labelId': 11,
#       'label': 'postcode',
#       'probability': 0.9818163996840167}],
#     'groundTruths': []},
#    'data': {'_1': 2,
#     'text': 'flat 201, 1 regent road, manchester (m3 4ay)',
#     'flat_tag': True,
#     'commercial_park_tag': False},
#    'id': 2},
#   {'programmatic': {'results': [{'start': 48,
#       'end': 54,
#       'text': 'wigan ',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 12,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 4,
#       'text': 'land',
#       'labelId': '15',
#       'label': 'unit_type',
#       'labellingFunctionId': 14,
#       'groundTruthId': None},
#      {'start': 55,
#       'end': 62,
#       'text': 'wn4 9aa',
#       'labelId': '11',
#       'label': 'postcode',
#       'labellingFunctionId': 36,
#       'groundTruthId': None},
#      {'start': 11,
#       'end': 24,
#       'text': 'gerard street',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 4,
#       'text': 'land',
#       'labelId': 15,
#       'label': 'unit_type',
#       'probability': 0.999999997120395},
#      {'start': 11,
#       'end': 24,
#       'text': 'gerard street',
#       'labelId': 12,
#       'label': 'street_name',
#       'probability': 0.999953448707446},
#      {'start': 48,
#       'end': 53,
#       'text': 'wigan',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.9996733452523681},
#      {'start': 55,
#       'end': 62,
#       'text': 'wn4 9aa',
#       'labelId': 11,
#       'label': 'postcode',
#       'probability': 0.9809847133885883}],
#     'groundTruths': []},
#    'data': {'_1': 3,
#     'text': 'land at 2a gerard street, ashton in makerfield, wigan (wn4 9aa)',
#     'flat_tag': False,
#     'commercial_park_tag': False},
#    'id': 3},
#   {'programmatic': {'results': [{'start': 40,
#       'end': 51,
#       'text': 'manchester ',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 12,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 4,
#       'text': 'unit',
#       'labelId': '15',
#       'label': 'unit_type',
#       'labellingFunctionId': 14,
#       'groundTruthId': None},
#      {'start': 52,
#       'end': 59,
#       'text': 'm15 4nz',
#       'labelId': '11',
#       'label': 'postcode',
#       'labellingFunctionId': 36,
#       'groundTruthId': None},
#      {'start': 5,
#       'end': 8,
#       'text': '111',
#       'labelId': '14',
#       'label': 'unit_id',
#       'labellingFunctionId': 48,
#       'groundTruthId': None},
#      {'start': 10,
#       'end': 22,
#       'text': 'timber wharf',
#       'labelId': '10',
#       'label': 'building_name',
#       'labellingFunctionId': 30,
#       'groundTruthId': None},
#      {'start': 10,
#       'end': 23,
#       'text': 'timber wharf,',
#       'labelId': '10',
#       'label': 'building_name',
#       'labellingFunctionId': 57,
#       'groundTruthId': None},
#      {'start': 24,
#       'end': 38,
#       'text': 'worsley street',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 8,
#       'text': 'unit 111',
#       'labelId': 15,
#       'label': 'unit_type',
#       'probability': 0.9082856366667307},
#      {'start': 10,
#       'end': 38,
#       'text': 'timber wharf, worsley street',
#       'labelId': 10,
#       'label': 'building_name',
#       'probability': 0.1544730377345121},
#      {'start': 40,
#       'end': 50,
#       'text': 'manchester',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.9997470022345131},
#      {'start': 52,
#       'end': 59,
#       'text': 'm15 4nz',
#       'labelId': 11,
#       'label': 'postcode',
#       'probability': 0.9852487287550119}],
#     'groundTruths': []},
#    'data': {'_1': 4,
#     'text': 'unit 111, timber wharf, worsley street, manchester (m15 4nz)',
#     'flat_tag': True,
#     'commercial_park_tag': False},
#    'id': 4},
#   {'programmatic': {'results': [{'start': 18,
#       'end': 31,
#       'text': 'peterborough ',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 12,
#       'groundTruthId': None},
#      {'start': 32,
#       'end': 39,
#       'text': 'pe2 8ns',
#       'labelId': '11',
#       'label': 'postcode',
#       'labellingFunctionId': 36,
#       'groundTruthId': None},
#      {'start': 3,
#       'end': 16,
#       'text': 'hawksbill way',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 20,
#       'groundTruthId': None},
#      {'start': 3,
#       'end': 16,
#       'text': 'hawksbill way',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 2,
#       'text': '81',
#       'labelId': '13',
#       'label': 'street_number',
#       'labellingFunctionId': 6,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 16,
#       'text': '81 hawksbill way',
#       'labelId': 13,
#       'label': 'street_number',
#       'probability': 0.9998693020335351},
#      {'start': 18,
#       'end': 30,
#       'text': 'peterborough',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.9996591720862607},
#      {'start': 32,
#       'end': 39,
#       'text': 'pe2 8ns',
#       'labelId': 11,
#       'label': 'postcode',
#       'probability': 0.9809849302391106}],
#     'groundTruths': []},
#    'data': {'_1': 5,
#     'text': '81 hawksbill way, peterborough (pe2 8ns)',
#     'flat_tag': False,
#     'commercial_park_tag': False},
#    'id': 5},
#   {'programmatic': {'results': [{'start': 16,
#       'end': 29,
#       'text': 'peterborough ',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 12,
#       'groundTruthId': None},
#      {'start': 30,
#       'end': 37,
#       'text': 'pe2 8nr',
#       'labelId': '11',
#       'label': 'postcode',
#       'labellingFunctionId': 36,
#       'groundTruthId': None},
#      {'start': 2,
#       'end': 14,
#       'text': 'beluga close',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 1,
#       'text': '3',
#       'labelId': '13',
#       'label': 'street_number',
#       'labellingFunctionId': 6,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 14,
#       'text': '3 beluga close',
#       'labelId': 13,
#       'label': 'street_number',
#       'probability': 0.9998602036452428},
#      {'start': 16,
#       'end': 28,
#       'text': 'peterborough',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.9996733644162554},
#      {'start': 30,
#       'end': 37,
#       'text': 'pe2 8nr',
#       'labelId': 11,
#       'label': 'postcode',
#       'probability': 0.9809863735884802}],
#     'groundTruths': []},
#    'data': {'_1': 6,
#     'text': '3 beluga close, peterborough (pe2 8nr)',
#     'flat_tag': False,
#     'commercial_park_tag': False},
#    'id': 6},
#   {'programmatic': {'results': [{'start': 19,
#       'end': 50,
#       'text': 'peterborough and parking space ',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 12,
#       'groundTruthId': None},
#      {'start': 51,
#       'end': 58,
#       'text': 'pe2 8ny',
#       'labelId': '11',
#       'label': 'postcode',
#       'labellingFunctionId': 36,
#       'groundTruthId': None},
#      {'start': 4,
#       'end': 17,
#       'text': 'hawksbill way',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 20,
#       'groundTruthId': None},
#      {'start': 36,
#       'end': 49,
#       'text': 'parking space',
#       'labelId': '15',
#       'label': 'unit_type',
#       'labellingFunctionId': 75,
#       'groundTruthId': None},
#      {'start': 4,
#       'end': 17,
#       'text': 'hawksbill way',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 3,
#       'text': '232',
#       'labelId': '13',
#       'label': 'street_number',
#       'labellingFunctionId': 6,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 17,
#       'text': '232 hawksbill way',
#       'labelId': 13,
#       'label': 'street_number',
#       'probability': 0.9998817635283388},
#      {'start': 19,
#       'end': 49,
#       'text': 'peterborough and parking space',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.9977172106552019},
#      {'start': 51,
#       'end': 58,
#       'text': 'pe2 8ny',
#       'labelId': 11,
#       'label': 'postcode',
#       'probability': 0.9827816860378712}],
#     'groundTruths': []},
#    'data': {'_1': 7,
#     'text': '232 hawksbill way, peterborough and parking space (pe2 8ny)',
#     'flat_tag': False,
#     'commercial_park_tag': False},
#    'id': 7},
#   {'programmatic': {'results': [{'start': 32,
#       'end': 44,
#       'text': 'peterborough',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 13,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 4,
#       'text': 'land',
#       'labelId': '15',
#       'label': 'unit_type',
#       'labellingFunctionId': 14,
#       'groundTruthId': None},
#      {'start': 19,
#       'end': 30,
#       'text': 'high street',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 4,
#       'text': 'land',
#       'labelId': 15,
#       'label': 'unit_type',
#       'probability': 0.999999997120153},
#      {'start': 19,
#       'end': 30,
#       'text': 'high street',
#       'labelId': 12,
#       'label': 'street_name',
#       'probability': 0.9999521360867561},
#      {'start': 32,
#       'end': 44,
#       'text': 'peterborough',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.992014657338846}],
#     'groundTruths': []},
#    'data': {'_1': 8,
#     'text': 'land at cityscape, high street, peterborough',
#     'flat_tag': False,
#     'commercial_park_tag': False},
#    'id': 8},
#   {'programmatic': {'results': [{'start': 27,
#       'end': 39,
#       'text': 'peterborough',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 13,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 4,
#       'text': 'land',
#       'labelId': '15',
#       'label': 'unit_type',
#       'labellingFunctionId': 14,
#       'groundTruthId': None},
#      {'start': 8,
#       'end': 25,
#       'text': 'queensgate centre',
#       'labelId': '10',
#       'label': 'building_name',
#       'labellingFunctionId': 30,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 4,
#       'text': 'land',
#       'labelId': 15,
#       'label': 'unit_type',
#       'probability': 0.9999999971747382},
#      {'start': 8,
#       'end': 25,
#       'text': 'queensgate centre',
#       'labelId': 10,
#       'label': 'building_name',
#       'probability': 0.6148381364235121},
#      {'start': 27,
#       'end': 39,
#       'text': 'peterborough',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.9923428348125883}],
#     'groundTruths': []},
#    'data': {'_1': 9,
#     'text': 'land at queensgate centre, peterborough',
#     'flat_tag': False,
#     'commercial_park_tag': False},
#    'id': 9},
#   {'programmatic': {'results': [{'start': 17,
#       'end': 30,
#       'text': 'peterborough ',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 12,
#       'groundTruthId': None},
#      {'start': 31,
#       'end': 38,
#       'text': 'pe2 8nr',
#       'labelId': '11',
#       'label': 'postcode',
#       'labellingFunctionId': 36,
#       'groundTruthId': None},
#      {'start': 3,
#       'end': 15,
#       'text': 'beluga close',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 2,
#       'text': '51',
#       'labelId': '13',
#       'label': 'street_number',
#       'labellingFunctionId': 6,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 15,
#       'text': '51 beluga close',
#       'labelId': 13,
#       'label': 'street_number',
#       'probability': 0.9998602036452428},
#      {'start': 17,
#       'end': 29,
#       'text': 'peterborough',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.9996733644162554},
#      {'start': 31,
#       'end': 38,
#       'text': 'pe2 8nr',
#       'labelId': 11,
#       'label': 'postcode',
#       'probability': 0.9809863735884802}],
#     'groundTruths': []},
#    'data': {'_1': 10,
#     'text': '51 beluga close, peterborough (pe2 8nr)',
#     'flat_tag': False,
#     'commercial_park_tag': False},
#    'id': 10},
#   {'programmatic': {'results': [{'start': 19,
#       'end': 32,
#       'text': 'peterborough ',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 12,
#       'groundTruthId': None},
#      {'start': 33,
#       'end': 40,
#       'text': 'pe2 8ns',
#       'labelId': '11',
#       'label': 'postcode',
#       'labellingFunctionId': 36,
#       'groundTruthId': None},
#      {'start': 4,
#       'end': 17,
#       'text': 'hawksbill way',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 20,
#       'groundTruthId': None},
#      {'start': 4,
#       'end': 17,
#       'text': 'hawksbill way',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 3,
#       'text': '121',
#       'labelId': '13',
#       'label': 'street_number',
#       'labellingFunctionId': 6,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 17,
#       'text': '121 hawksbill way',
#       'labelId': 13,
#       'label': 'street_number',
#       'probability': 0.9998693020335351},
#      {'start': 19,
#       'end': 31,
#       'text': 'peterborough',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.9996591720862607},
#      {'start': 33,
#       'end': 40,
#       'text': 'pe2 8ns',
#       'labelId': 11,
#       'label': 'postcode',
#       'probability': 0.9809849302391106}],
#     'groundTruths': []},
#    'data': {'_1': 11,
#     'text': '121 hawksbill way, peterborough (pe2 8ns)',
#     'flat_tag': False,
#     'commercial_park_tag': False},
#    'id': 11},
#   {'programmatic': {'results': [{'start': 17,
#       'end': 30,
#       'text': 'peterborough ',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 12,
#       'groundTruthId': None},
#      {'start': 31,
#       'end': 38,
#       'text': 'pe2 8ne',
#       'labelId': '11',
#       'label': 'postcode',
#       'labellingFunctionId': 36,
#       'groundTruthId': None},
#      {'start': 3,
#       'end': 15,
#       'text': 'beluga close',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 2,
#       'text': '44',
#       'labelId': '13',
#       'label': 'street_number',
#       'labellingFunctionId': 6,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 15,
#       'text': '44 beluga close',
#       'labelId': 13,
#       'label': 'street_number',
#       'probability': 0.9998602036452428},
#      {'start': 17,
#       'end': 29,
#       'text': 'peterborough',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.9996733644162554},
#      {'start': 31,
#       'end': 38,
#       'text': 'pe2 8ne',
#       'labelId': 11,
#       'label': 'postcode',
#       'probability': 0.9809863735884802}],
#     'groundTruths': []},
#    'data': {'_1': 12,
#     'text': '44 beluga close, peterborough (pe2 8ne)',
#     'flat_tag': False,
#     'commercial_park_tag': False},
#    'id': 12},
#   {'programmatic': {'results': [{'start': 46,
#       'end': 49,
#       'text': 'odd',
#       'labelId': '16',
#       'label': 'number_filter',
#       'labellingFunctionId': 10,
#       'groundTruthId': None},
#      {'start': 72,
#       'end': 75,
#       'text': 'odd',
#       'labelId': '16',
#       'label': 'number_filter',
#       'labellingFunctionId': 10,
#       'groundTruthId': None},
#      {'start': 6,
#       'end': 10,
#       'text': 'even',
#       'labelId': '16',
#       'label': 'number_filter',
#       'labellingFunctionId': 11,
#       'groundTruthId': None},
#      {'start': 86,
#       'end': 98,
#       'text': 'peterborough',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 13,
#       'groundTruthId': None},
#      {'start': 12,
#       'end': 22,
#       'text': 'miller way',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 20,
#       'groundTruthId': None},
#      {'start': 77,
#       'end': 84,
#       'text': 'fengate',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 20,
#       'groundTruthId': None},
#      {'start': 12,
#       'end': 22,
#       'text': 'miller way',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None},
#      {'start': 30,
#       'end': 44,
#       'text': 'hammonds drive',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None},
#      {'start': 60,
#       'end': 70,
#       'text': 'rudd close',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None},
#      {'start': 77,
#       'end': 84,
#       'text': 'fengate',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 4,
#       'text': '2-24',
#       'labelId': '13',
#       'label': 'street_number',
#       'labellingFunctionId': 7,
#       'groundTruthId': None},
#      {'start': 24,
#       'end': 29,
#       'text': '15-25',
#       'labelId': '13',
#       'label': 'street_number',
#       'labellingFunctionId': 7,
#       'groundTruthId': None},
#      {'start': 55,
#       'end': 59,
#       'text': '1-19',
#       'labelId': '13',
#       'label': 'street_number',
#       'labellingFunctionId': 7,
#       'groundTruthId': None},
#      {'start': 55,
#       'end': 56,
#       'text': '1',
#       'labelId': '13',
#       'label': 'street_number',
#       'labellingFunctionId': 4,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 4,
#       'text': '2-24',
#       'labelId': 13,
#       'label': 'street_number',
#       'probability': 5.713246247004728e-05},
#      {'start': 6,
#       'end': 10,
#       'text': 'even',
#       'labelId': 16,
#       'label': 'number_filter',
#       'probability': 5.272743118088579e-08},
#      {'start': 12,
#       'end': 22,
#       'text': 'miller way',
#       'labelId': 12,
#       'label': 'street_name',
#       'probability': 0.9999999995600399},
#      {'start': 24,
#       'end': 44,
#       'text': '15-25 hammonds drive',
#       'labelId': 13,
#       'label': 'street_number',
#       'probability': 0.0009097201118398571},
#      {'start': 46,
#       'end': 49,
#       'text': 'odd',
#       'labelId': 16,
#       'label': 'number_filter',
#       'probability': 5.3543553974868926e-08},
#      {'start': 55,
#       'end': 70,
#       'text': '1-19 rudd close',
#       'labelId': 13,
#       'label': 'street_number',
#       'probability': 0.0007739706599985628},
#      {'start': 72,
#       'end': 75,
#       'text': 'odd',
#       'labelId': 16,
#       'label': 'number_filter',
#       'probability': 5.354355397486912e-08},
#      {'start': 77,
#       'end': 84,
#       'text': 'fengate',
#       'labelId': 12,
#       'label': 'street_name',
#       'probability': 0.999999999625782},
#      {'start': 86,
#       'end': 98,
#       'text': 'peterborough',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.9940656867145568}],
#     'groundTruths': []},
#    'data': {'_1': 13,
#     'text': '2-24 (even) miller way, 15-25 hammonds drive (odd) and 1-19 rudd close (odd) fengate, peterborough',
#     'flat_tag': False,
#     'commercial_park_tag': False},
#    'id': 13},
#   {'programmatic': {'results': [{'start': 19,
#       'end': 32,
#       'text': 'peterborough ',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 12,
#       'groundTruthId': None},
#      {'start': 33,
#       'end': 40,
#       'text': 'pe2 8ns',
#       'labelId': '11',
#       'label': 'postcode',
#       'labellingFunctionId': 36,
#       'groundTruthId': None},
#      {'start': 4,
#       'end': 17,
#       'text': 'hawksbill way',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 20,
#       'groundTruthId': None},
#      {'start': 4,
#       'end': 17,
#       'text': 'hawksbill way',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 3,
#       'text': '155',
#       'labelId': '13',
#       'label': 'street_number',
#       'labellingFunctionId': 6,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 17,
#       'text': '155 hawksbill way',
#       'labelId': 13,
#       'label': 'street_number',
#       'probability': 0.9998693020335351},
#      {'start': 19,
#       'end': 31,
#       'text': 'peterborough',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.9996591720862607},
#      {'start': 33,
#       'end': 40,
#       'text': 'pe2 8ns',
#       'labelId': 11,
#       'label': 'postcode',
#       'probability': 0.9809849302391106}],
#     'groundTruths': []},
#    'data': {'_1': 14,
#     'text': '155 hawksbill way, peterborough (pe2 8ns)',
#     'flat_tag': False,
#     'commercial_park_tag': False},
#    'id': 14},
#   {'programmatic': {'results': [{'start': 17,
#       'end': 30,
#       'text': 'peterborough ',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 12,
#       'groundTruthId': None},
#      {'start': 31,
#       'end': 38,
#       'text': 'pe2 8nr',
#       'labelId': '11',
#       'label': 'postcode',
#       'labellingFunctionId': 36,
#       'groundTruthId': None},
#      {'start': 3,
#       'end': 15,
#       'text': 'beluga close',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 2,
#       'text': '61',
#       'labelId': '13',
#       'label': 'street_number',
#       'labellingFunctionId': 6,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 15,
#       'text': '61 beluga close',
#       'labelId': 13,
#       'label': 'street_number',
#       'probability': 0.9998602036452428},
#      {'start': 17,
#       'end': 29,
#       'text': 'peterborough',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.9996733644162554},
#      {'start': 31,
#       'end': 38,
#       'text': 'pe2 8nr',
#       'labelId': 11,
#       'label': 'postcode',
#       'probability': 0.9809863735884802}],
#     'groundTruths': []},
#    'data': {'_1': 15,
#     'text': '61 beluga close, peterborough (pe2 8nr)',
#     'flat_tag': False,
#     'commercial_park_tag': False},
#    'id': 15},
#   {'programmatic': {'results': [{'start': 19,
#       'end': 32,
#       'text': 'peterborough ',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 12,
#       'groundTruthId': None},
#      {'start': 33,
#       'end': 40,
#       'text': 'pe2 8ns',
#       'labelId': '11',
#       'label': 'postcode',
#       'labellingFunctionId': 36,
#       'groundTruthId': None},
#      {'start': 4,
#       'end': 17,
#       'text': 'hawksbill way',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 20,
#       'groundTruthId': None},
#      {'start': 4,
#       'end': 17,
#       'text': 'hawksbill way',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 3,
#       'text': '139',
#       'labelId': '13',
#       'label': 'street_number',
#       'labellingFunctionId': 6,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 17,
#       'text': '139 hawksbill way',
#       'labelId': 13,
#       'label': 'street_number',
#       'probability': 0.9998693020335351},
#      {'start': 19,
#       'end': 31,
#       'text': 'peterborough',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.9996591720862607},
#      {'start': 33,
#       'end': 40,
#       'text': 'pe2 8ns',
#       'labelId': 11,
#       'label': 'postcode',
#       'probability': 0.9809849302391106}],
#     'groundTruths': []},
#    'data': {'_1': 16,
#     'text': '139 hawksbill way, peterborough (pe2 8ns)',
#     'flat_tag': False,
#     'commercial_park_tag': False},
#    'id': 16},
#   {'programmatic': {'results': [{'start': 20,
#       'end': 29,
#       'text': 'cambridge',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 13,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 18,
#       'text': 'the grafton centre',
#       'labelId': '10',
#       'label': 'building_name',
#       'labellingFunctionId': 30,
#       'groundTruthId': None},
#      {'start': 20,
#       'end': 29,
#       'text': 'cambridge',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 18,
#       'text': 'the grafton centre',
#       'labelId': '10',
#       'label': 'building_name',
#       'labellingFunctionId': 77,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 18,
#       'text': 'the grafton centre',
#       'labelId': 10,
#       'label': 'building_name',
#       'probability': 0.9997629730555239},
#      {'start': 20,
#       'end': 29,
#       'text': 'cambridge',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.5744410742030762}],
#     'groundTruths': []},
#    'data': {'_1': 17,
#     'text': 'the grafton centre, cambridge',
#     'flat_tag': False,
#     'commercial_park_tag': False},
#    'id': 17},
#   {'programmatic': {'results': [{'start': 19,
#       'end': 32,
#       'text': 'peterborough ',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 12,
#       'groundTruthId': None},
#      {'start': 33,
#       'end': 40,
#       'text': 'pe2 8ns',
#       'labelId': '11',
#       'label': 'postcode',
#       'labellingFunctionId': 36,
#       'groundTruthId': None},
#      {'start': 4,
#       'end': 17,
#       'text': 'hawksbill way',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 20,
#       'groundTruthId': None},
#      {'start': 4,
#       'end': 17,
#       'text': 'hawksbill way',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 3,
#       'text': '157',
#       'labelId': '13',
#       'label': 'street_number',
#       'labellingFunctionId': 6,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 17,
#       'text': '157 hawksbill way',
#       'labelId': 13,
#       'label': 'street_number',
#       'probability': 0.9998693020335351},
#      {'start': 19,
#       'end': 31,
#       'text': 'peterborough',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.9996591720862607},
#      {'start': 33,
#       'end': 40,
#       'text': 'pe2 8ns',
#       'labelId': 11,
#       'label': 'postcode',
#       'probability': 0.9809849302391106}],
#     'groundTruths': []},
#    'data': {'_1': 18,
#     'text': '157 hawksbill way, peterborough (pe2 8ns)',
#     'flat_tag': False,
#     'commercial_park_tag': False},
#    'id': 18},
#   {'programmatic': {'results': [{'start': 19,
#       'end': 32,
#       'text': 'peterborough ',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 12,
#       'groundTruthId': None},
#      {'start': 33,
#       'end': 40,
#       'text': 'pe2 8ny',
#       'labelId': '11',
#       'label': 'postcode',
#       'labellingFunctionId': 36,
#       'groundTruthId': None},
#      {'start': 4,
#       'end': 17,
#       'text': 'hawksbill way',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 20,
#       'groundTruthId': None},
#      {'start': 4,
#       'end': 17,
#       'text': 'hawksbill way',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 3,
#       'text': '286',
#       'labelId': '13',
#       'label': 'street_number',
#       'labellingFunctionId': 6,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 17,
#       'text': '286 hawksbill way',
#       'labelId': 13,
#       'label': 'street_number',
#       'probability': 0.9998693020335351},
#      {'start': 19,
#       'end': 31,
#       'text': 'peterborough',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.9996591720862607},
#      {'start': 33,
#       'end': 40,
#       'text': 'pe2 8ny',
#       'labelId': 11,
#       'label': 'postcode',
#       'probability': 0.9809849302391106}],
#     'groundTruths': []},
#    'data': {'_1': 19,
#     'text': '286 hawksbill way, peterborough (pe2 8ny)',
#     'flat_tag': False,
#     'commercial_park_tag': False},
#    'id': 19},
#   {'programmatic': {'results': [{'start': 24,
#       'end': 34,
#       'text': 'cambridge ',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 12,
#       'groundTruthId': None},
#      {'start': 3,
#       'end': 22,
#       'text': 'great northern road',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 22,
#       'groundTruthId': None},
#      {'start': 34,
#       'end': 41,
#       'text': 'cb1 2fx',
#       'labelId': '11',
#       'label': 'postcode',
#       'labellingFunctionId': 36,
#       'groundTruthId': None},
#      {'start': 3,
#       'end': 22,
#       'text': 'great northern road',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 2,
#       'text': '88',
#       'labelId': '13',
#       'label': 'street_number',
#       'labellingFunctionId': 6,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 22,
#       'text': '88 great northern road',
#       'labelId': 13,
#       'label': 'street_number',
#       'probability': 0.9998697004066766},
#      {'start': 24,
#       'end': 41,
#       'text': 'cambridge cb1 2fx',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.775172606157009}],
#     'groundTruths': []},
#    'data': {'_1': 20,
#     'text': '88 great northern road, cambridge cb1 2fx',
#     'flat_tag': False,
#     'commercial_park_tag': False},
#    'id': 20},
#   {'programmatic': {'results': [{'start': 29,
#       'end': 38,
#       'text': 'barnsley ',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 12,
#       'groundTruthId': None},
#      {'start': 39,
#       'end': 46,
#       'text': 's70 5xf',
#       'labelId': '11',
#       'label': 'postcode',
#       'labellingFunctionId': 36,
#       'groundTruthId': None},
#      {'start': 3,
#       'end': 17,
#       'text': 'sheffield road',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 2,
#       'text': '73',
#       'labelId': '13',
#       'label': 'street_number',
#       'labellingFunctionId': 6,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 17,
#       'text': '73 sheffield road',
#       'labelId': 13,
#       'label': 'street_number',
#       'probability': 0.9998602036452428},
#      {'start': 29,
#       'end': 37,
#       'text': 'barnsley',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.9996733644162554},
#      {'start': 39,
#       'end': 46,
#       'text': 's70 5xf',
#       'labelId': 11,
#       'label': 'postcode',
#       'probability': 0.9809863735884802}],
#     'groundTruths': []},
#    'data': {'_1': 21,
#     'text': '73 sheffield road, birdwell, barnsley (s70 5xf)',
#     'flat_tag': False,
#     'commercial_park_tag': False},
#    'id': 21},
#   {'programmatic': {'results': [{'start': 29,
#       'end': 38,
#       'text': 'barnsley ',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 12,
#       'groundTruthId': None},
#      {'start': 39,
#       'end': 46,
#       'text': 's70 5xf',
#       'labelId': '11',
#       'label': 'postcode',
#       'labellingFunctionId': 36,
#       'groundTruthId': None},
#      {'start': 3,
#       'end': 17,
#       'text': 'sheffield road',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 2,
#       'text': '79',
#       'labelId': '13',
#       'label': 'street_number',
#       'labellingFunctionId': 6,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 17,
#       'text': '79 sheffield road',
#       'labelId': 13,
#       'label': 'street_number',
#       'probability': 0.9998602036452428},
#      {'start': 29,
#       'end': 37,
#       'text': 'barnsley',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.9996733644162554},
#      {'start': 39,
#       'end': 46,
#       'text': 's70 5xf',
#       'labelId': 11,
#       'label': 'postcode',
#       'probability': 0.9809863735884802}],
#     'groundTruths': []},
#    'data': {'_1': 22,
#     'text': '79 sheffield road, birdwell, barnsley (s70 5xf)',
#     'flat_tag': False,
#     'commercial_park_tag': False},
#    'id': 22},
#   {'programmatic': {'results': [{'start': 30,
#       'end': 39,
#       'text': 'barnsley ',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 12,
#       'groundTruthId': None},
#      {'start': 40,
#       'end': 47,
#       'text': 's70 5tj',
#       'labelId': '11',
#       'label': 'postcode',
#       'labellingFunctionId': 36,
#       'groundTruthId': None},
#      {'start': 4,
#       'end': 18,
#       'text': 'sheffield road',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 3,
#       'text': '185',
#       'labelId': '13',
#       'label': 'street_number',
#       'labellingFunctionId': 6,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 18,
#       'text': '185 sheffield road',
#       'labelId': 13,
#       'label': 'street_number',
#       'probability': 0.9998602036452428},
#      {'start': 30,
#       'end': 38,
#       'text': 'barnsley',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.9996733644162554},
#      {'start': 40,
#       'end': 47,
#       'text': 's70 5tj',
#       'labelId': 11,
#       'label': 'postcode',
#       'probability': 0.9809863735884802}],
#     'groundTruths': []},
#    'data': {'_1': 23,
#     'text': '185 sheffield road, birdwell, barnsley (s70 5tj)',
#     'flat_tag': False,
#     'commercial_park_tag': False},
#    'id': 23},
#   {'programmatic': {'results': [{'start': 30,
#       'end': 39,
#       'text': 'barnsley ',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 12,
#       'groundTruthId': None},
#      {'start': 40,
#       'end': 47,
#       'text': 's70 5tj',
#       'labelId': '11',
#       'label': 'postcode',
#       'labellingFunctionId': 36,
#       'groundTruthId': None},
#      {'start': 4,
#       'end': 18,
#       'text': 'sheffield road',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 3,
#       'text': '211',
#       'labelId': '13',
#       'label': 'street_number',
#       'labellingFunctionId': 6,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 18,
#       'text': '211 sheffield road',
#       'labelId': 13,
#       'label': 'street_number',
#       'probability': 0.9998602036452428},
#      {'start': 30,
#       'end': 38,
#       'text': 'barnsley',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.9996733644162554},
#      {'start': 40,
#       'end': 47,
#       'text': 's70 5tj',
#       'labelId': 11,
#       'label': 'postcode',
#       'probability': 0.9809863735884802}],
#     'groundTruths': []},
#    'data': {'_1': 24,
#     'text': '211 sheffield road, birdwell, barnsley (s70 5tj)',
#     'flat_tag': False,
#     'commercial_park_tag': False},
#    'id': 24},
#   {'programmatic': {'results': [{'start': 30,
#       'end': 39,
#       'text': 'barnsley ',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 12,
#       'groundTruthId': None},
#      {'start': 40,
#       'end': 47,
#       'text': 's70 5tg',
#       'labelId': '11',
#       'label': 'postcode',
#       'labellingFunctionId': 36,
#       'groundTruthId': None},
#      {'start': 4,
#       'end': 18,
#       'text': 'sheffield road',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 3,
#       'text': '298',
#       'labelId': '13',
#       'label': 'street_number',
#       'labellingFunctionId': 6,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 18,
#       'text': '298 sheffield road',
#       'labelId': 13,
#       'label': 'street_number',
#       'probability': 0.9998602036452428},
#      {'start': 30,
#       'end': 38,
#       'text': 'barnsley',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.9996733644162554},
#      {'start': 40,
#       'end': 47,
#       'text': 's70 5tg',
#       'labelId': 11,
#       'label': 'postcode',
#       'probability': 0.9809863735884802}],
#     'groundTruths': []},
#    'data': {'_1': 25,
#     'text': '298 sheffield road, birdwell, barnsley (s70 5tg)',
#     'flat_tag': False,
#     'commercial_park_tag': False},
#    'id': 25},
#   {'programmatic': {'results': [{'start': 30,
#       'end': 39,
#       'text': 'barnsley ',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 12,
#       'groundTruthId': None},
#      {'start': 40,
#       'end': 47,
#       'text': 's70 5tf',
#       'labelId': '11',
#       'label': 'postcode',
#       'labellingFunctionId': 36,
#       'groundTruthId': None},
#      {'start': 4,
#       'end': 18,
#       'text': 'sheffield road',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 3,
#       'text': '266',
#       'labelId': '13',
#       'label': 'street_number',
#       'labellingFunctionId': 6,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 18,
#       'text': '266 sheffield road',
#       'labelId': 13,
#       'label': 'street_number',
#       'probability': 0.9998602036452428},
#      {'start': 30,
#       'end': 38,
#       'text': 'barnsley',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.9996733644162554},
#      {'start': 40,
#       'end': 47,
#       'text': 's70 5tf',
#       'labelId': 11,
#       'label': 'postcode',
#       'probability': 0.9809863735884802}],
#     'groundTruths': []},
#    'data': {'_1': 26,
#     'text': '266 sheffield road, birdwell, barnsley (s70 5tf)',
#     'flat_tag': False,
#     'commercial_park_tag': False},
#    'id': 26},
#   {'programmatic': {'results': [{'start': 35,
#       'end': 36,
#       'text': '1',
#       'labelId': '13',
#       'label': 'street_number',
#       'labellingFunctionId': 9,
#       'groundTruthId': None},
#      {'start': 49,
#       'end': 59,
#       'text': 'sheffield ',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 12,
#       'groundTruthId': None},
#      {'start': 60,
#       'end': 66,
#       'text': 's3 8dr',
#       'labelId': '11',
#       'label': 'postcode',
#       'labellingFunctionId': 36,
#       'groundTruthId': None},
#      {'start': 10,
#       'end': 13,
#       'text': '223',
#       'labelId': '14',
#       'label': 'unit_id',
#       'labellingFunctionId': 47,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 9,
#       'text': 'apartment',
#       'labelId': '15',
#       'label': 'unit_type',
#       'labellingFunctionId': 18,
#       'groundTruthId': None},
#      {'start': 37,
#       'end': 47,
#       'text': 'dun street',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 13,
#       'text': 'apartment 223',
#       'labelId': 15,
#       'label': 'unit_type',
#       'probability': 0.950466356182617},
#      {'start': 35,
#       'end': 47,
#       'text': '1 dun street',
#       'labelId': 13,
#       'label': 'street_number',
#       'probability': 0.25589048696288214},
#      {'start': 49,
#       'end': 58,
#       'text': 'sheffield',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.9996895979199382},
#      {'start': 60,
#       'end': 66,
#       'text': 's3 8dr',
#       'labelId': 11,
#       'label': 'postcode',
#       'probability': 0.9819215293181822}],
#     'groundTruths': []},
#    'data': {'_1': 27,
#     'text': 'apartment 223, daisy spring works, 1 dun street, sheffield (s3 8dr)',
#     'flat_tag': True,
#     'commercial_park_tag': False},
#    'id': 27},
#   {'programmatic': {'results': [{'start': 73,
#       'end': 83,
#       'text': 'rotherham ',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 12,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 4,
#       'text': 'unit',
#       'labelId': '15',
#       'label': 'unit_type',
#       'labellingFunctionId': 14,
#       'groundTruthId': None},
#      {'start': 84,
#       'end': 91,
#       'text': 's63 7ef',
#       'labelId': '11',
#       'label': 'postcode',
#       'labellingFunctionId': 36,
#       'groundTruthId': None},
#      {'start': 6,
#       'end': 7,
#       'text': '4',
#       'labelId': '14',
#       'label': 'unit_id',
#       'labellingFunctionId': 44,
#       'groundTruthId': None},
#      {'start': 39,
#       'end': 53,
#       'text': 'doncaster road',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 7,
#       'text': 'units 4',
#       'labelId': 15,
#       'label': 'unit_type',
#       'probability': 0.7741241005323736},
#      {'start': 39,
#       'end': 53,
#       'text': 'doncaster road',
#       'labelId': 12,
#       'label': 'street_name',
#       'probability': 0.9999549649650022},
#      {'start': 73,
#       'end': 82,
#       'text': 'rotherham',
#       'labelId': 3,
#       'label': 'city',
#       'probability': 0.9996836964977323},
#      {'start': 84,
#       'end': 91,
#       'text': 's63 7ef',
#       'labelId': 11,
#       'label': 'postcode',
#       'probability': 0.9815902529518445}],
#     'groundTruths': []},
#    'data': {'_1': 28,
#     'text': 'units 4 and 6, callflex business park, doncaster road, wath upon dearne, rotherham (s63 7ef)',
#     'flat_tag': True,
#     'commercial_park_tag': True},
#    'id': 28},
#   {'programmatic': {'results': [{'start': 30,
#       'end': 39,
#       'text': 'barnsley ',
#       'labelId': '3',
#       'label': 'city',
#       'labellingFunctionId': 12,
#       'groundTruthId': None},
#      {'start': 40,
#       'end': 47,
#       'text': 's70 5tg',
#       'labelId': '11',
#       'label': 'postcode',
#       'labellingFunctionId': 36,
#       'groundTruthId': None},
#      {'start': 4,
#       'end': 18,
#       'text': 'sheffield road',
#       'labelId': '12',
#       'label': 'street_name',
#       'labellingFunctionId': 23,
#       'groundTruthId': None},
#      {'start': 0,
#       'end': 3,
#       'text': '274',
#       'labelId': '13',
#       'label': 'street_number',
#       'labellingFunctionId': 6,
#       'groundTruthId': None}],
#     'aggregateResults': [{'start': 0,
#       'end': 18,
#       'text': '274 sheffield road',
# ...
#    'labelId': 12,
#    'isValid': True,
#    'disabled': False,
#    'runTime': 2.85,
#    'metrics': None,
#    'updatedAt': '2022-03-25T08:20:36',
#    'createdAt': '2022-03-25T08:15:13'},
#   {'id': 59,
#    'name': 'special_street_names',
#    'body': 'import re\nfrom hlprogrammatic_helpers import special_streets\n\ndef special_street_names(row: Datapoint) -> List[Span]:\n    """\n    A collection of miscallaneous street names that do not fit the normal pattern\n    """\n\n    #special_streets = r"(pall mall|lower mall|haymarket|lower marsh|london wall|cheapside|eastcheap|piccadilly|aldwych|(the )?strand|point pleasant|bevis marks|old bailey|threelands|pendenza|castelnau|the old meadow|hortonwood|thoroughfare|navigation loop|turnberry|brentwood|hatton garden|whitehall|the quadrangle|green lanes|old jewry|st mary axe|minories|foxcover|meadow brook|daisy brook|north villas|south villas|march wall|millharbour|aztec west|trotwood|marlowes|petty france|petty cury|the quadrant|the spinney)"\n\n    search_pattern = re.compile(special_streets + r"(?=,| and| \\(|$)", flags=re.IGNORECASE)\n\n    coords = [(m.start(), m.end()) for m in re.finditer(search_pattern, row.text)]\n\n    return [Span(start=start, end=end) for start, end in coords]\n',
#    'labelId': 12,
#    'isValid': True,
#    'disabled': False,
#    'runTime': 5.82,
#    'metrics': None,
#    'updatedAt': '2022-04-02T12:38:42',
#    'createdAt': '2022-03-31T07:07:33'},
#   {'id': 60,
#    'name': 'park_roads',
#    'body': 'import re\n\ndef park_roads(row: Datapoint) -> List[Span]:\n    """\n    Mark all matches of a regular expression within\n    the document text as a span\n    """\n    search_pattern = re.compile(r"\\b[\\sa-z\']*park"+r"(?=,| and| \\(|$)", flags=re.IGNORECASE)\n\n    if (row.commercial_park_tag==False):\n    \n        coords = [(m.start(), m.end()) for m in re.finditer(search_pattern, row.text)]\n    else:\n        coords=[]\n    return [Span(start=start, end=end) for start, end in coords]\n',
#    'labelId': 12,
#    'isValid': True,
#    'disabled': False,
#    'runTime': 2.83,
#    'metrics': None,
#    'updatedAt': '2022-03-31T10:54:00',
#    'createdAt': '2022-03-31T07:20:44'},
#   {'id': 61,
#    'name': 'the_dales',
#    'body': 'import re\n\n\ndef the_dales(row: Datapoint) -> List[Span]:\n    """\n    Mark all matches of a regular expression within\n    the document text as a span\n    """\n    search_pattern = re.compile(r"(kirk|rye|avon|willow|darely |glen|thrush|nidder|moorside |arkengarth|wester|deep|fern|grise|common|moss)dale(?=,| and|$)", flags=re.IGNORECASE)\n\n    coords = [(m.start(), m.end()) for m in re.finditer(search_pattern, row.text)]\n\n    return [Span(start=start, end=end) for start, end in coords]\n',
#    'labelId': 12,
#    'isValid': True,
#    'disabled': False,
#    'runTime': 2.81,
#    'metrics': None,
#    'updatedAt': '2022-03-31T08:57:38',
#    'createdAt': '2022-03-31T08:45:22'},
#   {'id': 62,
#    'name': 'pavement',
#    'body': 'import re\n\n\ndef pavement(row: Datapoint) -> List[Span]:\n    """\n    Mark all matches of a regular expression within\n    the document text as a span\n    """\n    search_pattern = re.compile(r"\\b[a-z\\s]*pavement(?=,|$|;|;)", flags=re.IGNORECASE)\n\n    coords = [(m.start(), m.end()) for m in re.finditer(search_pattern, row.text)]\n\n    return [Span(start=start, end=end) for start, end in coords]\n',
#    'labelId': 12,
#    'isValid': True,
#    'disabled': False,
#    'runTime': 2.7,
#    'metrics': None,
#    'updatedAt': '2022-03-31T10:20:49',
#    'createdAt': '2022-03-31T08:59:19'},
#   {'id': 63,
#    'name': 'country_club',
#    'body': 'import re\nfrom hlprogrammatic_helpers import multi_word_no_land\n\ndef country_club(row: Datapoint) -> List[Span]:\n    """\n    Mark all matches of a regular expression within\n    the document text as a span\n    """\n    search_pattern = re.compile(multi_word_no_land+r"country club", flags=re.IGNORECASE)\n\n    coords = [(m.start(), m.end()) for m in re.finditer(search_pattern, row.text)]\n\n    return [Span(start=start, end=end) for start, end in coords]\n',
#    'labelId': 10,
#    'isValid': True,
#    'disabled': False,
#    'runTime': 2.75,
#    'metrics': None,
#    'updatedAt': '2022-03-31T09:38:38',
#    'createdAt': '2022-03-31T09:34:14'},
#   {'id': 64,
#    'name': 'the_chilterns',
#    'body': 'import re\n\n\ndef the_chilterns(row: Datapoint) -> List[Span]:\n    """\n    Mark all matches of a regular expression within\n    the document text as a span\n    """\n    search_pattern = re.compile("the chilterns", flags=re.IGNORECASE)\n\n    coords = [(m.start(), m.end()) for m in re.finditer(search_pattern, row.text)]\n\n    return [Span(start=start, end=end) for start, end in coords]\n',
#    'labelId': 10,
#    'isValid': True,
#    'disabled': False,
#    'runTime': 2.55,
#    'metrics': None,
#    'updatedAt': '2022-03-31T09:44:29',
#    'createdAt': '2022-03-31T09:43:17'},
#   {'id': 65,
#    'name': 'side',
#    'body': 'import re\n\n\ndef side(row: Datapoint) -> List[Span]:\n    """\n    roads which for some reason are called side\n    """\n    search_pattern = re.compile("(new road|lodge|carr moor|lake|chase|thames|kennet|coppice|church|pool) side", flags=re.IGNORECASE)\n\n    coords = [(m.start(), m.end()) for m in re.finditer(search_pattern, row.text)]\n\n    return [Span(start=start, end=end) for start, end in coords]\n',
#    'labelId': 12,
#    'isValid': True,
#    'disabled': False,
#    'runTime': 2.35,
#    'metrics': None,
#    'updatedAt': '2022-03-31T10:25:47',
#    'createdAt': '2022-03-31T10:20:58'},
#   {'id': 66,
#    'name': 'welsh_pattern',
#    'body': 'import re\n\n\ndef welsh_pattern(row: Datapoint) -> List[Span]:\n    """\n    Mark all matches of a regular expression within\n    the document text as a span\n    """\n    search_pattern = re.compile(r"\\b(lon|llys|fford|clos)\\s[a-z\\-\\s\']+(?=,| and|$)", flags=re.IGNORECASE)\n\n    coords = [(m.start(), m.end()) for m in re.finditer(search_pattern, row.text)]\n\n    return [Span(start=start, end=end) for start, end in coords]\n',
#    'labelId': 12,
#    'isValid': True,
#    'disabled': False,
#    'runTime': 2.16,
#    'metrics': None,
#    'updatedAt': '2022-03-31T13:00:35',
#    'createdAt': '2022-03-31T12:10:29'},
#   {'id': 67,
#    'name': 'exhchange_building',
#    'body': 'import re\n\n\ndef exhchange_building(row: Datapoint) -> List[Span]:\n    """\n    Mark all matches of a regular expression within\n    the document text as a span\n    """\n    search_pattern = re.compile("[a-z\\s\']+exchange,", flags=re.IGNORECASE)\n\n    coords = [(m.start(), m.end()) for m in re.finditer(search_pattern, row.text)]\n\n    return [Span(start=start, end=end) for start, end in coords]\n',
#    'labelId': 10,
#    'isValid': True,
#    'disabled': False,
#    'runTime': 2.77,
#    'metrics': None,
#    'updatedAt': '2022-03-31T12:37:02',
#    'createdAt': '2022-03-31T12:36:41'},
#   {'id': 68,
#    'name': 'welsh_special',
#    'body': 'import re\nfrom hlprogrammatic_helpers import welsh_streets\n\ndef welsh_special(row: Datapoint) -> List[Span]:\n    """\n    Mark all matches of a regular expression within\n    the document text as a span\n    """\n    search_pattern = re.compile(welsh_streets, flags=re.IGNORECASE)\n\n    coords = [(m.start(), m.end()) for m in re.finditer(search_pattern, row.text)]\n\n    return [Span(start=start, end=end) for start, end in coords]\n',
#    'labelId': 12,
#    'isValid': True,
#    'disabled': False,
#    'runTime': 3.17,
#    'metrics': None,
#    'updatedAt': '2022-03-31T13:08:12',
#    'createdAt': '2022-03-31T13:06:57'},
#   {'id': 69,
#    'name': 'building_regex',
#    'body': 'import re\n\n\ndef building_regex(row: Datapoint) -> List[Span]:\n    """\n    Mark all matches of a regular expression within\n    the document text as a span\n    """\n    search_pattern = re.compile(r"(?<!\\S)(?:(?!\\b(?:at|of|and)\\b)[^\\n\\d\\),])*? building(s)?\\b(?=,| and|$|;|:)", flags=re.IGNORECASE)\n\n    coords = [(m.start(), m.end()) for m in re.finditer(search_pattern, row.text)]\n\n    return [Span(start=start, end=end) for start, end in coords]\n',
#    'labelId': 10,
#    'isValid': True,
#    'disabled': False,
#    'runTime': 2.78,
#    'metrics': None,
#    'updatedAt': '2022-03-31T14:25:24',
#    'createdAt': '2022-03-31T14:11:38'},
#   {'id': 70,
#    'name': 'meadows_regex',
#    'body': 'import re\n\n\ndef meadows_regex(row: Datapoint) -> List[Span]:\n    """\n    Mark all matches of a regular expression within\n    the document text as a span\n    """\n    search_pattern = re.compile(r"(?<=[0-9])[a-z\'\\s]+meadow(s)?(?=,| and|$|;|:)", flags=re.IGNORECASE)\n\n    coords = [(m.start(), m.end()) for m in re.finditer(search_pattern, row.text)]\n\n    return [Span(start=start, end=end) for start, end in coords]\n',
#    'labelId': 12,
#    'isValid': True,
#    'disabled': False,
#    'runTime': 1.96,
#    'metrics': None,
#    'updatedAt': '2022-04-02T07:22:29',
#    'createdAt': '2022-04-02T07:11:04'},
#   {'id': 72,
#    'name': 'charpair_point_charpair',
#    'body': 'import re\n\n\ndef charpair_point_charpair(row: Datapoint) -> List[Span]:\n    """\n    Mark all matches of a regular expression within\n    the document text as a span\n    \\b[a-z0-9]{1,2}\\.[a-z0-9]{1,2}\\.[a-z0-9]{1,2}\\b\n    \\b[a-z0-9]{1,2}\\.((\\.)?[a-z0-9]{1,2}){1,}\n    """\n    search_pattern = re.compile(r"\\b[a-z0-9]{1,2}\\.[a-z0-9]{1,2}(\\.[a-z0-9]{1,2})?\\b", flags=re.IGNORECASE)\n\n    coords = [(m.start(), m.end()) for m in re.finditer(search_pattern, row.text)]\n\n    return [Span(start=start, end=end) for start, end in coords]\n',
#    'labelId': 14,
#    'isValid': True,
#    'disabled': False,
#    'runTime': 2.14,
#    'metrics': None,
#    'updatedAt': '2022-04-02T07:38:29',
#    'createdAt': '2022-04-02T07:25:39'},
#   {'id': 73,
#    'name': 'mill',
#    'body': 'import re\n\n\ndef mill(row: Datapoint) -> List[Span]:\n    """\n    Mark all matches of a regular expression within\n    the document text as a span\n    "(?<=[0-9],)[a-z\'\\s]+mill(?=,| and|$|;|:)"\n    """\n    simple = r"(?<=[0-9])[a-z\'\\s]+mill"\n    comma = r"(?<=[0-9],)[a-z\'\\s]+mill"\n    end = r"(?=,| and|$|;|:)"\n\n    combo = r"(" +simple +r"|"+comma+ r")"+end\n\n    search_pattern = re.compile(combo, flags=re.IGNORECASE)\n\n    coords = [(m.start(), m.end()) for m in re.finditer(search_pattern, row.text)]\n\n    return [Span(start=start, end=end) for start, end in coords]\n',
#    'labelId': 10,
#    'isValid': True,
#    'disabled': False,
#    'runTime': 2.46,
#    'metrics': None,
#    'updatedAt': '2022-04-02T12:49:04',
#    'createdAt': '2022-04-02T07:47:19'},
#   {'id': 74,
#    'name': 'beggining_mill',
#    'body': 'import re\n\n\ndef beggining_mill(row: Datapoint) -> List[Span]:\n    """\n    Mills are abit funny as places can also be called mill. \n    This along with the other mill, gets around the problem by only\n    looking at the beggining\n    """\n    search_pattern = re.compile( r"(?<=^)(?:(?!\\b(?:at|at|on|in|to|adjoining)\\b)[^\\n\\d,])*? mill\\b(?=,)", flags=re.IGNORECASE)\n\n    coords = [(m.start(), m.end()) for m in re.finditer(search_pattern, row.text)]\n\n    return [Span(start=start, end=end) for start, end in coords]\n',
#    'labelId': 10,
#    'isValid': True,
#    'disabled': False,
#    'runTime': 1.98,
#    'metrics': None,
#    'updatedAt': '2022-04-02T08:07:35',
#    'createdAt': '2022-04-02T07:55:37'},
#   {'id': 75,
#    'name': 'is_carpark2',
#    'body': 'import re\n\ndef is_carpark2(row: Datapoint) -> List[Span]:\n    """ \n    Mark the first match of a regex pattern within\n    the document text as a span \n    """\n    search_pattern = re.compile(r"(?<=.{2},\\s|and\\s)((garage)|(parking(\\s)?space)|(parking space)|(car park(ing)?(\\sspace)))")\n    \n    match = re.search(search_pattern, row.text)\n    \n    if match:\n        return Span(start=match.start(), end=match.end())\n',
#    'labelId': 15,
#    'isValid': True,
#    'disabled': False,
#    'runTime': 1.72,
#    'metrics': None,
#    'updatedAt': '2022-04-02T12:22:52',
#    'createdAt': '2022-04-02T12:17:58'},
#   {'id': 76,
#    'name': 'is_storage2',
#    'body': 'import re\n\ndef is_storage2(row: Datapoint) -> List[Span]:\n    """ \n    Mark the first match of a regex pattern within\n    the document text as a span \n    """\n    search_pattern = re.compile(r"(?<=.{2},\\s|and\\s)(store|storage)")\n    \n    match = re.search(search_pattern, row.text)\n    \n    if match:\n        return Span(start=match.start(), end=match.end())\n',
#    'labelId': 15,
#    'isValid': True,
#    'disabled': False,
#    'runTime': 1.52,
#    'metrics': None,
#    'updatedAt': '2022-04-02T12:27:05',
#    'createdAt': '2022-04-02T12:26:24'},
#   {'id': 77,
#    'name': 'words_only_start',
#    'body': 'import re\n\n\ndef words_only_start(row: Datapoint) -> List[Span]:\n    """\n    Mark the first match of a regex pattern within\n    the document text as a span\n    """\n    search_pattern = re.compile("^((?!^land|\\bland|plot|\\bplot|\\d|,|floor|estate|flat|apartment|penthouse|road|street|^car(\\s)?park|^parking|^basement).)*(?=,)")\n\n    match = re.search(search_pattern, row.text)\n\n    if match:\n        return Span(start=match.start(), end=match.end())\n',
#    'labelId': 10,
#    'isValid': True,
#    'disabled': False,
#    'runTime': 3.03,
#    'metrics': None,
#    'updatedAt': '2022-04-04T07:53:31',
#    'createdAt': '2022-04-04T07:36:20'}],
#  'labels': [{'id': 10,
#    'name': 'building_name',
#    'metrics': None,
#    'updatedAt': '2022-04-04T08:44:42',
#    'createdAt': '2022-03-23T16:22:31'},
#   {'id': 3,
#    'name': 'city',
#    'metrics': None,
#    'updatedAt': '2022-04-04T08:44:20',
#    'createdAt': '2022-03-23T16:13:41'},
#   {'id': 7,
#    'name': 'condition_description',
#    'metrics': None,
#    'updatedAt': '2022-04-04T08:44:32',
#    'createdAt': '2022-03-23T16:13:41'},
#   {'id': 4,
#    'name': 'condition_temperature',
#    'metrics': None,
#    'updatedAt': '2022-04-04T08:44:23',
#    'createdAt': '2022-03-23T16:13:41'},
#   {'id': 6,
#    'name': 'country',
#    'metrics': None,
#    'updatedAt': '2022-04-04T08:44:29',
#    'createdAt': '2022-03-23T16:13:41'},
#   {'id': 2,
#    'name': 'current_location',
#    'metrics': None,
#    'updatedAt': '2022-04-04T08:44:15',
#    'createdAt': '2022-03-23T16:13:41'},
#   {'id': 8,
#    'name': 'geographic_poi',
#    'metrics': None,
#    'updatedAt': '2022-04-04T08:44:35',
#    'createdAt': '2022-03-23T16:13:41'},
#   {'id': 17,
#    'name': 'last_do_not_use',
#    'metrics': None,
#    'updatedAt': '2022-04-04T08:45:09',
#    'createdAt': '2022-03-23T16:22:31'},
#   {'id': 16,
#    'name': 'number_filter',
#    'metrics': None,
#    'updatedAt': '2022-04-04T08:45:06',
#    'createdAt': '2022-03-23T16:22:31'},
#   {'id': 11,
#    'name': 'postcode',
#    'metrics': None,
#    'updatedAt': '2022-04-04T08:44:47',
#    'createdAt': '2022-03-23T16:22:31'},
#   {'id': 1,
#    'name': 'spatial_relation',
#    'metrics': None,
#    'updatedAt': '2022-04-04T08:44:12',
#    'createdAt': '2022-03-23T16:13:41'},
#   {'id': 5,
#    'name': 'state',
#    'metrics': None,
#    'updatedAt': '2022-04-04T08:44:26',
#    'createdAt': '2022-03-23T16:13:41'},
#   {'id': 12,
#    'name': 'street_name',
#    'metrics': None,
#    'updatedAt': '2022-04-04T10:53:28',
#    'createdAt': '2022-03-23T16:22:31'},
#   {'id': 13,
#    'name': 'street_number',
#    'metrics': None,
#    'updatedAt': '2022-04-04T08:44:56',
#    'createdAt': '2022-03-23T16:22:31'},
#   {'id': 9,
#    'name': 'timeRange',
#    'metrics': None,
#    'updatedAt': '2022-04-04T08:44:38',
#    'createdAt': '2022-03-23T16:13:41'},
#   {'id': 14,
#    'name': 'unit_id',
#    'metrics': None,
#    'updatedAt': '2022-04-04T08:44:59',
#    'createdAt': '2022-03-23T16:22:31'},
#   {'id': 15,
#    'name': 'unit_type',
#    'metrics': None,
#    'updatedAt': '2022-04-04T08:45:03',
#    'createdAt': '2022-03-23T16:22:31'}]}

# %%
all_entities = pd.json_normalize(
    all_entities_json["datapoints"],
    record_path=["programmatic", "results"],
    meta=["data", "id"],
    #record_prefix="result_stuff.",
    meta_prefix="data_stuff.",
    errors="ignore",
)
all_entities = all_entities.rename(columns = {'data_stuff.id':'datapoint_id',
                                             'text':'label_text'})

all_entities["text"] = all_entities["data_stuff.data"].map(lambda x: x["text"])

#all_entities.drop(['data_stuff.data'], axis = 1, inplace = True)

all_entities = all_entities.sort_values(['datapoint_id', 'start'])

# %%
# all_entities = pd.json_normalize(all_entities_json, record_path = "labels",
#                        meta = ['datapoint_id', 'text'])

all_entities['label_id_count'] = all_entities.groupby(['datapoint_id', 'label']).cumcount()

all_entities['label_text'] =all_entities['label_text'].str.replace("100-1124", "100-112")

#strips leading and trailing whitespace. this makes matching better
#but means the start and end points are incorrect
#There may be a crafty way of fixing this
all_entities['label_text'] = all_entities['label_text'].str.strip()

all_entities.drop(columns = ['data_stuff.data'], inplace = True)

# %%
all_entities
# Out:
#         datapoint_id  start  end                      label_text labelId  \
# 0                  0      0   25       westleigh lodge care home      10
# 1                  0     27   39                    nel pan lane      12
# 2                  0     41   47                           leigh       3
# 3                  0     48   55                         wn7 5jt      11
# 4                  1      0    4                            flat      15
# ...              ...    ...  ...                             ...     ...
# 414322         94087     12   42  discovery dock apartments east      10
# 414323         94087     44   45                               3      13
# 414324         94087     46   63               south quay square      12
# 414325         94087     65   72                          london       3
# 414326         94087     73   80                         e14 9ru      11
#
#                 label  labellingFunctionId groundTruthId  \
# 0       building_name                   30          None
# 1         street_name                   24          None
# 2                city                   12          None
# 3            postcode                   36          None
# 4           unit_type                   18          None
# ...               ...                  ...           ...
# 414322  building_name                   54          None
# 414323  street_number                    9          None
# 414324    street_name                   22          None
# 414325           city                   12          None
# 414326       postcode                   36          None
#
#                                                      text  label_id_count
# 0       westleigh lodge care home, nel pan lane, leigh...               0
# 1       westleigh lodge care home, nel pan lane, leigh...               0
# 2       westleigh lodge care home, nel pan lane, leigh...               0
# 3       westleigh lodge care home, nel pan lane, leigh...               0
# 4            flat 1, 1a canal street, manchester (m1 3he)               0
# ...                                                   ...             ...
# 414322  storage 17, discovery dock apartments east, 3 ...               0
# 414323  storage 17, discovery dock apartments east, 3 ...               0
# 414324  storage 17, discovery dock apartments east, 3 ...               0
# 414325  storage 17, discovery dock apartments east, 3 ...               0
# 414326  storage 17, discovery dock apartments east, 3 ...               0
#
# [414327 rows x 10 columns]

# %% [markdown]
# ## remove overlapping entities

# %%
def remove_overlaps(x):
    #this functions is modified from 
    #https://stackoverflow.com/questions/57804145/combining-rows-with-overlapping-time-periods-in-a-pandas-dataframe
    x = x.copy()
    #create a unique label, this is used for joining the data back on 
    #and removes a reliance on the data being pre-sorted
    x['unique_label'] = [*range(0,x.shape[0])]
    #get the size of the spans
    x['diff'] = (x['end']-x['start'])

    
    startdf = pd.DataFrame({'position':x['start'], 'unique_label':x['unique_label'], 'what':1})
    enddf = pd.DataFrame({'position':x['end'], 'unique_label':x['unique_label'], 'what':-1})
    mergdf = pd.concat([startdf, enddf]).sort_values('position')
    mergdf['running'] = mergdf['what'].cumsum()
    mergdf['newwin'] = mergdf['running'].eq(1) & mergdf['what'].eq(1)
    mergdf['group'] = mergdf['newwin'].cumsum()
    
    #merge back on using uniqe label to ensure correct ordering
    x = x.merge(mergdf.loc[mergdf['what'].eq(1),['unique_label','group']], how = 'left', on = 'unique_label')
    #sort within group and keep only the largest
    x = x.sort_values('diff', ascending=False).groupby(['group', 'datapoint_id'], as_index=False).first()

    x.drop(['diff', 'unique_label', 'group'], axis = 1, inplace = True)

    return(x)


#ddf = remove_overlaps(df)
#takes about 20 minutes
all_entities = all_entities.groupby(['datapoint_id']).apply(remove_overlaps)

# %% [markdown]
# ## Example of the data frame of labels

# %%
all_entities.reset_index(drop = True, inplace = True)

# %% [markdown]
# ## Identify multi versus single address observations
#
# Some addresses may have the form xx to yy but should not be expanded as this is a building that covers multiple street numbers. Items such as these need to be carefully removed before expansion

# %%
xx_to_yy_regex = r'^\d+(\s)?(-|to)(\s)?\d+$'

multi_check_df = all_entities[['datapoint_id', 'text', ]].drop_duplicates()
multi_check_df['comma_count'] = multi_check_df['text'].str.count(',')
multi_check_df['land'] = multi_check_df['text'].str.contains(r"^(land|plot|airspace|car|parking)", case = False)

multi_check_df['business'] = multi_check_df['text'].str.contains(r"(cinema)|(hotel)|(office)|centre|(\bpub)|holiday(\s)?inn|travel(\s)?lodge|(business)|(cafe)|(^shop)|( shop)|(restaurant)|(home)|(^store(s)?\b)|(^storage\b)|(company)|(ltd)|(limited)|(plc)|(retail)|(leisure)|(industrial)|(hall of)|trading|commercial|works", case = False)
temp_df = all_entities[['datapoint_id', 'label']].groupby(['datapoint_id', 'label']).value_counts().to_frame(name = "counts").reset_index().pivot(index = 'datapoint_id', columns = 'label', values = 'counts').fillna(0)
#test['datapoint_id'] = test.index

xx_to_yy_street_counts = all_entities['datapoint_id'][all_entities['label_text'].str.contains(
    xx_to_yy_regex)& (all_entities['label']=="street_number")
                            ].to_frame(name = 'datapoint_id').groupby('datapoint_id').size().to_frame(name = 'xx_to_yy_street_counts')

xx_to_yy_unit_counts = all_entities['datapoint_id'][all_entities['label_text'].str.contains(
    xx_to_yy_regex)& (all_entities['label']=="unit_id")
                            ].to_frame(name = 'datapoint_id').groupby('datapoint_id').size().to_frame(name = 'xx_to_yy_unit_counts')

multi_check_df = multi_check_df.merge(temp_df, how = 'left', left_on = "datapoint_id", right_index = True).\
merge(xx_to_yy_street_counts, how = 'left', left_on = "datapoint_id", right_index = True).\
merge(xx_to_yy_unit_counts, how = 'left', left_on = "datapoint_id", right_index = True).fillna(0)


del xx_to_yy_street_counts
del xx_to_yy_unit_counts

#separate the classes using logical rules
multi_check_df['class'] = np.select(
    [
        multi_check_df['land']== True,
        multi_check_df['business']== True,
        (multi_check_df['building_name']==1) & (multi_check_df['unit_id'] == 0), #this has to go infront of 'multi_check_df['xx_to_yy_unit_counts']>0'
        multi_check_df['xx_to_yy_unit_counts']>0,
        multi_check_df['street_number']>1,
        multi_check_df['unit_id']>1,
        (multi_check_df['street_number']<=1) & (multi_check_df['xx_to_yy_street_counts']<=1) & (multi_check_df['unit_id']<=1) ##This does most of the heavy lifting
    ], 
    [
        'single',
        'single',
        'single',
        'multi',
        'multi',
        'multi',
        'single',
        
    ], 
    default='unknown'
)
multi_check_df
# Out:
# <ipython-input-18-8da8733f2f27>:5: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   multi_check_df['land'] = multi_check_df['text'].str.contains(r"^(land|plot|airspace|car|parking)", case = False)
# <ipython-input-18-8da8733f2f27>:7: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   multi_check_df['business'] = multi_check_df['text'].str.contains(r"(cinema)|(hotel)|(office)|centre|(\bpub)|holiday(\s)?inn|travel(\s)?lodge|(business)|(cafe)|(^shop)|( shop)|(restaurant)|(home)|(^store(s)?\b)|(^storage\b)|(company)|(ltd)|(limited)|(plc)|(retail)|(leisure)|(industrial)|(hall of)|trading|commercial|works", case = False)
# <ipython-input-18-8da8733f2f27>:11: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   xx_to_yy_street_counts = all_entities['datapoint_id'][all_entities['label_text'].str.contains(
# <ipython-input-18-8da8733f2f27>:15: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   xx_to_yy_unit_counts = all_entities['datapoint_id'][all_entities['label_text'].str.contains(
#         datapoint_id                                               text  \
# 0                  0  westleigh lodge care home, nel pan lane, leigh...
# 4                  1       flat 1, 1a canal street, manchester (m1 3he)
# 9                  2       flat 201, 1 regent road, manchester (m3 4ay)
# 14                 3  land at 2a gerard street, ashton in makerfield...
# 18                 4  unit 111, timber wharf, worsley street, manche...
# ...              ...                                                ...
# 414305         94083       2nd floor, 52 lime street, london (ec3m 7aw)
# 414309         94084                 155 bishopsgate, london (ec2m 3ad)
# 414313         94085  9th and 10th floors, 52 lime street, london (e...
# 414317         94086  part of tenth floor, 6 bevis marks, london (ec...
# 414321         94087  storage 17, discovery dock apartments east, 3 ...
#
#         comma_count   land  business  building_name  city  number_filter  \
# 0                 2  False      True            1.0   1.0            0.0
# 4                 2  False     False            0.0   1.0            0.0
# 9                 2  False     False            0.0   1.0            0.0
# 14                2   True     False            0.0   1.0            0.0
# 18                3  False     False            1.0   1.0            0.0
# ...             ...    ...       ...            ...   ...            ...
# 414305            2  False     False            0.0   1.0            0.0
# 414309            1  False     False            0.0   1.0            0.0
# 414313            2  False     False            0.0   1.0            0.0
# 414317            2  False     False            0.0   1.0            0.0
# 414321            3  False      True            1.0   1.0            0.0
#
#         postcode  street_name  street_number  unit_id  unit_type  \
# 0            1.0          1.0            0.0      0.0        0.0
# 4            1.0          1.0            1.0      0.0        1.0
# 9            1.0          1.0            1.0      0.0        1.0
# 14           1.0          1.0            0.0      0.0        1.0
# 18           1.0          1.0            0.0      1.0        1.0
# ...          ...          ...            ...      ...        ...
# 414305       1.0          1.0            1.0      0.0        0.0
# 414309       1.0          1.0            1.0      0.0        0.0
# 414313       1.0          1.0            1.0      0.0        0.0
# 414317       1.0          1.0            1.0      0.0        0.0
# 414321       1.0          1.0            1.0      0.0        1.0
#
#         xx_to_yy_street_counts  xx_to_yy_unit_counts   class
# 0                          0.0                   0.0  single
# 4                          0.0                   0.0  single
# 9                          0.0                   0.0  single
# 14                         0.0                   0.0  single
# 18                         0.0                   0.0  single
# ...                        ...                   ...     ...
# 414305                     0.0                   0.0  single
# 414309                     0.0                   0.0  single
# 414313                     0.0                   0.0  single
# 414317                     0.0                   0.0  single
# 414321                     0.0                   0.0  single
#
# [94088 rows x 16 columns]

# %% [markdown]
# ### Get the indexes of multi properties

# %%
multi_unit_id = set(multi_check_df['datapoint_id'][(multi_check_df['class']=='multi') &( multi_check_df['unit_id']>0)].tolist())
multi_property = set(multi_check_df['datapoint_id'][(multi_check_df['class']=='multi') &( multi_check_df['unit_id']==0)].tolist())
all_multi_ids = list(multi_unit_id) +list(multi_property)
multi_check_df.groupby('class').size()
# Out:
# class
# multi      5194
# single    88894
# dtype: int64

# %% [markdown]
# # checking weird regex problems

# %%
all_entities['label_text'].to_list()[0]

# %% [markdown]
# ## Spread label data

# %%
#pivot the columns so that each label class is it's own column and the value in the column is the text

temp_df = all_entities[all_entities.datapoint_id.isin(all_multi_ids)]

temp_df['index'] = temp_df.index
df = temp_df[['index', 'label', 'label_text']].pivot(index='index',columns='label',values='label_text')
#add the datapoint_id back in for each of joining
df = pd.concat([temp_df['datapoint_id'], df], axis=1).merge(temp_df[['datapoint_id' ,'text']].drop_duplicates(), 
          how = "left",
          left_on = "datapoint_id", right_on = "datapoint_id")
del temp_df
# Out:
# <ipython-input-20-8bdee3a0bd7d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_df['index'] = temp_df.index

# %%
#df[df.text.str.contains('unit')==True].drop_duplicates()#.to_csv('/tf/empty_homes_data/delete_me.csv')

# %% [markdown]
# ## Add blockers
#
# Blockers prevent the filling of wrong information. As an example if a building is going to back fill up previous addresses it should not back fill past another street as this is highly unlikely to be the same building

# %%
df['building_name'][df['street_name'].notnull()] = 'block'
df['street_number'][df['street_name'].notnull()] = 'block' #for multi-flats inside a common building

#returns true if current number filter is null and the next row has street_number or unit id is not null
#prevents number filters propergsating back across roads and unit ids
number_filter_block = df['number_filter'].isnull() & (df['street_number'].shift().notnull() |df['unit_id'].shift().notnull())
df['number_filter'][number_filter_block] = 'block'
# Out:
# <ipython-input-21-b3dd40429e14>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['building_name'][df['street_name'].notnull()] = 'block'
# <ipython-input-21-b3dd40429e14>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['street_number'][df['street_name'].notnull()] = 'block' #for multi-flats inside a common building
# <ipython-input-21-b3dd40429e14>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['number_filter'][number_filter_block] = 'block'

# %% [markdown]
# ## Backfill
#
# Backfilling adds address information in. However, street address should only be back filled for multi addresses.
# I need to work out how to do flat, which may be before or after the unit ID
# Also I don't think this is a very good way of doing it at all. Using the pre-spread list is probably better and only working on the multi-addresses is probably a much faster and cleaner way. But I will have to think about how to do it

# %%
df['number_filter'] = df[['datapoint_id','number_filter']].groupby('datapoint_id').fillna(method ='bfill')
df['building_name'] = df[['datapoint_id','building_name']].groupby('datapoint_id').fillna(method ='bfill')
df['street_number'] = df[['datapoint_id','street_number']].groupby('datapoint_id').fillna(method ='bfill')
df['postcode'] = df[['datapoint_id','postcode']].groupby('datapoint_id').fillna(method ='bfill')
df['street_name'] = df[['datapoint_id','street_name']].groupby('datapoint_id').fillna(method ='bfill')
df['number_filter'] = df[['datapoint_id','number_filter']].groupby('datapoint_id').fillna(method ='bfill')
df['city'] = df[['datapoint_id','city']].groupby('datapoint_id').fillna(method ='bfill')
df['unit_type'] = df[['datapoint_id','unit_type']].groupby('datapoint_id').fillna(method ='ffill') #should this will backwards or forwards? as mostly it is flat xx not xx flat?

# %%
df

# %%
expanded_street = df[df.datapoint_id.isin(multi_property) & df.street_number.str.contains(xx_to_yy_regex)].reset_index()
expanded_unit_id = df[df.datapoint_id.isin(multi_unit_id) & df.unit_id.str.contains(xx_to_yy_regex)].reset_index()

expanded_street = expand_dataframe_numbers(expanded_street, column_name = "street_number" )
expanded_unit_id = expand_dataframe_numbers(expanded_unit_id, column_name = "unit_id" )
# Out:
# <ipython-input-23-6dd2bb121964>:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   expanded_street = df[df.datapoint_id.isin(multi_property) & df.street_number.str.contains(xx_to_yy_regex)].reset_index()
# <ipython-input-23-6dd2bb121964>:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   expanded_unit_id = df[df.datapoint_id.isin(multi_unit_id) & df.unit_id.str.contains(xx_to_yy_regex)].reset_index()
# i= 0  expand time,0.001 filter time0.0 make_dataframe_time 0.001
# i= 1000  expand time,0.203 filter time0.127 make_dataframe_time 0.985
# i= 2000  expand time,0.387 filter time0.244 make_dataframe_time 1.873
# i= 0  expand time,0.001 filter time0.0 make_dataframe_time 0.001
# i= 1000  expand time,0.19 filter time0.122 make_dataframe_time 1.025

# %%
#unit id and street number that does does not have the xx to yy format and so has already been expanded by spreaing and backfilling
expanded_street_simple = df[df.datapoint_id.isin(multi_property) & (df.street_number.str.contains(xx_to_yy_regex)==False) & (df.street_number!='block')].reset_index()
expanded_unit_id_simple = df[df.datapoint_id.isin(multi_unit_id) & (df.unit_id.str.contains(xx_to_yy_regex)==False) & (df.unit_id!='block')].reset_index()
# Out:
# <ipython-input-24-53d39f72e523>:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   expanded_street_simple = df[df.datapoint_id.isin(multi_property) & (df.street_number.str.contains(xx_to_yy_regex)==False) & (df.street_number!='block')].reset_index()
# <ipython-input-24-53d39f72e523>:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   expanded_unit_id_simple = df[df.datapoint_id.isin(multi_unit_id) & (df.unit_id.str.contains(xx_to_yy_regex)==False) & (df.unit_id!='block')].reset_index()

# %%
#pivot the columns so that each label class is it's own column and the value in the column is the text

#remove the multi-addresses
single_address_only =all_entities[~all_entities['datapoint_id'].isin(all_multi_ids)]
#remove all but the first instance of a label in the remaining instances
#this is because for single addresses there should be only a single label for each class
single_address_only =single_address_only[single_address_only['label_id_count']==0]
df2 = single_address_only.pivot(index='datapoint_id',columns='label',values='label_text')
#add the datapoint_id back in for each of joining
df2 = df2.merge(single_address_only[['datapoint_id', 'text']].drop_duplicates(), 
          how = "left",
          left_on = "datapoint_id", right_on = "datapoint_id")

df2
# Out:
#        datapoint_id                   building_name        city number_filter  \
# 0                 0       westleigh lodge care home       leigh           NaN
# 1                 1                             NaN  manchester           NaN
# 2                 2                             NaN  manchester           NaN
# 3                 3                             NaN       wigan           NaN
# 4                 4                             NaN  manchester           NaN
# ...             ...                             ...         ...           ...
# 88889         94083                             NaN      london           NaN
# 88890         94084                             NaN      london           NaN
# 88891         94085                             NaN      london           NaN
# 88892         94086                             NaN      london           NaN
# 88893         94087  discovery dock apartments east      london           NaN
#
#        postcode        street_name street_number unit_id unit_type  \
# 0       wn7 5jt       nel pan lane           NaN     NaN       NaN
# 1        m1 3he       canal street            1a     NaN      flat
# 2        m3 4ay        regent road             1     NaN      flat
# 3       wn4 9aa      gerard street           NaN     NaN      land
# 4       m15 4nz     worsley street           NaN     111      unit
# ...         ...                ...           ...     ...       ...
# 88889  ec3m 7aw        lime street            52     NaN       NaN
# 88890  ec2m 3ad        bishopsgate           155     NaN       NaN
# 88891  ec3m 7af        lime street            52     NaN       NaN
# 88892  ec3a 7ba        bevis marks             6     NaN       NaN
# 88893   e14 9ru  south quay square             3     NaN   storage
#
#                                                     text
# 0      westleigh lodge care home, nel pan lane, leigh...
# 1           flat 1, 1a canal street, manchester (m1 3he)
# 2           flat 201, 1 regent road, manchester (m3 4ay)
# 3      land at 2a gerard street, ashton in makerfield...
# 4      unit 111, timber wharf, worsley street, manche...
# ...                                                  ...
# 88889       2nd floor, 52 lime street, london (ec3m 7aw)
# 88890                 155 bishopsgate, london (ec2m 3ad)
# 88891  9th and 10th floors, 52 lime street, london (e...
# 88892  part of tenth floor, 6 bevis marks, london (ec...
# 88893  storage 17, discovery dock apartments east, 3 ...
#
# [88894 rows x 10 columns]

# %%
full_expanded_data = pd.concat([expanded_street, 
           expanded_unit_id, 
           expanded_street_simple, 
           expanded_unit_id_simple, 
           df2, ])

# %%
ocod_data =  pd.read_csv('/tf/empty_homes_data/' +
                    'OCOD_FULL_2022_02.csv',
                   encoding_errors= 'ignore').rename(columns = lambda x: x.lower().replace(" ", "_"))
#empty addresses cannot be used. however there are only three so not a problem
ocod_data = ocod_data.dropna(subset = 'property_address')
ocod_data.reset_index(inplace = True, drop = True)
ocod_data = ocod_data[['title_number', 'tenure', 'district', 'county',
       'region', 'multiple_address_indicator', 'price_paid', 'property_address']]
# Out:
# <ipython-input-27-83c4912c1574>:1: DtypeWarning: Columns (24,28,30,32,33,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   ocod_data =  pd.read_csv('/tf/empty_homes_data/' +

# %%
full_expanded_data = full_expanded_data.merge(ocod_data, how = "left", left_on = "datapoint_id", right_index = True)
full_expanded_data['property_address'].str.lower().equals(full_expanded_data['text']) # When 'True' this shows the match works because the address string are equal
# Out:
# False

# %%
#Why is this 1 address not the same?

full_expanded_data.loc[~((full_expanded_data['text']==full_expanded_data['property_address'].str.lower())), ['property_address', 'text', 'datapoint_id']]
# Out:
#                                        property_address  \
# 0     202, Stanley Court 19-23, Stanley Street, Live...
# 1     202, Stanley Court 19-23, Stanley Street, Live...
# 2     202, Stanley Court 19-23, Stanley Street, Live...
# 3     202, Stanley Court 19-23, Stanley Street, Live...
# 4     202, Stanley Court 19-23, Stanley Street, Live...
# 8589  40a, 40, 40¨, 42, 44 East Bond Street, 2, 4 Gr...
# 8590  40a, 40, 40¨, 42, 44 East Bond Street, 2, 4 Gr...
# 8591  40a, 40, 40¨, 42, 44 East Bond Street, 2, 4 Gr...
# 8592  40a, 40, 40¨, 42, 44 East Bond Street, 2, 4 Gr...
# 8593  40a, 40, 40¨, 42, 44 East Bond Street, 2, 4 Gr...
# 8594  40a, 40, 40¨, 42, 44 East Bond Street, 2, 4 Gr...
# 8595  40a, 40, 40¨, 42, 44 East Bond Street, 2, 4 Gr...
# 83    202, Stanley Court 19-23, Stanley Street, Live...
#
#                                                    text datapoint_id
# 0     202, stanley court, 19-23, stanley street, liv...         3102
# 1     202, stanley court, 19-23, stanley street, liv...         3102
# 2     202, stanley court, 19-23, stanley street, liv...         3102
# 3     202, stanley court, 19-23, stanley street, liv...         3102
# 4     202, stanley court, 19-23, stanley street, liv...         3102
# 8589  40a, 40, 40 ̈, 42, 44 east bond street, 2, 4 g...        57998
# 8590  40a, 40, 40 ̈, 42, 44 east bond street, 2, 4 g...        57998
# 8591  40a, 40, 40 ̈, 42, 44 east bond street, 2, 4 g...        57998
# 8592  40a, 40, 40 ̈, 42, 44 east bond street, 2, 4 g...        57998
# 8593  40a, 40, 40 ̈, 42, 44 east bond street, 2, 4 g...        57998
# 8594  40a, 40, 40 ̈, 42, 44 east bond street, 2, 4 g...        57998
# 8595  40a, 40, 40 ̈, 42, 44 east bond street, 2, 4 g...        57998
# 83    202, stanley court, 19-23, stanley street, liv...         3102

# %%
full_expanded_data.loc[:, 'property_address'].str.lower().loc[full_expanded_data['datapoint_id']==57998]
# Out:
# 8589    40a, 40, 40¨, 42, 44 east bond street, 2, 4 gr...
# 8590    40a, 40, 40¨, 42, 44 east bond street, 2, 4 gr...
# 8591    40a, 40, 40¨, 42, 44 east bond street, 2, 4 gr...
# 8592    40a, 40, 40¨, 42, 44 east bond street, 2, 4 gr...
# 8593    40a, 40, 40¨, 42, 44 east bond street, 2, 4 gr...
# 8594    40a, 40, 40¨, 42, 44 east bond street, 2, 4 gr...
# 8595    40a, 40, 40¨, 42, 44 east bond street, 2, 4 gr...
# Name: property_address, dtype: object

# %%
full_expanded_data['within_title_id'] = full_expanded_data.groupby('title_number').cumcount()+1
full_expanded_data['unique_id'] = [str(x) + '-' + str(y) for x, y in zip(full_expanded_data['title_number'], full_expanded_data['within_title_id'])]

tmp_df =((full_expanded_data[['title_number', 'within_title_id']].groupby('title_number').max('within_title_id'))>1)
tmp_df.columns = tmp_df.columns.str.replace('within_title_id', 'within_larger_title') #could also be called nested_address
full_expanded_data = full_expanded_data.merge(tmp_df, how = "left", left_on = "title_number", right_index = True)


full_expanded_data['postcode'] =full_expanded_data['postcode'].str.upper()
del tmp_df

#re-order the columns and drop columns that are not needed

full_expanded_data =full_expanded_data[['title_number', 'within_title_id', 'unique_id', 'within_larger_title',  'tenure','unit_id', 'unit_type','building_name','street_number', 'street_name', 'postcode','city',  'district', 'county', 'region',
       'multiple_address_indicator', 'price_paid' ,'property_address']].replace('block', np.NaN)

#save as CSV
full_expanded_data.to_csv("/tf/empty_homes_data/OCOD_cleaned_expanded2.csv")

# %%
full_expanded_data#[full_expanded_data['street_name'].isnull()]['property_address'].to_csv('/tf/empty_homes_data/street_is_null.csv')
# Out:
#       title_number  within_title_id    unique_id  within_larger_title  \
# 0         CB400630                1   CB400630-1                 True
# 1         CB400630                2   CB400630-2                 True
# 2         CB400630                3   CB400630-3                 True
# 3         CB400630                4   CB400630-4                 True
# 4         CB400630                5   CB400630-5                 True
# ...            ...              ...          ...                  ...
# 88889    AGL470128                1  AGL470128-1                False
# 88890    AGL473126                1  AGL473126-1                False
# 88891    AGL473595                1  AGL473595-1                False
# 88892    AGL475468                1  AGL475468-1                False
# 88893    AGL476501                1  AGL476501-1                False
#
#           tenure unit_id unit_type                   building_name  \
# 0       Freehold     NaN       NaN                             NaN
# 1       Freehold     NaN       NaN                             NaN
# 2       Freehold     NaN       NaN                             NaN
# 3       Freehold     NaN       NaN                             NaN
# 4       Freehold     NaN       NaN                             NaN
# ...          ...     ...       ...                             ...
# 88889  Leasehold     NaN       NaN                             NaN
# 88890  Leasehold     NaN       NaN                             NaN
# 88891  Leasehold     NaN       NaN                             NaN
# 88892  Leasehold     NaN       NaN                             NaN
# 88893  Leasehold     NaN   storage  discovery dock apartments east
#
#       street_number        street_name  postcode          city  \
# 0                 2         miller way       NaN  peterborough
# 1                 4         miller way       NaN  peterborough
# 2                 6         miller way       NaN  peterborough
# 3                 8         miller way       NaN  peterborough
# 4                10         miller way       NaN  peterborough
# ...             ...                ...       ...           ...
# 88889            52        lime street  EC3M 7AW        london
# 88890           155        bishopsgate  EC2M 3AD        london
# 88891            52        lime street  EC3M 7AF        london
# 88892             6        bevis marks  EC3A 7BA        london
# 88893             3  south quay square   E14 9RU        london
#
#                    district                county          region  \
# 0      CITY OF PETERBOROUGH  CITY OF PETERBOROUGH     EAST ANGLIA
# 1      CITY OF PETERBOROUGH  CITY OF PETERBOROUGH     EAST ANGLIA
# 2      CITY OF PETERBOROUGH  CITY OF PETERBOROUGH     EAST ANGLIA
# 3      CITY OF PETERBOROUGH  CITY OF PETERBOROUGH     EAST ANGLIA
# 4      CITY OF PETERBOROUGH  CITY OF PETERBOROUGH     EAST ANGLIA
# ...                     ...                   ...             ...
# 88889        CITY OF LONDON        GREATER LONDON  GREATER LONDON
# 88890        CITY OF LONDON        GREATER LONDON  GREATER LONDON
# 88891        CITY OF LONDON        GREATER LONDON  GREATER LONDON
# 88892        CITY OF LONDON        GREATER LONDON  GREATER LONDON
# 88893         TOWER HAMLETS        GREATER LONDON  GREATER LONDON
#
#       multiple_address_indicator  price_paid  \
# 0                              N         NaN
# 1                              N         NaN
# 2                              N         NaN
# 3                              N         NaN
# 4                              N         NaN
# ...                          ...         ...
# 88889                          N         NaN
# 88890                          N         NaN
# 88891                          N         NaN
# 88892                          N         NaN
# 88893                          N         NaN
#
#                                         property_address
# 0      2-24 (even) Miller Way, 15-25 Hammonds Drive (...
# 1      2-24 (even) Miller Way, 15-25 Hammonds Drive (...
# 2      2-24 (even) Miller Way, 15-25 Hammonds Drive (...
# 3      2-24 (even) Miller Way, 15-25 Hammonds Drive (...
# 4      2-24 (even) Miller Way, 15-25 Hammonds Drive (...
# ...                                                  ...
# 88889       2nd Floor, 52 Lime Street, London (EC3M 7AW)
# 88890                 155 Bishopsgate, London (EC2M 3AD)
# 88891  9th and 10th floors, 52 Lime Street, London (E...
# 88892  part of Tenth Floor, 6 Bevis Marks, London (EC...
# 88893  Storage 17, Discovery Dock Apartments East, 3 ...
#
# [159612 rows x 18 columns]

# %%
full_expanded_data[full_expanded_data['property_address'].str.contains('Scottish Provident')]

# %%
300000*700
