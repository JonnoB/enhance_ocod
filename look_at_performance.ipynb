# %%
import pandas as pd

test = pd.read_parquet("data/ocod_history_processed/OCOD_FULL_2015_10.parquet")

# %%
test
# Out:
#        title_number  within_title_id   unique_id  within_larger_title  \
# 0            236218                1    236218-1                 True
# 1            403779                1    403779-1                 True
# 2            404026                1    404026-1                 True
# 3          LN104402                1  LN104402-1                 True
# 4          LN167456                1  LN167456-1                 True
# ...             ...              ...         ...                  ...
# 107485       YY9019                1    YY9019-1                False
# 107486       YY9279                1    YY9279-1                False
# 107487       YY9295                1    YY9295-1                False
# 107488       YY9805                1    YY9805-1                False
# 107489       YY9844                1    YY9844-1                False
#
#            tenure unit_id unit_type  building_name street_number street_name  \
# ...
